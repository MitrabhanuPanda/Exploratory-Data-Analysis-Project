# %% [markdown]
# ## <font color="brown">IMPORTING LIBRARY

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### <font color="green">EXTRACTING DATASETS

# %%
gb_df=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS SUMMARIZATION\Dataset\Group By\Gb_gender.csv")

# %%
gb_df
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
df_gg=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS SUMMARIZATION\Dataset\Group By\gbsales.csv")

# %%
df_gg
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
mov=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS SUMMARIZATION\Dataset\Group By\imdb-top-1000.csv")

# %%
mov
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
dli=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS SUMMARIZATION\Dataset\Group By\deliveries.csv")

# %%
dli
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
mov.head(2)
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
# 1             The Godfather          1972      175  Crime          9.2
#
#                Director          Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont    Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola  Marlon Brando      1620367  134966411.0      100.0

# %%
mov.select_dtypes(["int64","float"])
# Out:
#      Runtime  IMDB_Rating  No_of_Votes        Gross  Metascore
# 0        142          9.3      2343110   28341469.0       80.0
# 1        175          9.2      1620367  134966411.0      100.0
# 2        152          9.0      2303232  534858444.0       84.0
# 3        202          9.0      1129952   57300000.0       90.0
# 4         96          9.0       689845    4360000.0       96.0
# ..       ...          ...          ...          ...        ...
# 995      115          7.6       166544  679874270.0       76.0
# 996      201          7.6        34075  195217415.0       84.0
# 997      118          7.6        43374   30500000.0       85.0
# 998       97          7.6        26471  852142728.0       78.0
# 999       86          7.6        51853  302787539.0       93.0
#
# [1000 rows x 5 columns]

# %%
mov["Genre"].value_counts()
# Out:
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: Genre, dtype: int64

# %%
# It give path
mov.groupby("Genre")

# %%
# Storing this into a variable.
gen=mov.groupby("Genre")

# %% [markdown]
# ##### APPLY BUILT-IN AGGREGATE FUNCTION ON GROUP BY OBJECTS

# %%
# IT IS DATAFRAME.
# "GENRE" IS THE INDEX.
# WE SUM ALL THE NUMERIC COLUMN FOR EVERY "GENRE".

gen.sum()
# Out:
#            Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action       22196       1367.3     72282412  3.263226e+10    10499.0
# Adventure     9656        571.5     22576163  9.496922e+09     5020.0
# Animation     8166        650.3     21978630  1.463147e+10     6082.0
# Biography    11970        698.6     24006844  8.276358e+09     6023.0
# Comedy       17380       1224.7     27620327  1.566387e+10     9840.0
# Crime        13524        857.8     33533615  8.452632e+09     6706.0
# Drama        36049       2299.7     61367304  3.540997e+10    19208.0
# Family         215         15.6       551221  4.391106e+08      158.0
# Fantasy        170         16.0       146222  7.827267e+08        0.0
# Film-Noir      312         23.9       367215  1.259105e+08      287.0
# Horror        1123         87.0      3742556  1.034649e+09      880.0
# Mystery       1429         95.7      4203004  1.256417e+09      633.0
# ...

# %%
gen.min()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                                 300          1924       45
# Adventure            2001: A Space Odyssey          1925       88
# Animation                            Akira          1940       71
# Biography                 12 Years a Slave          1928       93
# Comedy                (500) Days of Summer          1921       68
# Crime                         12 Angry Men          1931       80
# Drama                                 1917          1925       64
# Family          E.T. the Extra-Terrestrial          1971      100
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                Shadow of a Doubt          1941      100
# Horror                               Alien          1933       71
# Mystery                          Dark City          1938       96
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
gen.max()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %%
# FINDING THE TOP 3 GENRES BY TOTAL EARNING.
gen.sum()["Gross"].sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# The best way to do.  Always do like this
gen["Gross"].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# FINDING THE GENRE WITH HIGHEST AVG IMDB RATING
gen["IMDB_Rating"].mean().sort_values(ascending=False)
# Out:
# Genre
# Western      8.350000
# Crime        8.016822
# Fantasy      8.000000
# Mystery      7.975000
# Film-Noir    7.966667
# Drama        7.957439
# Action       7.949419
# Biography    7.938636
# Adventure    7.937500
# Animation    7.930488
# Horror       7.909091
# Comedy       7.901290
# Family       7.800000
# Thriller     7.800000
# Name: IMDB_Rating, dtype: float64

# %%
# FIND DIRECTOR WITH MOST POPULARITY.
dr=mov.groupby("Director")  # First Groupby it basis of "Director"

# %%
dr["No_of_Votes"].sum().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan    11578345
# Quentin Tarantino     8123208
# Steven Spielberg      7817166
# David Fincher         6607859
# Martin Scorsese       6513530
#                        ...
# J. Lee Thompson         26457
# Peter Mullan            25938
# René Laloux             25229
# Francis Lee             25198
# Kaige Chen              25088
# Name: No_of_Votes, Length: 548, dtype: int64

# %%
# FIND NUMBER OF MOVIES DONE BY EACH ACTOR.
mov["Star1"].value_counts() # Simple Way
# Out:
# Tom Hanks          12
# Robert De Niro     11
# Al Pacino          10
# Clint Eastwood     10
# Humphrey Bogart     9
#                    ..
# Preity Zinta        1
# Javier Bardem       1
# Ki-duk Kim          1
# Vladimir Garin      1
# Robert Donat        1
# Name: Star1, Length: 660, dtype: int64

# %%
st=mov.groupby("Star1") # Using group by

# %%
st["Series_Title"].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks             12
# Robert De Niro        11
# Clint Eastwood        10
# Al Pacino             10
# Leonardo DiCaprio      9
#                       ..
# Glen Hansard           1
# Giuseppe Battiston     1
# Giulietta Masina       1
# Gerardo Taracena       1
# Ömer Faruk Sorak       1
# Name: Series_Title, Length: 660, dtype: int64

# %% [markdown]
# ### <font color="brown">GROUP BY ATTRIBUTES & METHODS

# %% [markdown]
# #### 1. len
#     It find the total number of groups.

# %%
len(mov.groupby("Genre"))
# Out:
# 14

# %%
mov["Genre"].nunique()
# Out:
# 14

# %% [markdown]
# #### 2. size
#     It find items in each group.
#     It also tell us how many rows go to each group.

# %%
mov.groupby("Genre").size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %% [markdown]
# #### 3. first() / last()
#     It give first/last values of each group.

# %%
gen.first()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                     The Dark Knight          2008      152
# Adventure                     Interstellar          2014      169
# Animation    Sen to Chihiro no kamikakushi          2001      125
# Biography                 Schindler's List          1993      195
# Comedy                        Gisaengchung          2019      132
# Crime                        The Godfather          1972      175
# Drama             The Shawshank Redemption          1994      142
# Family          E.T. the Extra-Terrestrial          1982      115
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                    The Third Man          1949      104
# Horror                              Psycho          1960      109
# Mystery                            Memento          2000      113
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
gen.last()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %% [markdown]
# #### 4. nth
#     It give custom value of each group.

# %%
gen.nth(7)
# Out:
#                        Series_Title Released_Year  Runtime  IMDB_Rating  \
# Genre
# Action                    Star Wars          1977      121          8.6
# Adventure                     Queen          2013      146          8.2
# Animation             Mononoke-hime          1997      134          8.4
# Biography                   Amadeus          1984      160          8.3
# Comedy                       Amélie          2001      122          8.3
# Crime      The Silence of the Lambs          1991      118          8.6
# Drama                      Whiplash          2014      106          8.5
# Horror                    Halloween          1978       91          7.7
# Mystery           The Lady Vanishes          1938       96          7.8
#
#                      Director              Star1  No_of_Votes        Gross  \
# Genre
# Action           George Lucas        Mark Hamill      1231473  322740140.0
# Adventure          Vikas Bahl     Kangana Ranaut        60701    1429534.0
# ...

# %% [markdown]
# #### 5. get_group
#     It give all the values of a particulat group

# %%
# It give all the movies that comes under "Drama" genre.
gen.get_group("Drama")
# Out:
#                         Series_Title Released_Year  Runtime  Genre  \
# 0           The Shawshank Redemption          1994      142  Drama
# 9                         Fight Club          1999      139  Drama
# 11                      Forrest Gump          1994      142  Drama
# 17   One Flew Over the Cuckoo's Nest          1975      133  Drama
# 20                   Soorarai Pottru          2020      153  Drama
# ..                               ...           ...      ...    ...
# 990                     Giù la testa          1971      157  Drama
# 993                           Blowup          1966      111  Drama
# 996                            Giant          1956      201  Drama
# 997            From Here to Eternity          1953      118  Drama
# 998                         Lifeboat          1944       97  Drama
#
#      IMDB_Rating                Director              Star1  No_of_Votes  \
# 0            9.3          Frank Darabont        Tim Robbins      2343110
# ...

# %% [markdown]
# #### 6. Groups
#     It give all the groups in Dictionary

# %%
# Here Key--> Genre Name
# Values--> Index Position / Number inside list 
gen.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %% [markdown]
# #### 7. Describe

# %%
gen.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %% [markdown]
# #### 8. Sample

# %%
gen.sample()
# Out:
#                      Series_Title Released_Year  Runtime      Genre  \
# 784              The Last Samurai          2003      154     Action
# 300                       Ben-Hur          1959      212  Adventure
# 744                The Lego Movie          2014      100  Animation
# 729      The Theory of Everything          2014      123  Biography
# 128                    Chhichhore          2019      143     Comedy
# 584             The Hateful Eight          2015      168      Crime
# 448             In a Lonely Place          1950       94      Drama
# 688    E.T. the Extra-Terrestrial          1982      115     Family
# 568                     Nosferatu          1922       94    Fantasy
# 456            The Maltese Falcon          1941      100  Film-Noir
# 271                     The Thing          1982      109     Horror
# 959                     Dark City          1998      100    Mystery
# 700               Wait Until Dark          1967      108   Thriller
# ...

# %%
gen.sample(2,replace=True)
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 326                                 Baby          2015      159     Action
# 856                      The Dirty Dozen          1967      150     Action
# 576                         Paddington 2          2017      103  Adventure
# 514                        Almost Famous          2000      122  Adventure
# 409               Tenkû no shiro Rapyuta          1986      125  Animation
# 891                        Incredibles 2          2018      118  Animation
# 987                     Midnight Express          1978      121  Biography
# 671                           Awakenings          1990      121  Biography
# 830                         Withnail & I          1987      107     Comedy
# 563                      His Girl Friday          1940       92     Comedy
# 802                         Training Day          2001      122      Crime
# ...

# %% [markdown]
# #### 9. Nunique

# %%
gen.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %% [markdown]
# ### <font color="orange">AGGREGARTION METHOD USES

# %% [markdown]
# #### PASSING IN DICTIONARY

# %%
gen.agg({
    'Runtime':'mean',
        'IMDB_Rating':'mean',
        'No_of_Votes':'sum',
        'Gross':'sum',
        'Metascore':'min'
})
# Out:
#               Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419     72282412  3.263226e+10       33.0
# Adventure  134.111111     7.937500     22576163  9.496922e+09       41.0
# Animation   99.585366     7.930488     21978630  1.463147e+10       61.0
# Biography  136.022727     7.938636     24006844  8.276358e+09       48.0
# Comedy     112.129032     7.901290     27620327  1.566387e+10       45.0
# Crime      126.392523     8.016822     33533615  8.452632e+09       47.0
# Drama      124.737024     7.957439     61367304  3.540997e+10       28.0
# Family     107.500000     7.800000       551221  4.391106e+08       67.0
# Fantasy     85.000000     8.000000       146222  7.827267e+08        NaN
# Film-Noir  104.000000     7.966667       367215  1.259105e+08       94.0
# Horror     102.090909     7.909091      3742556  1.034649e+09       46.0
# Mystery    119.083333     7.975000      4203004  1.256417e+09       52.0
# ...

# %% [markdown]
# #### PASSING LIST

# %%
gen.agg(["min","max","sum","mean"])
# Out:
# C:\Users\mitra\AppData\Local\Temp\ipykernel_27388\3031087277.py:1: FutureWarning: ['Series_Title', 'Released_Year', 'Director', 'Star1'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   gen.agg(["min","max","sum","mean"])
#           Runtime                         IMDB_Rating                         \
#               min  max    sum        mean         min  max     sum      mean
# Genre
# Action         45  321  22196  129.046512         7.6  9.0  1367.3  7.949419
# Adventure      88  228   9656  134.111111         7.6  8.6   571.5  7.937500
# Animation      71  137   8166   99.585366         7.6  8.6   650.3  7.930488
# Biography      93  209  11970  136.022727         7.6  8.9   698.6  7.938636
# Comedy         68  188  17380  112.129032         7.6  8.6  1224.7  7.901290
# Crime          80  229  13524  126.392523         7.6  9.2   857.8  8.016822
# ...

# %% [markdown]
# #### PASSING IN BOTH DICTIONARY & LIST

# %%
gen.agg(
    {
        'Runtime':['min','mean'],
        'IMDB_Rating':'mean',
        'No_of_Votes':['sum','max'],
        'Gross':'sum',
        'Metascore':'min'
    }
)
# Out:
#           Runtime             IMDB_Rating No_of_Votes                  Gross  \
#               min        mean        mean         sum      max           sum
# Genre
# Action         45  129.046512    7.949419    72282412  2303232  3.263226e+10
# Adventure      88  134.111111    7.937500    22576163  1512360  9.496922e+09
# Animation      71   99.585366    7.930488    21978630   999790  1.463147e+10
# Biography      93  136.022727    7.938636    24006844  1213505  8.276358e+09
# Comedy         68  112.129032    7.901290    27620327   939631  1.566387e+10
# Crime          80  126.392523    8.016822    33533615  1826188  8.452632e+09
# Drama          64  124.737024    7.957439    61367304  2343110  3.540997e+10
# Family        100  107.500000    7.800000      551221   372490  4.391106e+08
# Fantasy        76   85.000000    8.000000      146222    88794  7.827267e+08
# Film-Noir     100  104.000000    7.966667      367215   158731  1.259105e+08
# ...

# %%
gb_gen = gb_df.groupby("Gender")

# %%
for x, y in gb_gen:
    print(x)
    print("__________________")
    print()
    print(y)
    print()
    print("********************************************")
    print()
# Out:
# Female
# __________________
#
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# ...

# %% [markdown]
# ## <font color="brown">MULTI COLUMN GROUP BY

# %%
mov
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
# FIND THE HIGHTEST RATED MOVIE OF EACH GENRE.
mov.groupby(["Director","Series_Title"],as_index=False).agg(Hig=("IMDB_Rating","max"))
# Out:
#                 Director                Series_Title  Hig
# 0             Aamir Khan            Taare Zameen Par  8.4
# 1           Aaron Sorkin  The Trial of the Chicago 7  7.8
# 2    Abdellatif Kechiche              La vie d'Adèle  7.7
# 3       Abhishek Chaubey                 Udta Punjab  7.8
# 4        Abhishek Kapoor                 Kai po che!  7.7
# ..                   ...                         ...  ...
# 995       Zaza Urushadze                 Mandariinid  8.2
# 996          Zoya Akhtar                   Gully Boy  8.0
# 997          Zoya Akhtar    Zindagi Na Milegi Dobara  8.1
# 998          Çagan Irmak              Babam ve Oglum  8.3
# 999     Ömer Faruk Sorak                    G.O.R.A.  8.0
#
# [1000 rows x 3 columns]

# %%
# Mulitple Aggregate Functions
mov.groupby(["Director","Series_Title"],as_index=False).agg(["min","max","sum"])
# Out:
#                                                Released_Year              \
#                                                          min   max   sum
# Director            Series_Title
# Aamir Khan          Taare Zameen Par                    2007  2007  2007
# Aaron Sorkin        The Trial of the Chicago 7          2020  2020  2020
# Abdellatif Kechiche La vie d'Adèle                      2013  2013  2013
# Abhishek Chaubey    Udta Punjab                         2016  2016  2016
# Abhishek Kapoor     Kai po che!                         2013  2013  2013
# ...                                                      ...   ...   ...
# Zaza Urushadze      Mandariinid                         2013  2013  2013
# Zoya Akhtar         Gully Boy                           2019  2019  2019
#                     Zindagi Na Milegi Dobara            2011  2011  2011
# Çagan Irmak         Babam ve Oglum                      2005  2005  2005
# ...

# %%
# FIND THE HIGHTEST RATED MOVIE OF EACH GENRE.
