# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### <font color="brown">PIVOT FUNCTION
# - IT CONVERT THE ROW INTO COLUMN.

# %%
df = pd.read_csv("C:\\Users\\mitra\\Desktop\\INNOMATICS(MITRABHANU PANDA)\\Python Class\\Pandas\\Dataset_Pandas\\Data mining dataset\\Pivot _ Pivottable\\pivot_temp.csv")

# %%
df
# Out:
#          Date       City  Temp  Humid
# 0    1-Mar-22  Hyderabad    33     40
# 1    2-Mar-22  Hyderabad    34     44
# 2    3-Mar-22  Hyderabad    35     42
# 3    4-Mar-22  Hyderabad    36     43
# 4    5-Mar-22  Hyderabad    37     40
# 5    6-Mar-22  Hyderabad    38     41
# 6    7-Mar-22  Hyderabad    39     40
# 7    8-Mar-22  Hyderabad    33     44
# 8    9-Mar-22  Hyderabad    34     42
# 9   10-Mar-22  Hyderabad    35     43
# 10   1-Mar-22      Vizag    34     40
# 11   2-Mar-22      Vizag    35     44
# 12   3-Mar-22      Vizag    36     42
# 13   4-Mar-22      Vizag    37     43
# 14   5-Mar-22      Vizag    38     40
# 15   6-Mar-22      Vizag    39     41
# 16   7-Mar-22      Vizag    33     43
# 17   8-Mar-22      Vizag    34     40
# 18   9-Mar-22      Vizag    35     41
# 19  10-Mar-22      Vizag    34     40
# 20   1-Mar-22      Delhi    33     44
# 21   2-Mar-22      Delhi    34     42
# 22   3-Mar-22      Delhi    35     43
# 23   4-Mar-22      Delhi    36     40
# ...

# %%
dfpv=df.pivot(index="Date",columns="City")

# %%
dfpv
# Out:
#              Temp                         Humid
# City      Chennai Delhi Hyderabad Vizag Chennai Delhi Hyderabad Vizag
# Date
# 1-Mar-22       34    33        33    34      43    44        40    40
# 10-Mar-22      34    35        35    34      40    41        43    40
# 2-Mar-22       35    34        34    35      40    42        44    44
# 3-Mar-22       36    35        35    36      41    43        42    42
# 4-Mar-22       37    36        36    37      40    40        43    43
# 5-Mar-22       38    37        37    38      44    44        40    40
# 6-Mar-22       39    38        38    39      42    40        41    41
# 7-Mar-22       33    39        39    33      43    41        40    43
# 8-Mar-22       34    33        33    34      40    43        44    40
# 9-Mar-22       35    34        34    35      44    40        42    41

# %%
df=pd.to_datetime(df["Date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6652\2254887700.py in <module>
# ----> 1 df=pd.to_datetime(df[["Date"]])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1052             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1054         result = _assemble_from_unit_mappings(arg, errors, tz)
#    1055     elif isinstance(arg, Index):
#    1056         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _assemble_from_unit_mappings(arg, errors, tz)
#    1158     if len(req):
#    1159         _required = ",".join(req)
# ...

# %%
df

# %%
dfpv=df.pivot(index="Date",columns="City")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6652\293478162.py in <module>
# ----> 1 dfpv=df.pivot(index="Date",columns="City")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'pivot'

# %%
dfpv
# Out:
# 0    2022-03-01
# 1    2022-03-02
# 2    2022-03-03
# 3    2022-03-04
# 4    2022-03-05
# 5    2022-03-06
# 6    2022-03-07
# 7    2022-03-08
# 8    2022-03-09
# 9    2022-03-10
# 10   2022-03-01
# 11   2022-03-02
# 12   2022-03-03
# 13   2022-03-04
# 14   2022-03-05
# 15   2022-03-06
# 16   2022-03-07
# 17   2022-03-08
# 18   2022-03-09
# 19   2022-03-10
# 20   2022-03-01
# 21   2022-03-02
# 22   2022-03-03
# 23   2022-03-04
# 24   2022-03-05
# 25   2022-03-06
# 26   2022-03-07
# 27   2022-03-08
# 28   2022-03-09
# 29   2022-03-10
# 30   2022-03-01
# 31   2022-03-02
# 32   2022-03-03
# 33   2022-03-04
# 34   2022-03-05
# 35   2022-03-06
# 36   2022-03-07
# 37   2022-03-08
# 38   2022-03-09
# 39   2022-03-10
# Name: Date, dtype: datetime64[ns]

# %%
df.pivot(index="Date",columns="City",values="Humid")
# Out:
# City       Chennai  Delhi  Hyderabad  Vizag
# Date
# 1-Mar-22        43     44         40     40
# 10-Mar-22       40     41         43     40
# 2-Mar-22        40     42         44     44
# 3-Mar-22        41     43         42     42
# 4-Mar-22        40     40         43     43
# 5-Mar-22        44     44         40     40
# 6-Mar-22        42     40         41     41
# 7-Mar-22        43     41         40     43
# 8-Mar-22        40     43         44     40
# 9-Mar-22        44     40         42     41

# %%
df.pivot(index="Date",columns="City",values="Temp")
# Out:
# City       Chennai  Delhi  Hyderabad  Vizag
# Date
# 1-Mar-22        34     33         33     34
# 10-Mar-22       34     35         35     34
# 2-Mar-22        35     34         34     35
# 3-Mar-22        36     35         35     36
# 4-Mar-22        37     36         36     37
# 5-Mar-22        38     37         37     38
# 6-Mar-22        39     38         38     39
# 7-Mar-22        33     39         39     33
# 8-Mar-22        34     33         33     34
# 9-Mar-22        35     34         34     35

# %%
dfpv["Temp"]
# Out:
# City       Chennai  Delhi  Hyderabad  Vizag
# Date
# 1-Mar-22        34     33         33     34
# 10-Mar-22       34     35         35     34
# 2-Mar-22        35     34         34     35
# 3-Mar-22        36     35         35     36
# 4-Mar-22        37     36         36     37
# 5-Mar-22        38     37         37     38
# 6-Mar-22        39     38         38     39
# 7-Mar-22        33     39         39     33
# 8-Mar-22        34     33         33     34
# 9-Mar-22        35     34         34     35

# %%
dfpv["Humid"]
# Out:
# City       Chennai  Delhi  Hyderabad  Vizag
# Date
# 1-Mar-22        43     44         40     40
# 10-Mar-22       40     41         43     40
# 2-Mar-22        40     42         44     44
# 3-Mar-22        41     43         42     42
# 4-Mar-22        40     40         43     43
# 5-Mar-22        44     44         40     40
# 6-Mar-22        42     40         41     41
# 7-Mar-22        43     41         40     43
# 8-Mar-22        40     43         44     40
# 9-Mar-22        44     40         42     41
