# %% [markdown]
# ### <font color="brown">IMPORTING LIBRARY

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### <font color="green">EXTRACTING DATASETS

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ex=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS VECTORIZED STRING OPERATIONS\DATASETS\expense_data.csv")
ex
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
tit=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS VECTORIZED STRING OPERATIONS\DATASETS\titanic.csv")
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## <font color="dark blue">PIVOT TABLE
# - THE PIVOT TABLE TAKES SIMPLE COLUMN-WISE DATA AS INPUT & GROUPS THE ENTIRES INTO A TWO-DIMENSIONAL TABLE THAT PROVIDES A MULTIDIMENSIONAL SUMMARIZATION OF THE DATA.

# %% [markdown]
# - INDEX--> TO WHICH VARIABLE YOU WANT TO DO YOUR ROW/INDEX. (CATEGORICAL/DIMENSION FIELD)
#
# - COLUMNS---> TO WHICH VARIABLE YOU WANT TO DO YOUR COLUMN. (CATEGORICAL/DIMENSION FIELD)
#
# - VALUES---> TO WHICH VARIABLE YOU WANT TO SHOW AS VALUES. (MEASURE/NUMERIC FIELD)
#
# - AGGFUN---> BY DEFAULT "MEAN" YOU CAN CONVERT TO (SUM,STD,COUNT)
#
# - MARGIN--> IN GIVE TOTAL/SUM OF VALUES ==> (True)
#
# - DROPNA--> IT DELETE THE "NAN".
#
# - FILL_VALUE---> IT FILL THE VALUE THAT YOU PROVIDE TO "NAN" PLACES.
#
# - MARGIN_NAME--> BY DEFAULT "ALL". YOU CAN CHANGE IT.
#
# - SORT--> BY DEFAULT "TRUE". IF YOU CHANGE IT TO "FALSE" THEN THE VALUES SORT INTO DESCENDING ORDER.

# %%
# IT GIVE EVERY COLUMN WISE ANALYSIS
df.pivot_table(index="sex",columns="smoker")
# Out:
#             size                 tip           total_bill
# smoker       Yes        No       Yes        No        Yes         No
# sex
# Male    2.500000  2.711340  3.051167  3.113402  22.284500  19.791237
# Female  2.242424  2.592593  2.931515  2.773519  17.977879  18.105185

# %%
# SEX & SMOKER WISE AVERGAE TOTAL_BIL
df.pivot_table(index="sex",columns="smoker",values="total_bill")
# Out:
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
# SEX & SMOKER WISE TOTAL_BIL
df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="sum")
# Out:
# smoker      Yes       No
# sex
# Male    1337.07  1919.75
# Female   593.27   977.68

# %%
# SEX,SMOKER & DAY,TIME WISE AVERAGE TOTAL BIIL
df.pivot_table(index=["sex","smoker"],columns=["day","time"],values="total_bill")
# Out:
# day                 Thur               Fri                Sat        Sun
# time               Lunch Dinner      Lunch  Dinner     Dinner     Dinner
# sex    smoker
# Male   Yes     19.171000    NaN  11.386667  25.892  21.837778  26.141333
#        No      18.486500    NaN        NaN  17.475  19.929063  20.403256
# Female Yes     19.218571    NaN  13.260000  12.200  20.266667  16.540000
#        No      15.899167  18.78  15.980000  22.750  19.003846  20.824286

# %%
# SEX,SMOKER & DAY,TIME WISE AVERAGE MAX BILL & AVERAGE SIZE & TOTAL TIP
df.pivot_table(index=["sex","smoker"],columns=["day","time"],aggfunc={"size":"mean","tip":"sum","total_bill":"max"})
# Out:
#                    size                                                tip  \
# day                Thur              Fri              Sat       Sun   Thur
# time              Lunch Dinner     Lunch Dinner    Dinner    Dinner  Lunch
# sex    smoker
# Male   Yes     2.300000    NaN  1.666667    2.4  2.629630  2.600000  30.58
#        No      2.500000    NaN       NaN    2.0  2.656250  2.883721  58.83
# Female Yes     2.428571    NaN  2.000000    2.0  2.200000  2.500000  20.93
#        No      2.500000    2.0  3.000000    2.0  2.307692  3.071429  58.49
#
#                                                               total_bill  \
# day                    Fri          Sat           Sun               Thur
# time          Dinner Lunch Dinner Lunch  Dinner Lunch  Dinner      Lunch
# sex    smoker
# Male   Yes       0.0  5.70  16.23   0.0   77.74   0.0   52.82      32.68
#        No        0.0  0.00   5.00   0.0  104.21   0.0  133.96      41.19
# ...

# %%
# SEX & SMKOER WISE TOTAL BILL WITH TOTAL OF VALUES
df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="sum",margins=True)
# Out:
# smoker      Yes       No      All
# sex
# Male    1337.07  1919.75  3256.82
# Female   593.27   977.68  1570.95
# All     1930.34  2897.43  4827.77

# %%
# NAMING THE MARGIN
df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="sum",margins=True,margins_name="Total")
# Out:
# smoker      Yes       No    Total
# sex
# Male    1337.07  1919.75  3256.82
# Female   593.27   977.68  1570.95
# Total   1930.34  2897.43  4827.77

# %%
# SORT IT
df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="sum",margins=True,margins_name="Total",sort=False)
# Out:
# smoker       No      Yes    Total
# sex
# Female   977.68   593.27  1570.95
# Male    1919.75  1337.07  3256.82
# Total   2897.43  1930.34  4827.77

# %% [markdown]
# ### <font color="brown">PLOTTING GRAPHS

# %%
ex
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
ex["Category"].value_counts()
# Out:
# Food                156
# Other                60
# Transportation       31
# Apparel               7
# Household             6
# Allowance             6
# Social Life           5
# Education             1
# Salary                1
# Self-development      1
# Beauty                1
# Gift                  1
# Petty cash            1
# Name: Category, dtype: int64

# %%
ex['Date'] = pd.to_datetime(ex['Date'])

# %%
ex['month'] = ex['Date'].dt.month_name()

# %%
ex
# Out:
#                    Date               Account        Category  Subcategory  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1   2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2   2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4   2022-03-01 18:22:00  CUB - online payment            Food          NaN
# ..                  ...                   ...             ...          ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 273 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation          NaN
# 275 2021-11-21 15:50:00  CUB - online payment            Food          NaN
# 276 2021-11-21 13:30:00  CUB - online payment           Other          NaN
#
# ...

# %%
ex.pivot_table(index="month",columns="Category",values="INR",fill_value=0)
# Out:
# Category  Allowance  Apparel  Beauty  Education        Food  Gift  Household  \
# month
# December       2750      518     196          0  112.995088     0       4800
# February          0      399       0          0  214.609615     0        702
# January        1000        0       0       1400  207.102500     0       4580
# March             0        0       0          0   65.000000     0          0
# November       2000        0       0          0  122.092308   115          0
#
# Category        Other  Petty cash  Salary  Self-development  Social Life  \
# month
# December   137.692308           0       0               400       256.86
# February  2000.000000           0       0                 0       900.00
# January    399.333333           0    8000                 0       200.00
# March      300.000000           0       0                 0         0.00
# November  2000.000000           3       0                 0         0.00
#
# Category  Transportation
# month
# ...

# %%
ex.pivot_table(index="month",columns="Category",values="INR",fill_value=0).plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
ex.pivot_table(index="month",columns="Income/Expense",values="INR")
# Out:
# Income/Expense     Expense       Income
# month
# December        212.135584  1025.833333
# February        372.180208  3033.333333
# January         299.703043   853.956522
# March           105.000000   300.000000
# November        113.137500  1334.333333

# %%
ex.pivot_table(index="month",columns="Income/Expense",values="INR").plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
ex.pivot_table(index="month",columns="Account",values="INR")
# Out:
# Account   CUB - online payment     Cash
# month
# December            312.769545  1120.72
# February            667.863889      NaN
# January             438.266413      NaN
# March               160.714286      NaN
# November            217.811429      NaN

# %%
ex.pivot_table(index="month",columns="Account",values="INR").plot()
# Out:
# <AxesSubplot:xlabel='month'>
