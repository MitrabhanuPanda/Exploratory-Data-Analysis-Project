# %% [markdown]
# ## <font color="brown">IMPORTING LIBRARY

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### <font color="green">EXTRACTIONG DATASETS

# %%
cor=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS JOINING\Datasets\courses.csv")

# %%
cor
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
std=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS JOINING\Datasets\students.csv")

# %%
std
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
nov=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS JOINING\Datasets\reg-month1.csv")

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
dec=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS JOINING\Datasets\reg-month2.csv")

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
mat=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS JOINING\Datasets\matches.csv")

# %%
mat
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
deli=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS JOINING\Datasets\deliveries.csv")

# %%
deli
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %% [markdown]
# ### <font color="brown">CONCAT
#     It Join two datasets Vertically / Horizonatlly.

# %% [markdown]
# ![merging_concat_basic.png](attachment:merging_concat_basic.png)

# %% [markdown]
# ![introduction-to-concatenation-and-reshaping-of-dataframes.webp](attachment:introduction-to-concatenation-and-reshaping-of-dataframes.webp)

# %%
pd.concat([nov,dec])
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# ...

# %% [markdown]
# #### Ignore Index

# %%
# It give New indexes.
pd.concat([nov,dec],ignore_index=True)
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
col1=pd.DataFrame({
    "red" : [2,3,4],
    "green" : [8,9,10]
})

# %%
col1
# Out:
#    red  green
# 0    2      8
# 1    3      9
# 2    4     10

# %%
col2=pd.DataFrame({
    "green" : [2,4,6,7],
    "blue" : [5,6,7,8]
})

# %%
col2
# Out:
#    green  blue
# 0      2     5
# 1      4     6
# 2      6     7
# 3      7     8

# %%
col3=pd.DataFrame({
    "orange" : [2,4,6,7],
    "grey" : [5,6,7,8]
})

# %%
col3
# Out:
#    orange  grey
# 0       2     5
# 1       4     6
# 2       6     7
# 3       7     8

# %%
# Green Column is common both dataset
# We do Column wise Joining
pd.concat([col1,col2],axis=1)
# Out:
#    red  green  green  blue
# 0  2.0    8.0      2     5
# 1  3.0    9.0      4     6
# 2  4.0   10.0      6     7
# 3  NaN    NaN      7     8

# %%
pd.concat([col1,col2])
# Out:
#    red  green  blue
# 0  2.0      8   NaN
# 1  3.0      9   NaN
# 2  4.0     10   NaN
# 0  NaN      2   5.0
# 1  NaN      4   6.0
# 2  NaN      6   7.0
# 3  NaN      7   8.0

# %%
# No column is Common
pd.concat([col1,col3])
# Out:
#    red  green  orange  grey
# 0  2.0    8.0     NaN   NaN
# 1  3.0    9.0     NaN   NaN
# 2  4.0   10.0     NaN   NaN
# 0  NaN    NaN     2.0   5.0
# 1  NaN    NaN     4.0   6.0
# 2  NaN    NaN     6.0   7.0
# 3  NaN    NaN     7.0   8.0

# %%
pd.concat([col1,col3],axis=1)
# Out:
#    red  green  orange  grey
# 0  2.0    8.0       2     5
# 1  3.0    9.0       4     6
# 2  4.0   10.0       6     7
# 3  NaN    NaN       7     8

# %% [markdown]
# ### <font color="brown">MULTI-INDEX DATAFRAME

# %%
mul=pd.concat([nov,dec],keys=["Nov","Dec"])
mul
# Out:
#         student_id  course_id
# Nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# Dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
# ...

# %% [markdown]
# #### FETCHING FIRST INDEX FROM THIS MULTI-INDEX DATAFRAME

# %%
mul.loc["Dec"]
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %% [markdown]
# #### FETCHING ITEMS FROM MULTI-INDEX DATAFRAME

# %%
mul.loc[("Nov",4)]
# Out:
# student_id    16
# course_id      9
# Name: (Nov, 4), dtype: int64

# %%
mul.loc[("Nov",0)]
# Out:
# student_id    23
# course_id      1
# Name: (Nov, 0), dtype: int64

# %% [markdown]
# ## <font color="brown">APPEND

# %%
nov.append(dec,ignore_index=True)
# Out:
# C:\Users\mitra\AppData\Local\Temp\ipykernel_21092\3584171061.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nov.append(dec,ignore_index=True)
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# ...

# %% [markdown]
# ## <font color="brown">JOIN--> MERGE
#     If you have one column common in both Datasets

# %% [markdown]
# #### INNER JOIN

# %% [markdown]
# ![Inner%20Join.png](attachment:Inner%20Join.png)

# %%
pd.merge(std,nov,on="student_id",how="inner")
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            3      Parveen Bhalla        3          3
# 3            7        Tarun Thaker        9          8
# 4            7        Tarun Thaker        9         10
# 5           11  David Mukhopadhyay       20          7
# 6           13      Munni Varghese       24          3
# 7           15           Preet Sha       16          5
# 8           15           Preet Sha       16          1
# 9           16        Elias Dodiya       25          9
# 10          16        Elias Dodiya       25          5
# 11          17        Yasmin Palan        7          7
# 12          18     Fardeen Mahabir       13          6
# 13          18     Fardeen Mahabir       13          1
# 14          19        Qabeel Raman       12          4
# 15          19        Qabeel Raman       12          2
# ...

# %% [markdown]
# #### LEFT JOIN

# %% [markdown]
# ![Left%20Join.png](attachment:Left%20Join.png)

# %%
cor.merge(nov,how="left",on="course_id")
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           2               sql   3499        19.0
# 7           3     data analysis   4999        22.0
# 8           3     data analysis   4999        13.0
# 9           3     data analysis   4999        23.0
# 10          3     data analysis   4999         3.0
# 11          4  machine learning   9999        23.0
# 12          4  machine learning   9999        19.0
# 13          4  machine learning   9999        24.0
# 14          5           tableau   2499        15.0
# 15          5           tableau   2499        16.0
# 16          6          power bi   1899        18.0
# ...

# %% [markdown]
# #### LEFT NULL JOIN

# %% [markdown]
# ![Left%20Null%20Join.png](attachment:Left%20Null%20Join.png)

# %%
dfff=cor.merge(nov,how="left",on="course_id")
lef_nul_df=dfff[dfff["student_id"].isnull()]
lef_nul_df
# Out:
#     course_id course_name  price  student_id
# 25         11       Numpy    699         NaN
# 26         12         C++   1299         NaN

# %% [markdown]
# #### RIGHT JOIN

# %% [markdown]
# ![Right%20Join.png](attachment:Right%20Join.png)

# %%
df_rgh=cor.merge(nov,how="right",on="course_id")
df_rgh
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499          23
# 1           5           tableau   2499          15
# 2           6          power bi   1899          18
# 3           4  machine learning   9999          23
# 4           9            plotly    699          16
# 5           1            python   2499          18
# 6           1            python   2499           1
# 7           8            pandas   1099           7
# 8           3     data analysis   4999          22
# 9           1            python   2499          15
# 10          4  machine learning   9999          19
# 11          6          power bi   1899           1
# 12         10           pyspark   2499           7
# 13          7          ms sxcel   1599          11
# 14          3     data analysis   4999          13
# 15          4  machine learning   9999          24
# 16          1            python   2499          21
# ...

# %% [markdown]
# #### RIGHT NULL JOIN

# %% [markdown]
# ![Right%20Null%20Join.png](attachment:Right%20Null%20Join.png)

# %%
righ_nul_df=df_rgh[df_rgh["course_name"].isnull()]
righ_nul_df
# Out:
# Empty DataFrame
# Columns: [course_id, course_name, price, student_id]
# Index: []

# %% [markdown]
# #### FULL OUTER JOIN

# %% [markdown]
# ![Full%20Outer%20Join.png](attachment:Full%20Outer%20Join.png)

# %%
ful_df=cor.merge(nov,how="outer",on="course_id")
ful_df
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           2               sql   3499        19.0
# 7           3     data analysis   4999        22.0
# 8           3     data analysis   4999        13.0
# 9           3     data analysis   4999        23.0
# 10          3     data analysis   4999         3.0
# 11          4  machine learning   9999        23.0
# 12          4  machine learning   9999        19.0
# 13          4  machine learning   9999        24.0
# 14          5           tableau   2499        15.0
# 15          5           tableau   2499        16.0
# 16          6          power bi   1899        18.0
# ...

# %% [markdown]
# #### OUTER JOIN

# %% [markdown]
# ![Outer%20Join.png](attachment:Outer%20Join.png)

# %%
out_df=ful_df[(ful_df["course_name"].isnull()) | (ful_df["student_id"].isnull())]
out_df
# Out:
#     course_id course_name  price  student_id
# 25         11       Numpy    699         NaN
# 26         12         C++   1299         NaN
