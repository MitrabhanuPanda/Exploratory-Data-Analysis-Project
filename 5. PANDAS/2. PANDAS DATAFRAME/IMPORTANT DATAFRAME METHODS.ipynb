# %% [markdown]
# ### <font color="brown">IMPORTING LIBRARY

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### <font color="violet">EXTRCATING DATASETS

# %%
of1=pd.read_csv("C:/Users/mitra/Desktop/INNOMATICS(MITRABHANU PANDA)/Python Class/Pandas/Dataset_Pandas/hyd_outliers.csv",na_values=[4450,1111,9999])

# %%
of1
# Out:
#           Date  Temp
# 0   21-01-2022  30.0
# 1   22-01-2022  28.0
# 2   23-01-2022   NaN
# 3   24-01-2022  29.0
# 4   25-01-2022   NaN
# 5   26-01-2022  32.0
# 6   27-01-2022  34.0
# 7   28-01-2022 -50.0
# 8   29-01-2022  36.0
# 9   30-01-2022  38.0
# 10  31-01-2022   NaN
# 11  13-02-2022  25.0
# 12  14-02-2022   NaN
# 13  15-02-2022  22.0
# 14  16-02-2022  21.0
# 15  17-02-2022   NaN
# 16  18-02-2022  22.0
# 17  19-02-2022   NaN
# 18  20-02-2022  20.0

# %%
sf1=pd.read_csv("C:/Users/mitra/Desktop/INNOMATICS(MITRABHANU PANDA)/Python Class/Pandas/Dataset_Pandas/std_multinan.csv")

# %%
sf1
# Out:
#   Name  English  Science
# 0  AAA     50.0      40.0
# 1  BBB      NaN      45.0
# 2  CCC      NaN      58.0
# 3  DDD      NaN      90.0
# 4  EEE      NaN      55.0
# 5  NaN     40.0       NaN
# 6  GGG     45.0       NaN
# 7  NaN     58.0       NaN
# 8  KKK     90.0      90.0

# %%
sf2=pd.read_csv("C:/Users/mitra/Desktop/INNOMATICS(MITRABHANU PANDA)/Python Class/Pandas/Dataset_Pandas/Interpolate/std_interp.csv")

# %%
sf2
# Out:
#   Stdname  StdClass   Age
# 0     AAA        10  15.0
# 1     BBB        11   NaN
# 2     CCC        12  18.0
# 3     DDD        10   NaN
# 4     EEE        11  16.0
# 5     FFF        12  18.0
# 6     GGG        11  16.0
# 7     HHH        10  15.0
# 8     JJJ        12   NaN
# 9     KKK        10   NaN

# %%
dfstore = pd.read_csv(r"C:\Users\mitra\Desktop\INNOMATICS(MITRABHANU PANDA)\Python Class\Pandas\Dataset_Pandas\Functions\cloths_store_sale.csv")

# %%
dfstore
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 0          1          Regular      1      39.50          Discover    Male
# 1          2      Promotional      1     102.40  Proprietary Card  Female
# 2          3          Regular      1      22.50  Proprietary Card  Female
# 3          4      Promotional      5     100.40  Proprietary Card  Female
# 4          5          Regular      2      54.00        MasterCard  Female
# ..       ...              ...    ...        ...               ...     ...
# 95        96          Regular      1      39.50        MasterCard  Female
# 96        97      Promotional      9     253.00  Proprietary Card  Female
# 97        98      Promotional     10     287.59  Proprietary Card  Female
# 98        99      Promotional      2      47.60  Proprietary Card  Female
# 99       100      Promotional      1      28.44  Proprietary Card  Female
#
#    Marital Status  Age
# 0         Married   32
# 1         Married   36
# ...

# %%
ipl=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS DATAFRAME\datasets\ipl-matches.csv")

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
mv=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS DATAFRAME\datasets\movies.csv")

# %%
mv
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
dia=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS DATAFRAME\datasets\diabetes.csv")

# %%
dia
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
batip=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS DATAFRAME\datasets\batsman_runs_ipl.csv")

# %%
batip
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
std=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS DATAFRAME\datasets\std_data1.csv")

# %%
std
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
std_mrk={
    "iq":[100,70,80,70,40],
    "marks":[30,60,50,60,70],
    "package":[10,9,8,9,6]
}
std_mrk
# Out:
# {'iq': [100, 70, 80, 70, 40],
#  'marks': [30, 60, 50, 60, 70],
#  'package': [10, 9, 8, 9, 6]}

# %%
std_mrk=pd.DataFrame(std_mrk)

# %%
std_mrk
# Out:
#     iq  marks  package
# 0  100     30       10
# 1   70     60        9
# 2   80     50        8
# 3   70     60        9
# 4   40     70        6

# %% [markdown]
# ## <font color="brown">METHODS

# %% [markdown]
# #### 1. VALUE COUNTS (SERIES & DATAFRAME)
#     It give all the unique values & count of the number of the Occurences of the unique values.

# %%
std_mrk.value_counts()
# Out:
# iq   marks  package
# 70   60     9          2
# 40   70     6          1
# 80   50     8          1
# 100  30     10         1
# dtype: int64

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# FIND HOW MANY PLAYER OF THE MATCH IS GOT BY PLAYERS IN FINALS & QUATERS.
ipl[~ipl["MatchNumber"].str.isdigit()]["Player_of_Match"].value_counts()
# Out:
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# KH Pandya            1
# ...

# %%
# TOSS DECISION PLOT
ipl["TossDecision"].value_counts()
# Out:
# field    599
# bat      351
# Name: TossDecision, dtype: int64

# %%
ipl["TossDecision"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='TossDecision'>

# %%
# HOW MANY MATCHES EACH TEAM HAS PLAYED
(ipl["Team1"].value_counts()+ipl["Team2"].value_counts())
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# dtype: int64

# %%
(ipl["Team1"].value_counts()+ipl["Team2"].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %% [markdown]
# #### 2. SORT VALUES (SERIES & DATAFRAME)
#     (ascending , na_position ,  inplace , multiple columns)
#
#     It sort the values in Ascending / Descending Orders.

# %%
x = pd.Series([12,14,1,56,89])
x
# Out:
# 0    12
# 1    14
# 2     1
# 3    56
# 4    89
# dtype: int64

# %%
x.sort_values() # Ascending order
# Out:
# 2     1
# 0    12
# 1    14
# 3    56
# 4    89
# dtype: int64

# %%
x.sort_values(ascending=False)  # Descending Order
# Out:
# 4    89
# 3    56
# 1    14
# 0    12
# 2     1
# dtype: int64

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
# Single Column Sorting with Ascending Order
mv.sort_values(by="title_x")
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# Single Column Sorting with descending Order
mv.sort_values(by="title_x",ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# Multiple Column Sorting
mv.sort_values(by=["year_of_release","title_x"])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
mv.sort_values(by=["year_of_release","title_x"],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# This dataset having missing values
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
# All missing values go to Last
students.sort_values(by="name")
# Out:
#          name college branch   cgpa  package
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
# All missing values go to First
students.sort_values(by="name",na_position="first")
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %% [markdown]
# #### 3. RANK (SERIES)

# %%
batip
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
batip["Ranking"]=batip["batsman_run"].rank(ascending=False)
batip.sort_values(by="Ranking")
# Out:
#            batter  batsman_run  Ranking
# 569       V Kohli         6634      1.0
# 462      S Dhawan         6244      2.0
# 130     DA Warner         5883      3.0
# 430     RG Sharma         5881      4.0
# 493      SK Raina         5536      5.0
# ..            ...          ...      ...
# 512   SS Cottrell            0    594.0
# 466     S Kaushik            0    594.0
# 203     IC Pandey            0    594.0
# 467       S Ladda            0    594.0
# 468  S Lamichhane            0    594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# #### 4. SORT INDEX (SERIES & DATAFRAME)
#     It sort the Indexes

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks_series.sort_index() # It comes in Aplhabetic Order
# Out:
# english     57
# hindi      100
# maths       67
# science     89
# dtype: int64

# %%
mv.sort_index(ascending=False) # It sort in Descending Order
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# #### 5. SET INDEX (DATAFRAME)
#     It convert the column into Index

# %%
std
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
std.set_index("SNAME",inplace=True)

# %%
std
# Out:
#        SCLASS   ENGLISH  COMPUTER  SCIENCE
# SNAME
# A           10       67        66       66
# B           12       87        56       65
# C           11       66        89       63
# D           10       56        88       66
# E           10       89        90       56
# F            9       88        85       89
# G           12       90        83       88
# H           11       79        88       90

# %%
std
# Out:
#        SCLASS   ENGLISH  COMPUTER  SCIENCE
# SNAME
# A           10       67        66       66
# B           12       87        56       65
# C           11       66        89       63
# D           10       56        88       66
# E           10       89        90       56
# F            9       88        85       89
# G           12       90        83       88
# H           11       79        88       90

# %% [markdown]
# #### 6. RESET INDEX (DATAFRAME & SERIES)

# %%
std.reset_index(inplace=True)

# %%
std
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
# RESET INDEX in SERIES
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# SERIES CONVERT TO DATAFRAME
marks_series.reset_index()
# Out:
#      index    0
# 0    maths   67
# 1  english   57
# 2  science   89
# 3    hindi  100

# %% [markdown]
# #### 7. UNIQUE (SERIES)
#     It give the Unique values in the Series.

# %%
temp1=pd.Series([1,1,1,2,2,2,3,4,5,2,3,3,4,5,6,7,8])
temp1
# Out:
# 0     1
# 1     1
# 2     1
# 3     2
# 4     2
# 5     2
# 6     3
# 7     4
# 8     5
# 9     2
# 10    3
# 11    3
# 12    4
# 13    5
# 14    6
# 15    7
# 16    8
# dtype: int64

# %%
temp1.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8], dtype=int64)

# %%
temp=pd.Series([1,1,1,2,2,2,3,4,5,2,3,3,4,5,6,7,8,np.nan,np.nan,np.nan])
temp
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     2.0
# 4     2.0
# 5     2.0
# 6     3.0
# 7     4.0
# 8     5.0
# 9     2.0
# 10    3.0
# 11    3.0
# 12    4.0
# 13    5.0
# 14    6.0
# 15    7.0
# 16    8.0
# 17    NaN
# 18    NaN
# 19    NaN
# dtype: float64

# %%
temp.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6.,  7.,  8., nan])

# %%
len(temp.unique())
# Out:
# 9

# %% [markdown]
# #### 8. NUNIQUE (DATAFRAME & SERIES)
#     Does not count "NaN".
#     If "NaN" is in the Dataset then first Drop the "NaN".

# %%
temp1
# Out:
# 0     1
# 1     1
# 2     1
# 3     2
# 4     2
# 5     2
# 6     3
# 7     4
# 8     5
# 9     2
# 10    3
# 11    3
# 12    4
# 13    5
# 14    6
# 15    7
# 16    8
# dtype: int64

# %%
temp1.nunique()
# Out:
# 8

# %%
temp.nunique()
# Out:
# 8

# %% [markdown]
# #### 9. ISNULL (DATAFRAME & SERIES)
#     It give "nan" present inside the dataset

# %%
# Isnull in Dataframe
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %%
# Isnull in Series
students["name"].isnull() # It give Boolean Series
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
students["name"][students["name"].isnull()] # It give the index Position of "NaN"
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: object

# %% [markdown]
# #### 10. NOTNULL (SERIES & DATAFRAME)
#     It is opposite of Isnull.

# %%
# Notnull in Dataframe
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False   False  False    False
# 4   True    False    True   True     True
# 5  False     True    True   True     True
# 6   True     True    True   True     True
# 7  False    False    True   True     True
# 8   True    False    True   True    False
# 9  False     True   False  False    False

# %%
# Notnull in Series
students["name"].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# Name: name, dtype: bool

# %%
students["name"][students["name"].notnull()]
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %% [markdown]
# #### 11. HASNANS (SERIES)
#     It give a Summary of the Nan present inside a dataset in True/False

# %%
students["name"].hasnans
# Out:
# True

# %% [markdown]
# #### 12. DROPNA (DATAFRAME & SERIES)
#     It delete the entire row if "NaN" present inside the row.

# %%
# Dropna in Dataframe
students.dropna()
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
# Dropna is Series
students["name"].dropna()
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %%
# "How" Parameter:

students.dropna(how="any")
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
# It means if the "NaN" present inside the entire rows.
students.dropna(how="all")
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
# "Subset" Parameter:

# It drop basis on column
students.dropna(subset=["name"])
# Out:
#          name college branch  cgpa  package
# 0      nitish     bit    eee  6.66      4.0
# 1       ankit     iit     it  8.25      5.0
# 2      rupesh     vit    cse  6.41      6.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 8      aditya     NaN    bio  7.40      NaN

# %%
# It drop basic on multiple columns
students.dropna(subset=["name","college"])
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %% [markdown]
# #### 13. FILLNA (DATAFRAME & SERIES)
#     It replace "NaN" to some Values

# %%
# Fillna in Series
students["name"].fillna("Unknown")
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3       Unknown
# 4    mrityunjay
# 5       Unknown
# 6       rishabh
# 7       Unknown
# 8        aditya
# 9       Unknown
# Name: name, dtype: object

# %%
# Fillna in Dataframe
students.fillna(0)
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3           0       0      0   0.00      0.0
# 4  mrityunjay       0     me   5.60      6.0
# 5           0    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7           0       0    cse  10.00      9.0
# 8      aditya       0    bio   7.40      0.0
# 9           0     git      0   0.00      0.0

# %%
# "Method" Parameter:
# Forward Fill

students["name"].fillna(method="ffill")
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3        rupesh
# 4    mrityunjay
# 5    mrityunjay
# 6       rishabh
# 7       rishabh
# 8        aditya
# 9        aditya
# Name: name, dtype: object

# %%
# Backward Fill

students["name"].fillna(method="bfill")
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3    mrityunjay
# 4    mrityunjay
# 5       rishabh
# 6       rishabh
# 7        aditya
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %% [markdown]
# #### 14. DROP DUPLICATES (DATAFRAME & SERIES)
#     It delete all the Duplicates Values.

# %%
std_mrk.duplicated().sum() # It show how many duplicate value are in the Datasets
# Out:
# 1

# %%
std_mrk.drop_duplicates() # It delete the Duplicate Values
# Out:
#     iq  marks  package
# 0  100     30       10
# 1   70     60        9
# 2   80     50        8
# 4   40     70        6

# %%
std_mrk.drop_duplicates(keep="last") # It delete first duplicates row i.e. 1.
# Out:
#     iq  marks  package
# 0  100     30       10
# 2   80     50        8
# 3   70     60        9
# 4   40     70        6

# %%
# Duplicated in Series
temp1.duplicated().sum()
# Out:
# 9

# %%
# Drop_Duplicates in Series
temp1.drop_duplicates()
# Out:
# 0     1
# 3     2
# 6     3
# 7     4
# 8     5
# 14    6
# 15    7
# 16    8
# dtype: int64

# %% [markdown]
# ##### <font color="green">SCENARIO FOR DROP DUPLICATES

# %%
# find the last match played by virat kohli in Delhi
ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
def did_kohli_play(players_list):
      return 'V Kohli' in players_list

# %%
ipl['did_kohli_play'] = ipl['all_players'].apply(did_kohli_play)
ipl[(ipl['City'] == 'Delhi') & (ipl['did_kohli_play'] == True)].drop_duplicates(subset=['City','did_kohli_play'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_kohli_play
# 208           True
#
# [1 rows x 22 columns]

# %% [markdown]
# #### 15. DROP (DATAFRAME & SERIES)
#     It drop rows & also columns.

# %%
# Drop in Series
temp = pd.Series([10,2,3,16,45,78,10])
temp
# Out:
# 0    10
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# 6    10
# dtype: int64

# %%
# Only One Row
temp.drop(index=0)
# Out:
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# 6    10
# dtype: int64

# %%
# Multiple Rows
temp.drop(index=[0,1,2])
# Out:
# 3    16
# 4    45
# 5    78
# 6    10
# dtype: int64

# %%
# Drop in DataFrame
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
# Only One Column
students.drop(columns="branch")
# Out:
#          name college   cgpa  package
# 0      nitish     bit   6.66      4.0
# 1       ankit     iit   8.25      5.0
# 2      rupesh     vit   6.41      6.0
# 3         NaN     NaN    NaN      NaN
# 4  mrityunjay     NaN   5.60      6.0
# 5         NaN    vlsi   9.00      7.0
# 6     rishabh    ssit   7.40      8.0
# 7         NaN     NaN  10.00      9.0
# 8      aditya     NaN   7.40      NaN
# 9         NaN     git    NaN      NaN

# %%
# Multiple Columns
students.drop(columns=["branch","cgpa"])
# Out:
#          name college  package
# 0      nitish     bit      4.0
# 1       ankit     iit      5.0
# 2      rupesh     vit      6.0
# 3         NaN     NaN      NaN
# 4  mrityunjay     NaN      6.0
# 5         NaN    vlsi      7.0
# 6     rishabh    ssit      8.0
# 7         NaN     NaN      9.0
# 8      aditya     NaN      NaN
# 9         NaN     git      NaN

# %% [markdown]
# #### 16. APPLY (DATAFRAME & SERIES)

# %%
# Apply in Series
temp = pd.Series([10,20,30,40,50])
temp
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
temp.apply(lambda x : x*10)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
# Apply in DataFrame
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def euclidean(row):
      pt_A = row['1st point']
      pt_B = row['2nd point']

      return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['distance'] = points_df.apply(euclidean,axis=1)
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000

# %% [markdown]
# #### 17. INTERPOLATE
# - IT IS USED FOR FILL THE "NAN" VALUES.

# %%
sf1["English"].interpolate()
# Out:
# 0    50.0
# 1    48.0
# 2    46.0
# 3    44.0
# 4    42.0
# 5    40.0
# 6    45.0
# 7    58.0
# 8    90.0
# Name: English, dtype: float64

# %% [markdown]
# ##### METHOD="nearest" ---> II TAKE THE NEAREST VALUE TO FILL "NaN".

# %%
sf1["English"].interpolate(method="nearest")
# Out:
# 0    50.0
# 1    50.0
# 2    50.0
# 3    40.0
# 4    40.0
# 5    40.0
# 6    45.0
# 7    58.0
# 8    90.0
# Name: English, dtype: float64

# %%
sf2["Age"].interpolate(method="linear")
# Out:
# 0    15.0
# 1    16.5
# 2    18.0
# 3    17.0
# 4    16.0
# 5    18.0
# 6    16.0
# 7    15.0
# 8    15.0
# 9    15.0
# Name: Age, dtype: float64

# %% [markdown]
# #### 18.QUERY

# %%
dfstore
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 0          1          Regular      1      39.50          Discover    Male
# 1          2      Promotional      1     102.40  Proprietary Card  Female
# 2          3          Regular      1      22.50  Proprietary Card  Female
# 3          4      Promotional      5     100.40  Proprietary Card  Female
# 4          5          Regular      2      54.00        MasterCard  Female
# ..       ...              ...    ...        ...               ...     ...
# 95        96          Regular      1      39.50        MasterCard  Female
# 96        97      Promotional      9     253.00  Proprietary Card  Female
# 97        98      Promotional     10     287.59  Proprietary Card  Female
# 98        99      Promotional      2      47.60  Proprietary Card  Female
# 99       100      Promotional      1      28.44  Proprietary Card  Female
#
#    Marital Status  Age
# 0         Married   32
# 1         Married   36
# ...

# %%
dfstore.query(" Gender == 'Male'  ")
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment Gender  \
# 0          1          Regular      1       39.5          Discover   Male
# 14        15          Regular      1       49.5              Visa   Male
# 15        16      Promotional      2       71.4  Proprietary Card   Male
# 24        25      Promotional      2       39.5              Visa   Male
# 35        36          Regular      1       29.5        MasterCard   Male
# 51        52      Promotional      5      118.8  Proprietary Card   Male
# 68        69      Promotional      2       47.2  Proprietary Card   Male
#
#    Marital Status  Age
# 0         Married   32
# 14         Single   24
# 15         Single   36
# 24        Married   48
# 35         Single   36
# 51        Married   68
# 68        Married   46

# %%
dfstore.query("Age == 30")
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 6          7      Promotional      2      78.00  Proprietary Card  Female
# 47        48      Promotional      3      63.64  Proprietary Card  Female
# 61        62      Promotional      3      59.91  Proprietary Card  Female
# 70        71      Promotional      5     155.32  Proprietary Card  Female
# 81        82      Promotional      6      53.20  Proprietary Card  Female
# 93        94      Promotional     17     229.50  Proprietary Card  Female
# 96        97      Promotional      9     253.00  Proprietary Card  Female
# 98        99      Promotional      2      47.60  Proprietary Card  Female
#
#    Marital Status  Age
# 6         Married   30
# 47        Married   30
# 61         Single   30
# 70        Married   30
# 81         Single   30
# 93        Married   30
# 96        Married   30
# 98        Married   30

# %%
dfstore.query("Age == 46")
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 8          9      Promotional      2      56.52  Proprietary Card  Female
# 13        14      Promotional      2      64.50              Visa  Female
# 41        42      Promotional      4      19.50              Visa  Female
# 46        47          Regular      1      25.00        MasterCard  Female
# 49        50      Promotional      9     145.20        MasterCard  Female
# 58        59      Promotional      4      65.20        MasterCard  Female
# 60        61      Promotional      1     108.80  Proprietary Card  Female
# 68        69      Promotional      2      47.20  Proprietary Card    Male
# 94        95          Regular      3      66.00  American Express  Female
#
#    Marital Status  Age
# 8         Married   46
# 13        Married   46
# 41        Married   46
# 46        Married   46
# 49        Married   46
# 58        Married   46
# 60        Married   46
# 68        Married   46
# ...

# %%
dfstore.query("Age == 46 and Gender == 'Male'")
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment Gender  \
# 68        69      Promotional      2       47.2  Proprietary Card   Male
#
#    Marital Status  Age
# 68        Married   46

# %%
dfstore.query("Age <= 46 and Gender == 'Male'")
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment Gender  \
# 0          1          Regular      1       39.5          Discover   Male
# 14        15          Regular      1       49.5              Visa   Male
# 15        16      Promotional      2       71.4  Proprietary Card   Male
# 35        36          Regular      1       29.5        MasterCard   Male
# 68        69      Promotional      2       47.2  Proprietary Card   Male
#
#    Marital Status  Age
# 0         Married   32
# 14         Single   24
# 15         Single   36
# 35         Single   36
# 68        Married   46

# %% [markdown]
# #### 19. BETWEEN
# - IT IS SAME AS SQL "BETWEEN".
# - IT GIVE IN RANGE OF VALUES THAT PUT INSIDE BETWEEN CLAUSE.

# %%
dfstore["Age"].between(35,55)
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96    False
# 97     True
# 98    False
# 99     True
# Name: Age, Length: 100, dtype: bool

# %%
dfstore[   dfstore["Age"].between(35,55)  ]
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 1          2      Promotional      1     102.40  Proprietary Card  Female
# 5          6          Regular      1      44.50        MasterCard  Female
# 7          8          Regular      1      22.50              Visa  Female
# 8          9      Promotional      2      56.52  Proprietary Card  Female
# 9         10          Regular      1      44.50  Proprietary Card  Female
# 10        11          Regular      1      29.50  Proprietary Card  Female
# 11        12      Promotional      1      31.60  Proprietary Card  Female
# 12        13      Promotional      9     160.40              Visa  Female
# 13        14      Promotional      2      64.50              Visa  Female
# 15        16      Promotional      2      71.40  Proprietary Card    Male
# 17        18          Regular      3      54.50          Discover  Female
# 21        22      Promotional      4      70.82  Proprietary Card  Female
# ...

# %%
dfstore[     dfstore["Age"].between(20,40)   ]
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 0          1          Regular      1      39.50          Discover    Male
# 1          2      Promotional      1     102.40  Proprietary Card  Female
# 2          3          Regular      1      22.50  Proprietary Card  Female
# 3          4      Promotional      5     100.40  Proprietary Card  Female
# 4          5          Regular      2      54.00        MasterCard  Female
# 6          7      Promotional      2      78.00  Proprietary Card  Female
# 7          8          Regular      1      22.50              Visa  Female
# 9         10          Regular      1      44.50  Proprietary Card  Female
# 11        12      Promotional      1      31.60  Proprietary Card  Female
# 12        13      Promotional      9     160.40              Visa  Female
# 14        15          Regular      1      49.50              Visa    Male
# 15        16      Promotional      2      71.40  Proprietary Card    Male
# ...

# %% [markdown]
# #### 20. GET DUMMIES
# - IT FIRST CREATE COLUMNS AS MUCH THE UNIQUE VALUES PRESENT INSIDE THE COLUMN.
# - THEN FILL WITH 0 & 1.
# - 0 --> NOT PRESENT IN THE RECORDS.
# - 1 --> PRESENT INSIDE THE RECORDS

# %%
dfpay = pd.get_dummies(dfstore["Method of Payment"])
dfpay
# Out:
#     American Express  Discover  MasterCard  Proprietary Card  Visa
# 0                  0         1           0                 0     0
# 1                  0         0           0                 1     0
# 2                  0         0           0                 1     0
# 3                  0         0           0                 1     0
# 4                  0         0           1                 0     0
# ..               ...       ...         ...               ...   ...
# 95                 0         0           1                 0     0
# 96                 0         0           0                 1     0
# 97                 0         0           0                 1     0
# 98                 0         0           0                 1     0
# 99                 0         0           0                 1     0
#
# [100 rows x 5 columns]

# %% [markdown]
# #### 21. SELECT DTYPES
# - BY USING THIS WE CAN SELECT SPECIFIC TYPES OF DATA TYPES PRESENT INSIDE A DATASET.

# %%
dfstore
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 0          1          Regular      1      39.50          Discover    Male
# 1          2      Promotional      1     102.40  Proprietary Card  Female
# 2          3          Regular      1      22.50  Proprietary Card  Female
# 3          4      Promotional      5     100.40  Proprietary Card  Female
# 4          5          Regular      2      54.00        MasterCard  Female
# ..       ...              ...    ...        ...               ...     ...
# 95        96          Regular      1      39.50        MasterCard  Female
# 96        97      Promotional      9     253.00  Proprietary Card  Female
# 97        98      Promotional     10     287.59  Proprietary Card  Female
# 98        99      Promotional      2      47.60  Proprietary Card  Female
# 99       100      Promotional      1      28.44  Proprietary Card  Female
#
#    Marital Status  Age
# 0         Married   32
# 1         Married   36
# ...

# %%
dfstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer           100 non-null    int64
#  1   Type of Customer   100 non-null    object
#  2   Items              100 non-null    int64
#  3   Net Sales          100 non-null    float64
#  4   Method of Payment  100 non-null    object
#  5   Gender             100 non-null    object
#  6   Marital Status     100 non-null    object
#  7   Age                100 non-null    int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 6.4+ KB

# %%
# IT ONLY GIVE THE FEATURES WHICH ARE "int64" DATATYPE.
dfstore.select_dtypes(["int64"])
# Out:
#     Customer  Items  Age
# 0          1      1   32
# 1          2      1   36
# 2          3      1   32
# 3          4      5   28
# 4          5      2   34
# ..       ...    ...  ...
# 95        96      1   44
# 96        97      9   30
# 97        98     10   52
# 98        99      2   30
# 99       100      1   44
#
# [100 rows x 3 columns]

# %%
# IT ONLY GIVE THE FEATURES WHICH ARE "object" DATATYPE.
dfstore.select_dtypes(["object"])
# Out:
#    Type of Customer Method of Payment  Gender Marital Status
# 0           Regular          Discover    Male        Married
# 1       Promotional  Proprietary Card  Female        Married
# 2           Regular  Proprietary Card  Female        Married
# 3       Promotional  Proprietary Card  Female        Married
# 4           Regular        MasterCard  Female        Married
# ..              ...               ...     ...            ...
# 95          Regular        MasterCard  Female        Married
# 96      Promotional  Proprietary Card  Female        Married
# 97      Promotional  Proprietary Card  Female        Married
# 98      Promotional  Proprietary Card  Female        Married
# 99      Promotional  Proprietary Card  Female        Married
#
# [100 rows x 4 columns]

# %%
# IT GIVES FEATURES WHICH ARE "int64" AS WELL AS "float64"DATATYPE.
dfstore.select_dtypes(["int64","float64"])
# Out:
#     Customer  Items  Net Sales  Age
# 0          1      1      39.50   32
# 1          2      1     102.40   36
# 2          3      1      22.50   32
# 3          4      5     100.40   28
# 4          5      2      54.00   34
# ..       ...    ...        ...  ...
# 95        96      1      39.50   44
# 96        97      9     253.00   30
# 97        98     10     287.59   52
# 98        99      2      47.60   30
# 99       100      1      28.44   44
#
# [100 rows x 4 columns]
