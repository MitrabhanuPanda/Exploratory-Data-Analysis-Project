# %% [markdown]
# ### <font color="brown">IMPORTING LIBRARY

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### <font color="green">EXTRACTING DATASETS

# %%
tit=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS VECTORIZED STRING OPERATIONS\DATASETS\titanic.csv")
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## <font color="dark blue">VECTORIZED OPERATION
# - Vectorized operations in Pandas can be applied to entire columns or Series, which results in faster and more concise code

# %%
a=np.array([1,2,3,4])
a
# Out:
# array([1, 2, 3, 4])

# %%
a*4
# Out:
# array([ 4,  8, 12, 16])

# %% [markdown]
# #### PROBLEM WITH VANILLA PYTHON
# -  It do not use in Vanilla Python
# - It is very very slow.

# %%
s=["cat","mat","rat",None]
s
# Out:
# ['cat', 'mat', 'rat', None]

# %%
[i.strartswith("c") for i in s]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16568\544421937.py in <module>
# ----> 1 [i.strartswith("c") for i in s]
#
# ~\AppData\Local\Temp\ipykernel_16568\544421937.py in <listcomp>(.0)
# ----> 1 [i.strartswith("c") for i in s]
#
# AttributeError: 'str' object has no attribute 'strartswith'

# %% [markdown]
# #### HOW PANDAS SOLVES THIS ISSUE?

# %%
se=pd.Series(["cat","mat","rat","com"])
se
# Out:
# 0    cat
# 1    mat
# 2    rat
# 3    com
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><font color="red">Note:</b> <br>
#     <b>- str---> STRING ACCESOR <br>
# - WHENEVER YOU APPLY VECTORIZED STRING OPERTION YOU HAVE TO USE "str".
# </div>

# %%
se.str.startswith("c")
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
se[se.str.startswith("c")]
# Out:
# 0    cat
# 3    com
# dtype: object

# %% [markdown]
# ## <font color="dark blue">STRING FUNCTION

# %%
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### <font color="Orange">COMMON FUNCTIONS

# %%
tit["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# #### <font color="green">1. UPPER
#     - It convert to Upper Case

# %%
tit["Name"].str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
df[<"Column Name">].str.lower()
df["Name"].str.lower()

# %% [markdown]
# #### <font color="green">2. LOWER
#     It convert to Lower Case.

# %%
tit["Name"].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# #### <font color="Green">3. TITLE
# -  It convert to Title Case.
# -  eg:
# `the sky--> The Sky`

# %%
tit["Name"].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# #### <font color="green">4. LEN
# - It give the Number of character in a string value.
# - eg:
#     `bhubaneswar ---> 11`

# %%
tit["Name"].str.len()
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %% [markdown]
# #### <font color="green">5. STRIP
# -  It delete all the leading & trailing Spaces (Unnescessary Space) from Values
# - eg:
#     `"    the sky    " ---> "the sky"`

# %%
tit["Name"].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# #### <font color="green">6. SPLIT
# - It divide the String values by delimeter and store it into a `list`.
# - eg:
#     `the sky --> ["the","sky"]` <br>
#      here the delimeter is `space`.

# %% [markdown]
# #### <font color="red">REAL TIME EXAMPLE-1
# - We want the Sure name from "Name" Column

# %%
tit["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# Split by the delimeter ","
tit["Name"].str.split(",")
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
# By Using "get" function we extract the Sure name
tit["Name"].str.split(",").str.get(0)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# #### <font color="red">REAL TIME EXAMPLE-2
# - We want the Title & Full Name from "Name" Column

# %%
# It give Full Name with Title
tit["Name"].str.split(",").str.get(1)
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# Every Name have Space from the First.
# So we First remove this Spaces.
tit["Name"].str.split(",").str.get(1).str.strip()
# Out:
# 0                                 Mr. Owen Harris
# 1      Mrs. John Bradley (Florence Briggs Thayer)
# 2                                     Miss. Laina
# 3              Mrs. Jacques Heath (Lily May Peel)
# 4                               Mr. William Henry
#                           ...
# 886                                   Rev. Juozas
# 887                          Miss. Margaret Edith
# 888                Miss. Catherine Helen "Carrie"
# 889                               Mr. Karl Howell
# 890                                   Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# Here the Problem is From the Second Elements of list, there are more than one Elements.
tit["Name"].str.split(",").str.get(1).str.strip().str.split(" ")
# Out:
# 0                                    [Mr., Owen, Harris]
# 1      [Mrs., John, Bradley, (Florence, Briggs, Thayer)]
# 2                                         [Miss., Laina]
# 3              [Mrs., Jacques, Heath, (Lily, May, Peel)]
# 4                                  [Mr., William, Henry]
#                              ...
# 886                                       [Rev., Juozas]
# 887                             [Miss., Margaret, Edith]
# 888                  [Miss., Catherine, Helen, "Carrie"]
# 889                                  [Mr., Karl, Howell]
# 890                                       [Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
# It Split only First Occurance.
tit["Name"].str.split(",").str.get(1).str.strip().str.split(" ",n=1)
# Out:
# 0                                 [Mr., Owen Harris]
# 1      [Mrs., John Bradley (Florence Briggs Thayer)]
# 2                                     [Miss., Laina]
# 3              [Mrs., Jacques Heath (Lily May Peel)]
# 4                               [Mr., William Henry]
#                            ...
# 886                                   [Rev., Juozas]
# 887                          [Miss., Margaret Edith]
# 888                [Miss., Catherine Helen "Carrie"]
# 889                               [Mr., Karl Howell]
# 890                                   [Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
# It extract the Title & Full Name and Store it to a dataframe
tit["Name"].str.split(",").str.get(1).str.strip().str.split(" ",n=1,expand=True)
# Out:
#          0                                      1
# 0      Mr.                            Owen Harris
# 1     Mrs.  John Bradley (Florence Briggs Thayer)
# 2    Miss.                                  Laina
# 3     Mrs.          Jacques Heath (Lily May Peel)
# 4      Mr.                          William Henry
# ..     ...                                    ...
# 886   Rev.                                 Juozas
# 887  Miss.                         Margaret Edith
# 888  Miss.               Catherine Helen "Carrie"
# 889    Mr.                            Karl Howell
# 890    Mr.                                Patrick
#
# [891 rows x 2 columns]

# %%
# Store it to the datasets
tit[["Title","Full Name"]]=tit["Name"].str.split(",").str.get(1).str.strip().str.split(" ",n=1,expand=True)
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### <font color="green">7. REPLACE
# - It replace the Value with your custom value.
# -  eg:<br>
#     `Ram --> Sam`<br>
#     We Replace `"R"` of Ram with `"S"`.

# %%
tit["Title"].str.replace("Ms.","Miss")
# Out:
# C:\Users\mitra\AppData\Local\Temp\ipykernel_16568\1486040041.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   tit["Title"].str.replace("Ms.","Miss")
# 0        Mr.
# 1       Mrs.
# 2      Miss.
# 3       Mrs.
# 4        Mr.
#        ...
# 886     Rev.
# 887    Miss.
# 888    Miss.
# 889      Mr.
# 890      Mr.
# Name: Title, Length: 891, dtype: object

# %% [markdown]
# #### <font color="Purple">FILTERING

# %% [markdown]
# #### <font color="Green"> 8. STRATSWITH
# - It give the value that start with your Custom Value.
# - eg:<br>
#     `["cat","mat","rat","com"] ---> "cat" , "com"` <br>
#     Here we want the elements that start with `"c"`.

# %%
# It give all the Full Name that Starts with "A"
tit[tit["Full Name"].str.startswith("A")]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 13            14         0       3         Andersson, Mr. Anders Johan
# 22            23         1       3         McGowan, Miss. Anna "Annie"
# 35            36         0       1      Holverson, Mr. Alexander Oskar
# 38            39         0       3  Vander Planke, Miss. Augusta Maria
# 61            62         1       1                 Icard, Miss. Amelie
# ..           ...       ...     ...                                 ...
# 842          843         1       1             Serepeca, Miss. Augusta
# 845          846         0       3                 Abbing, Mr. Anthony
# 866          867         1       2        Duran y More, Miss. Asuncion
# 875          876         1       3    Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3       Gustafsson, Mr. Alfred Ossian
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked  Title  \
# ...

# %% [markdown]
# #### <font color="Green"> 9. ENDSWITH
# - It give the value that start with your Custom Value.
# - eg:<br>
#     `["cat","mat","rat","com"] ---> "cat" , "mat" , "rat"` <br>
#     Here we want the elements that end with `"t"`.

# %%
# It give all the Full Name that Ends with "A"
tit[tit["Full Name"].str.endswith("A")]
# Out:
#      PassengerId  Survived  Pclass                   Name     Sex  Age  SibSp  \
# 64            65         0       1  Stewart, Mr. Albert A    male  NaN      0
# 303          304         1       2    Keane, Miss. Nora A  female  NaN      0
#
#      Parch    Ticket     Fare Cabin Embarked  Title Full Name
# 64       0  PC 17605  27.7208   NaN        C    Mr.  Albert A
# 303      0    226593  12.3500  E101        Q  Miss.    Nora A

# %% [markdown]
# #### <font color="green">10. ISDIGIT
# - It give the values that have digits.
# - eg:
#     `E102`

# %%
# It give the Ticket Column having Digit only.
tit[tit["Ticket"].str.isdigit()]
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ...

# %% [markdown]
# #### <font color="green">10. ISALPHA
# - It give the values that have alphabets.
# - eg:
#     `ER202`

# %%
# It give the Ticket Column having Alphabets only.
tit[tit["Ticket"].str.isalpha()]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 179          180         0       3              Leonard, Mr. Lionel  male
# 271          272         1       3     Tornquist, Mr. William Henry  male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  male
# 597          598         0       3              Johnson, Mr. Alfred  male
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked Title           Full Name
# 179  36.0      0      0   LINE   0.0   NaN        S   Mr.              Lionel
# 271  25.0      0      0   LINE   0.0   NaN        S   Mr.       William Henry
# 302  19.0      0      0   LINE   0.0   NaN        S   Mr.  William Cahoone Jr
# 597  49.0      0      0   LINE   0.0   NaN        S   Mr.              Alfred

# %% [markdown]
# #### <font color="green">11. CONTAINS
# - `"CASE"--> Default is `__True__`. If you convert to `__False__` then it do not care about the CASE OF ALPHABETS.`
# - It find the Particular Values that you provide.
# - eg: <br>
#     `["Rama","Samya","Ram","Dhama"] --> "Ram"` <br>
#     Here we want to find a particular element i.e. `"Ram"`

# %%
# It give all the Full Name that Ends with "A"
tit[tit["Full Name"].str.contains("john",case=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# 550          551         1       1
# 563          564         0       3
# 572          573         1       1
# ...

# %%
# Find lastnames with start and end char vowel
tit[tit['Full Name'].str.contains('^[^aeiouAEIOU].+[^aeiouAEIOU]$')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### <font color="violet">SLICING

# %%
tit['Full Name'].str[4:]
# Out:
# 0                                 Harris
# 1       Bradley (Florence Briggs Thayer)
# 2                                      a
# 3              ues Heath (Lily May Peel)
# 4                              iam Henry
#                      ...
# 886                                   as
# 887                           aret Edith
# 888                 erine Helen "Carrie"
# 889                               Howell
# 890                                  ick
# Name: Full Name, Length: 891, dtype: object
