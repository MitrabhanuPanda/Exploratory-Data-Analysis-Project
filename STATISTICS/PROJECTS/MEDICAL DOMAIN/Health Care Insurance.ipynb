# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# # <font color='red'>DATA IMPORTING

# %%
df=pd.read_csv(r"C:\Users\mitra\Desktop\INNOMATICS(MITRABHANU PANDA)\Statistics\DATASETS\Medical Domain\insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns # Show all the columns name
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.isnull().sum() # show null value of of columns
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info() # Show all infomation(Column Name,Not Null Value,Data Type) about all the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.shape # Show how many records and columns are in the dataset
# Out:
# (1338, 7)

# %% [markdown]
# # <font color='red'>Univariate Analysis On Numerical Features
#
# ##    <font color='blue'>Non-Vizualize
#     Min
#     MAx
#     Cental Tendency
#     percentiles
#     Dispersion
#
# ##   <font color='blue'> Vizualize
#     plot of Dist- Distribution
#     plot of box plot- outlier

# %% [markdown]
# ### <font color='brown'>1. AGE

# %%
df["age"]
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
print('minimum value of this feature :       ',df['age'].min())    # Show the minimum value of feature
print('maximum value of this feature :       ',df['age'].max())    # Show the maximum value of feature
print('mean of this feature :                ',df['age'].mean())   # Show the mean value of feature
print('median of this feature :              ',df['age'].median()) # Show the median value of feature
print('standard deviation of this feature :  ',df['age'].std())    # Show the standard deviation of feature
# Out:
# minimum value of this feature :        18
# maximum value of this feature :        64
# mean of this feature :                 39.20702541106129
# median of this feature :               39.0
# standard deviation of this feature :   14.049960379216172

# %%
# Other way to know about the mean,median,standard deviation,min,max

print(df['age'].describe())
print('median    ',df['age'].median())
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64
# median     39.0

# %%
df['age'].plot(kind='box') # show the outlier of this feature
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### --->Age feature has no outlier

# %%
df['age'].plot(kind='kde') # show the feature normally distributed or not using kde plot
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
stats.probplot(df['age'],dist='norm',plot=plt) # Exactly show the feature normally distributed or not using probabilty plot
plt.grid()

# %%
# Other way to know about the normal distribution
df['age'].skew()
# Out:
# 0.05567251565299186

# %% [markdown]
# ### --->Age Feature is Normally Distributed

# %% [markdown]
# ### <font color='brown'>2. BMI (BODY MASS INDEX)

# %% [markdown]
#     Body mass index (BMI) is a measure of body fat based on height and weight that applies to adult men and women.
#         Underweight = <18.5
#         Normal weight = 18.5–24.9
#         Overweight = 25–29.9
#         Obesity = BMI of 30 or greater

# %%
df['bmi']
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %%
print('minimum value of this feature :       ',df['bmi'].min())
print('maximum value of this feature :       ',df['bmi'].max())
print('mean of this feature :                ',df['bmi'].mean())
print('median of this feature :              ',df['bmi'].median())
print('standard deviation of this feature :  ',df['bmi'].std())
# Out:
# minimum value of this feature :        15.96
# maximum value of this feature :        53.13
# mean of this feature :                 30.663396860986538
# median of this feature :               30.4
# standard deviation of this feature :   6.098186911679017

# %%
df['bmi'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### --->BMI feature has outlier

# %%
df['bmi'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
stats.probplot(df['bmi'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# ### ----> BMI feature is Normally Distributed

# %% [markdown]
# ### <font color='green'> OUTLIER DETECTION

# %% [markdown]
# #### MEAN-STD METHOD :
# #### LOWER LIMIT= MEAN-(3*STD)
# #### UPPER LIMIT= MEAN+(3*STD)

# %%
mean_bmi=df['bmi'].mean() # Mean value of BMI feature

# %%
std_bmi=df['bmi'].std() # Standard Deviation of BMI feature

# %%
lower_limit=mean_bmi-(3*std_bmi) # Lower Limit of BMI feature

# %%
upper_limit=mean_bmi+(3*std_bmi) # Upper Limit of BMI feature

# %%
df[df['bmi']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
df[df['bmi']>upper_limit]
# Out:
#       age   sex    bmi  children smoker     region     charges
# 116    58  male  49.06         0     no  southeast  11381.3254
# 847    23  male  50.38         1     no  southeast   2438.0552
# 1047   22  male  52.58         1    yes  southeast  44501.3982
# 1317   18  male  53.13         0     no  southeast   1163.4627

# %%
df[(df['bmi']<lower_limit)|(df['bmi']>upper_limit)] # Show records of the outliers
# Out:
#       age   sex    bmi  children smoker     region     charges
# 116    58  male  49.06         0     no  southeast  11381.3254
# 847    23  male  50.38         1     no  southeast   2438.0552
# 1047   22  male  52.58         1    yes  southeast  44501.3982
# 1317   18  male  53.13         0     no  southeast   1163.4627

# %% [markdown]
# ### Trimming

# %%
df=df[((df['bmi']>lower_limit))&((df['bmi']<upper_limit))] # Delete records of the outliers and put into the dataset

# %%
df[(df['bmi']<lower_limit)|(df['bmi']>upper_limit)]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
df.shape
# Out:
# (1334, 7)

# %%
df['bmi'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
print('minimum value of this feature :       ',df['bmi'].min())
print('maximum value of this feature :       ',df['bmi'].max())
print('mean of this feature :                ',df['bmi'].mean())
print('median of this feature :              ',df['bmi'].median())
print('standard deviation of this feature :  ',df['bmi'].std())
# Out:
# minimum value of this feature :        15.96
# maximum value of this feature :        48.07
# mean of this feature :                 30.601555472263843
# median of this feature :               30.3325
# standard deviation of this feature :   6.000927253768586

# %%
df['bmi'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df=df[df['bmi']<45]

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1318 rows x 7 columns]

# %%
df['bmi'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['bmi'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
stats.probplot(df['bmi'],dist='norm',plot=plt)
plt.grid()

# %%
print('minimum value of this feature :       ',df['bmi'].min())
print('maximum value of this feature :       ',df['bmi'].max())
print('mean of this feature :                ',df['bmi'].mean())
print('median of this feature :              ',df['bmi'].median())
print('standard deviation of this feature :  ',df['bmi'].std())
# Out:
# minimum value of this feature :        15.96
# maximum value of this feature :        44.88
# mean of this feature :                 30.407143399089513
# median of this feature :               30.21
# standard deviation of this feature :   5.769453525132324

# %% [markdown]
# ### <font color='brown'>3. CHILDREN

# %%
df['children']
# Out:
# 0       0
# 1       1
# 2       3
# 3       0
# 4       0
#        ..
# 1333    3
# 1334    0
# 1335    0
# 1336    0
# 1337    0
# Name: children, Length: 1318, dtype: int64

# %%
df['children'].value_counts()
# Out:
# 0    570
# 1    317
# 2    233
# 3    156
# 4     25
# 5     17
# Name: children, dtype: int64

# %%
df['children'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
print('minimum value of this feature :       ',df['children'].min())
print('maximum value of this feature :       ',df['children'].max())
print('mean of this feature :                ',df['children'].mean())
print('median of this feature :              ',df['children'].median())
print('standard deviation of this feature :  ',df['children'].std())
# Out:
# minimum value of this feature :        0
# maximum value of this feature :        5
# mean of this feature :                 1.0895295902883155
# median of this feature :               1.0
# standard deviation of this feature :   1.2053523725236366

# %%
df['children'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ---> Children has no outlier

# %%
df['children'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import numpy as np

# %%
df['children'].skew()
# Out:
# 0.9375832236814263

# %%
np.round(df['children'].skew())
# Out:
# 1.0

# %%
stats.probplot(df['children'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# ### <font color='brown'>4. CHARGES

# %%
df['charges']
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1318, dtype: float64

# %%
print('minimum value of this feature :       ',df['charges'].min())
print('maximum value of this feature :       ',df['charges'].max())
print('mean of this feature :                ',df['charges'].mean())
print('median of this feature :              ',df['charges'].median())
print('standard deviation of this feature :  ',df['charges'].std())
# Out:
# minimum value of this feature :        1121.8739
# maximum value of this feature :        62592.87309
# mean of this feature :                 13205.513244119122
# median of this feature :               9369.61575
# standard deviation of this feature :   11974.486055602221

# %%
df['charges'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ----> Charges feature has outliers

# %%
df['charges'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['charges'].skew()
# Out:
# 1.4988616530238879

# %%
stats.probplot(df['charges'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# ### ---> Not Normally Distributed

# %% [markdown]
# ### <font color='green'> OUTLIER DETECTION

# %% [markdown]
# #### q1=df[column name].quantile(0.25)
# #### q3=df[column name].quantile(0.75)
#
# #### IQR= q3-q1
#
# #### upper limt=q1-(1.5*IQR)
# #### lower limt=q3+(1.5*IQR)

# %%
q1=df['charges'].quantile(0.25)
q3=df['charges'].quantile(0.75)

IQR= q3-q1

charges_lower=q1-1.5*IQR
charges_upper=q3+1.5*IQR

# %%
df[(df['charges'] < charges_lower) | (df['charges'] > charges_upper)]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 14     27    male  42.130         0    yes  southeast  39611.75770
# 19     30    male  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 29     31    male  36.300         2    yes  southwest  38711.00000
# 30     22    male  35.600         0    yes  southwest  35585.57600
# ...   ...     ...     ...       ...    ...        ...          ...
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1301   62    male  30.875         3    yes  northwest  46718.16325
# 1303   43    male  27.800         0    yes  southwest  37829.72420
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1323   42  female  40.370         2    yes  southeast  43896.37630
#
# [134 rows x 7 columns]

# %%
df['charges'] = df['charges'].map( lambda x : charges_lower  if x < charges_lower else  charges_upper if x > charges_upper else x)

# %%
df[(df['charges'] < charges_lower) | (df['charges'] > charges_upper)]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1318 rows x 7 columns]

# %%
df['charges'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['charges'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
stats.probplot(df['charges'],dist='norm',plot=plt)
plt.grid()

# %% [markdown]
# # <font color='red'>Univariate Analysis On Categorical Features
# ##   <font color='blue'>Non-Vizualize
#      counts- value_counts
#
# ##   <font color='blue'> Vizualize
#      count plot
#      bar plot

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1318 rows x 7 columns]

# %% [markdown]
# ### <font color='brown'>1. SEX

# %%
df['sex']
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: sex, Length: 1318, dtype: object

# %%
df['sex'].value_counts()
# Out:
# male      664
# female    654
# Name: sex, dtype: int64

# %%
df['sex'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Male is more than Female

# %% [markdown]
# ### <font color='brown'>2. SMOKER

# %%
df['smoker']
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1318, dtype: object

# %%
df['smoker'].value_counts()
# Out:
# no     1049
# yes     269
# Name: smoker, dtype: int64

# %%
df['smoker'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Person(Male,Female) who donot smoke is more.

# %% [markdown]
# ### <font color='brown'>3. REGION

# %%
df['region']
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1318, dtype: object

# %%
df['region'].value_counts()
# Out:
# southeast    348
# northwest    325
# northeast    323
# southwest    322
# Name: region, dtype: int64

# %%
df['region'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Person(Male,Female) from SOUTHEAST are more.

# %% [markdown]
# ###

# %% [markdown]
# # <font color='red'>Bivariate Analysis

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1318 rows x 7 columns]

# %% [markdown]
# ### <font color='red'>NUM VS NUM

# %%
plt.scatter(x=df['age'],y=df['charges'])

# %%
plt.scatter(x=df['bmi'],y=df['charges'])

# %%
plt.scatter(x=df['age'],y=df['bmi'])

# %% [markdown]
# ### <font color='red'>NUM VS CATEGORICAL

# %%
df.boxplot(by="sex",column="bmi")
# Out:
# <AxesSubplot:title={'center':'bmi'}, xlabel='sex'>

# %%
df.boxplot(by="sex",column="charges")
# Out:
# <AxesSubplot:title={'center':'charges'}, xlabel='sex'>

# %%
df.boxplot(by="region",column="bmi")
# Out:
# <AxesSubplot:title={'center':'bmi'}, xlabel='region'>

# %%
df.boxplot(by="region",column="charges")
# Out:
# <AxesSubplot:title={'center':'charges'}, xlabel='region'>
