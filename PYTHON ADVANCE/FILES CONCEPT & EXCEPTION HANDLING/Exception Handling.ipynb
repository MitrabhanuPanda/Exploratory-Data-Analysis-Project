# %% [markdown]
# ### Error:
#     It is a process of abnormal termination of program due to some illegal activity.
# ### Types of Errors:
#     •	Syntax Errors:
#         o	Errors which are triggered due to not following the predefined rules while coding.
#         o	This error are triggered due to mistakes done by programmer or developer.
#         o	Developer/Programmer are responsible for the type of errors.
#
#     •	Run Time Errors:
#         o	This errors which are triggered due to wrong input given by the user.
#         o	End User is responsible for these type of error.
#
#     	This error are also referred as Exceptions.
#
# ### Exception Handling:
#     •	Handling run-time errors (Exceptions)
#     •	It is a process of handling exception to avoid abnormal termination of program/application.
#
# ### Steps:
#     Try:
#         --------------------------
#         --------------------------
#     Except:
#         --------------------------
#         --------------------------
#     Finally:
#         -------------------------
#
#         --------------------------

# %%
import time

# %%
tnum=int(input("Enter Number to print Table: "))
num1=int(input("Enter 1st Number: "))
num2=int(input("Enter 2nd Number: "))

print("Task-1")

add=num1+num2
print("Addition: ",add)

sub=num1-num2
print("Substraction: ",sub)

div=num1/num2
print("Division: ",div)

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 5
# Enter 1st Number: 20
# Enter 2nd Number: 10
# Task-1
# Addition:  30
# Substraction:  10
# Division:  2.0
# ******************************************************
# Task-2
# 5 * 1 == 5
# 5 * 2 == 10
# 5 * 3 == 15
# 5 * 4 == 20
# 5 * 5 == 25
# 5 * 6 == 30
# 5 * 7 == 35
# 5 * 8 == 40
# 5 * 9 == 45
# 5 * 10 == 50

# %%
tnum=int(input("Enter Number to print Table: "))
num1=int(input("Enter 1st Number: "))
num2=int(input("Enter 2nd Number: "))

print("Task-1")

try:
    add=num1+num2
    print("Addition: ",add)


    div=num1/num2
    print("Division: ",div)

except:
    print("Please Enter Non Zero Number")

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 6
# Enter 1st Number: 15
# Enter 2nd Number: 0
# Task-1
# Addition:  15
# Please Enter Non Zero Number
# ******************************************************
# Task-2
# 6 * 1 == 6
# 6 * 2 == 12
# 6 * 3 == 18
# 6 * 4 == 24
# 6 * 5 == 30
# 6 * 6 == 36
# 6 * 7 == 42
# 6 * 8 == 48
# 6 * 9 == 54
# 6 * 10 == 60

# %%
tnum=int(input("Enter Number to print Table: "))


print("Task-1")

try:
    num1=int(input("Enter 1st Number: "))
    num2=int(input("Enter 2nd Number: "))
    add=num1+num2
    print("Addition: ",add)


    div=num1/num2
    print("Division: ",div)

except ZeroDivisionError:
    print("Please Enter Non Zero Number")
    
except ValueError:
    print("Please Enter Number Only.")

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 6
# Task-1
# Enter 1st Number: 10
# Enter 2nd Number: 0
# Addition:  10
# Please Enter Non Zero Number
# ******************************************************
# Task-2
# 6 * 1 == 6
# 6 * 2 == 12
# 6 * 3 == 18
# 6 * 4 == 24
# 6 * 5 == 30
# 6 * 6 == 36
# 6 * 7 == 42
# 6 * 8 == 48
# 6 * 9 == 54
# 6 * 10 == 60

# %%
tnum=int(input("Enter Number to print Table: "))


print("Task-1")

try:
    num1=int(input("Enter 1st Number: "))
    num2=int(input("Enter 2nd Number: "))
    add=num1+num2
    print("Addition: ",add)


    div=num1/num2
    print("Division: ",div)

except ZeroDivisionError:
    print("Please Enter Non Zero Number")
    
except ValueError:
    print("Please Enter Number Only.")

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 7
# Task-1
# Enter 1st Number: 10
# Enter 2nd Number: a
# Please Enter Number Only.
# ******************************************************
# Task-2
# 7 * 1 == 7
# 7 * 2 == 14
# 7 * 3 == 21
# 7 * 4 == 28
# 7 * 5 == 35
# 7 * 6 == 42
# 7 * 7 == 49
# 7 * 8 == 56
# 7 * 9 == 63
# 7 * 10 == 70

# %%
tnum=int(input("Enter Number to print Table: "))


print("Task-1")

try:
    num1=int(input("Enter 1st Number: "))
    num2=int(input("Enter 2nd Number: "))
    add=num1+num2
    print("Addition: ",add)


    div=num1/num2
    print("Division: ",div)



except BaseException as msg :
    print(msg)
    print(msg.__class__)
    print(msg.__class__.__name__)

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 7
# Task-1
# Enter 1st Number: 13
# Enter 2nd Number: a
# invalid literal for int() with base 10: 'a'
# <class 'ValueError'>
# ValueError
# ******************************************************
# Task-2
# 7 * 1 == 7
# 7 * 2 == 14
# 7 * 3 == 21
# 7 * 4 == 28
# 7 * 5 == 35
# 7 * 6 == 42
# 7 * 7 == 49
# 7 * 8 == 56
# 7 * 9 == 63
# 7 * 10 == 70

# %%
tnum=int(input("Enter Number to print Table: "))


print("Task-1")

try:
    num1=int(input("Enter 1st Number: "))
    num2=int(input("Enter 2nd Number: "))
    add=num1+num2
    print("Addition: ",add)


    div=num1/num2
    print("Division: ",div)



except BaseException as msg :
    
    error=msg.__class__.__name__
    
    if error == "ValueError":
        print("Please enter Number Only")
    elif error == "ZeroDivisionError":
        print("Please enter Non-Zero Number")
    else:
        print("Error Triggered")

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 8
# Task-1
# Enter 1st Number: 10
# Enter 2nd Number: 0
# Addition:  10
# Please enter Non-Zero Number
# ******************************************************
# Task-2
# 8 * 1 == 8
# 8 * 2 == 16
# 8 * 3 == 24
# 8 * 4 == 32
# 8 * 5 == 40
# 8 * 6 == 48
# 8 * 7 == 56
# 8 * 8 == 64
# 8 * 9 == 72
# 8 * 10 == 80

# %%
tnum=int(input("Enter Number to print Table: "))


print("Task-1")

try:
    
    num1=int(input("Enter 1st Number: "))
    num2=int(input("Enter 2nd Number: "))
    add=num1+num2
    print("Addition: ",add)


    div=num1/num2
    print("Division: ",div)



except BaseException as msg :
    
    error=msg.__class__.__name__
    
    if error == "ValueError":
        print("Please enter Number Only")
    elif error == "ZeroDivisionError":
        print("Please enter Non-Zero Number")
    else:
        print("Error Triggered")

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 8
# Task-1
# Enter 1st Number: 10
# Enter 2nd Number: a
# Please enter Number Only
# ******************************************************
# Task-2
# 8 * 1 == 8
# 8 * 2 == 16
# 8 * 3 == 24
# 8 * 4 == 32
# 8 * 5 == 40
# 8 * 6 == 48
# 8 * 7 == 56
# 8 * 8 == 64
# 8 * 9 == 72
# 8 * 10 == 80

# %%
tnum=int(input("Enter Number to print Table: "))


print("Task-1")

try:
    print("CONNECT TO CLOUD")
    num1=int(input("Enter 1st Number: "))
    num2=int(input("Enter 2nd Number: "))
    add=num1+num2
    print("Addition: ",add)


    div=num1/num2
    print("Division: ",div)



except BaseException as msg :
    
    error=msg.__class__.__name__
    
    if error == "ValueError":
        print("Please enter Number Only")
    elif error == "ZeroDivisionError":
        print("Please enter Non-Zero Number")
    else:
        print("Error Triggered")
    
finally:
    print("______________________")
    print("Finally Block")
    print("CLOUD CLOSING CODE")

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 10
# Task-1
# CONNECT TO CLOUD
# Enter 1st Number: 20
# Enter 2nd Number: a
# Please enter Number Only
# ______________________
# Finally Block
# CLOUD CLOSING CODE
# ******************************************************
# Task-2
# 10 * 1 == 10
# 10 * 2 == 20
# 10 * 3 == 30
# 10 * 4 == 40
# 10 * 5 == 50
# 10 * 6 == 60
# 10 * 7 == 70
# 10 * 8 == 80
# 10 * 9 == 90
# 10 * 10 == 100

# %%
tnum=int(input("Enter Number to print Table: "))


print("Task-1")

try:
    print("CONNECT TO CLOUD")
    num1=int(input("Enter 1st Number: "))
    num2=int(input("Enter 2nd Number: "))
    add=num1+num2
    print("Addition: ",add)


    div=num1/num2
    print("Division: ",div)



except BaseException as msg :
    
    error=msg.__class__.__name__
    
    if error == "ValueError":
        print("Please enter Number Only")
    elif error == "ZeroDivisionError":
        print("Please enter Non-Zero Number")
    else:
        print("Error Triggered")
        
    print("CLOUD CLOSING CODE")

print("******************************************************")


print("Task-2")
for i in range(1,11):
    print(tnum,"*",i,"==",tnum*i)
    time.sleep(0.5)
# Out:
# Enter Number to print Table: 10
# Task-1
# CONNECT TO CLOUD
# Enter 1st Number: 60
# Enter 2nd Number: a
# Please enter Number Only
# CLOUD CLOSING CODE
# ******************************************************
# Task-2
# 10 * 1 == 10
# 10 * 2 == 20
# 10 * 3 == 30
# 10 * 4 == 40
# 10 * 5 == 50
# 10 * 6 == 60
# 10 * 7 == 70
# 10 * 8 == 80
# 10 * 9 == 90
# 10 * 10 == 100
