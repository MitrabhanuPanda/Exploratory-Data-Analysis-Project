# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
dftips = pd.read_csv("tips.csv")

# %%
dftips.columns = ['total', 'tip', 'gender', 'smoker', 'day', 'time', 'size']

# %%
dftips
# Out:
#      total   tip  gender smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = dftips["day"], y = dftips["total"])
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(y = dftips["day"], x = dftips["total"])
# Out:
# <AxesSubplot:xlabel='total', ylabel='day'>

# %%
sns.barplot(x = dftips["day"], y = dftips["total"], hue = dftips["gender"])
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot( y= dftips["day"], x = dftips["total"], hue = dftips["gender"])
# Out:
# <AxesSubplot:xlabel='total', ylabel='day'>

# %%
sns.barplot(x = dftips["day"], y = dftips["total"], hue = dftips["time"])
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order=["Female","Male"])
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
horder = ["Female", "Male"]

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, ci = 50)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, ci = 100)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, ci = 20)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, color="b")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, palette='cool')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, palette='cool_r')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, palette='abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     205                 # Perhaps a named matplotlib colormap?
# --> 206                 palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207             except ValueError:
#
# ~\anaconda3\lib\site-packages\seaborn\palettes.py in mpl_palette(name, n_colors, as_cmap)
#     442     else:
# --> 443         cmap = mpl.cm.get_cmap(name)
#     444
#
# ~\anaconda3\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     285         return name
# --> 286     _api.check_in_list(sorted(_cmap_registry), name=name)
#     287     if lut is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py in check_in_list(_values, _print_supported_values, **kwargs)
# ...

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, palette='Wistia')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder, errcolor='0.7')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, hue_order= horder,     dodge=False,)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips,)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, dodge=False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, errcolor='0.6')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>

# %%
sns.barplot(x = "day", y = "total", hue = "gender", data = dftips, errcolor='0.6', errwidth=10)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total'>
