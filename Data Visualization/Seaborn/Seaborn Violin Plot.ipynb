# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dfmall = pd.read_csv("supermarket_sales.csv")

# %%
dfmall
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dfmall["Total"]
# Out:
# 0       548.9715
# 1        80.2200
# 2       340.5255
# 3       489.0480
# 4       634.3785
#          ...
# 995      42.3675
# 996    1022.4900
# 997      33.4320
# 998      69.1110
# 999     649.2990
# Name: Total, Length: 1000, dtype: float64

# %%
sns.violinplot(y = "Total", data = dfmall)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.violinplot(y = "Total", data = dfmall, width=0.5)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.violinplot(y = "Total", data = dfmall, width=0.5, color="yellow")
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.violinplot(x = "Total", data = dfmall)    # width=0.8,
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
sns.violinplot(x = "Total", data = dfmall,width=0.5)
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
sns.violinplot(x = "Total", data = dfmall,width=0.5, color="r")
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
sns.distplot(dfmall["Total"])
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
dfmall["Payment"]
# Out:
# 0          Ewallet
# 1             Cash
# 2      Credit card
# 3          Ewallet
# 4          Ewallet
#           ...
# 995        Ewallet
# 996        Ewallet
# 997           Cash
# 998           Cash
# 999           Cash
# Name: Payment, Length: 1000, dtype: object

# %%
dfmall["Payment"].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
dfmall["Total"]
# Out:
# 0       548.9715
# 1        80.2200
# 2       340.5255
# 3       489.0480
# 4       634.3785
#          ...
# 995      42.3675
# 996    1022.4900
# 997      33.4320
# 998      69.1110
# 999     649.2990
# Name: Total, Length: 1000, dtype: float64

# %%
sns.violinplot(x = "Payment", y = "Total", data = dfmall)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x = "Payment", y = "Total", data = dfmall, color = "y")
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x = "Payment", y = "Total", data = dfmall, hue="Gender")
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x="Payment", y="Total", data=dfmall, hue="City")
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="Payment", y="Total", data=dfmall, hue="Gender")
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="Payment", y="Total", data=dfmall, hue="Gender", split=True)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="Payment", y="Total", data=dfmall, hue="Gender", split=True, inner='quartile')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="Payment", y="Total", data=dfmall, hue="Gender", inner='quartile')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="Payment", y="Total", data=dfmall, hue="Gender", split=True, inner='stick')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="Payment", y="Total", data=dfmall, hue="Gender", split=True, inner='quartile', bw=1.5)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="Payment", y="Total", data=dfmall, hue="Gender", split=True, inner='quartile', bw=10)
plt.show()
