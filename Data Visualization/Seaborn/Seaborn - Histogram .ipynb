# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
dftips = pd.read_csv("tips.csv")

# %%
dftips.columns = ['total', 'tip', 'gender', 'smoker', 'day', 'time', 'size']

# %%
dftips
# Out:
#      total   tip  gender smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dftips["day"]
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: object

# %%
dftips["day"].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dftips["time"].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
dftips
# Out:
#      total   tip  gender smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dftips["total"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total, Length: 244, dtype: float64

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
sns.distplot(dftips["total"])
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
plt.hist(dftips["total"], bins = 20)
plt.show()

# %%
sns.distplot(dftips["total"], label = "Total Bill")
plt.legend()

# %%
sns.distplot(dftips["size"])
# Out:
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %%
dftips
# Out:
#      total   tip  gender smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dftips["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
sns.distplot(dftips["tip"])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(dftips["total"])
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 10)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 20)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 100)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 25)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 25, hist=False)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 25)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 25, kde = False)
# Out:
# <AxesSubplot:xlabel='total'>

# %%
sns.distplot(dftips["total"], bins = 25, kde = False, color="r")
# Out:
# <AxesSubplot:xlabel='total'>

# %%
sns.distplot(dftips["total"], bins = 25)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 25, rug = True)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
plt.figure(figsize=(16,10))
sns.distplot(dftips["total"], bins = 25, rug = True)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
plt.figure(figsize=(16,10))
sns.distplot(dftips["total"], bins = 25)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
from scipy.stats import norm

# %%
plt.figure(figsize=(10,6))
sns.distplot(dftips["total"], bins = 25, fit = norm)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
plt.figure(figsize=(16,10))
sns.distplot(dftips["total"], bins = 25, hist = False, fit = norm)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
plt.figure(figsize=(16,10))
sns.distplot(dftips["total"], bins = 25, kde = False, fit = norm)
# Out:
# <AxesSubplot:xlabel='total'>

# %%
sns.distplot(dftips["total"], bins = 25, kde = False, fit = norm)
# Out:
# <AxesSubplot:xlabel='total'>

# %%
sns.distplot(dftips["total"], bins = 25)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>

# %%
sns.distplot(dftips["total"], bins = 25, vertical= True)
# Out:
# <AxesSubplot:xlabel='Density', ylabel='total'>

# %%
sns.distplot(dftips["total"], bins = 25, color= "y")
# Out:
# <AxesSubplot:xlabel='total', ylabel='Density'>
