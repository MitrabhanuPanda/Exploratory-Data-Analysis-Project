# %%
import pandas as pd

# %%
import numpy as np

# %%
dfsales = pd.read_csv(r"C:/Users/hp/Desktop/DATASETS/Datasets/Groupby/gbsales.csv")

# %%
dfsales
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
dfsales.drop("Account", axis = 1)
# Out:
#                             Name            Rep        Manager      Product  \
# 0                Trantow-Barrows   Craig Booker   Debra Henley          CPU
# 1                Trantow-Barrows   Craig Booker   Debra Henley     Software
# 2                Trantow-Barrows   Craig Booker   Debra Henley  Maintenance
# 3   Fritsch, Russel and Anderson   Craig Booker   Debra Henley          CPU
# 4                   Kiehn-Spinka  Daniel Hilton   Debra Henley          CPU
# 5                      Kulas Inc  Daniel Hilton   Debra Henley          CPU
# 6                      Kulas Inc  Daniel Hilton   Debra Henley     Software
# 7                  Jerde-Hilpert     John Smith   Debra Henley  Maintenance
# 8                     Barton LLC     John Smith   Debra Henley          CPU
# 9                     Herman LLC    Cedric Moss  Fred Anderson          CPU
# 10                   Purdy-Kunde    Cedric Moss  Fred Anderson          CPU
# ...

# %%
dfsales.drop("Account", axis = 1, inplace = True)

# %%
dfsales
# Out:
#                             Name            Rep        Manager      Product  \
# 0                Trantow-Barrows   Craig Booker   Debra Henley          CPU
# 1                Trantow-Barrows   Craig Booker   Debra Henley     Software
# 2                Trantow-Barrows   Craig Booker   Debra Henley  Maintenance
# 3   Fritsch, Russel and Anderson   Craig Booker   Debra Henley          CPU
# 4                   Kiehn-Spinka  Daniel Hilton   Debra Henley          CPU
# 5                      Kulas Inc  Daniel Hilton   Debra Henley          CPU
# 6                      Kulas Inc  Daniel Hilton   Debra Henley     Software
# 7                  Jerde-Hilpert     John Smith   Debra Henley  Maintenance
# 8                     Barton LLC     John Smith   Debra Henley          CPU
# 9                     Herman LLC    Cedric Moss  Fred Anderson          CPU
# 10                   Purdy-Kunde    Cedric Moss  Fred Anderson          CPU
# ...

# %%
dfsales.drop("Status", axis = 1, inplace=True)

# %%
dfsales
# Out:
#                             Name            Rep        Manager      Product  \
# 0                Trantow-Barrows   Craig Booker   Debra Henley          CPU
# 1                Trantow-Barrows   Craig Booker   Debra Henley     Software
# 2                Trantow-Barrows   Craig Booker   Debra Henley  Maintenance
# 3   Fritsch, Russel and Anderson   Craig Booker   Debra Henley          CPU
# 4                   Kiehn-Spinka  Daniel Hilton   Debra Henley          CPU
# 5                      Kulas Inc  Daniel Hilton   Debra Henley          CPU
# 6                      Kulas Inc  Daniel Hilton   Debra Henley     Software
# 7                  Jerde-Hilpert     John Smith   Debra Henley  Maintenance
# 8                     Barton LLC     John Smith   Debra Henley          CPU
# 9                     Herman LLC    Cedric Moss  Fred Anderson          CPU
# 10                   Purdy-Kunde    Cedric Moss  Fred Anderson          CPU
# ...

# %%
dfsales["Manager"].unique()
# Out:
# array(['Debra Henley', 'Fred Anderson'], dtype=object)

# %%
dfsales["Rep"].unique()
# Out:
# array(['Craig Booker', 'Daniel Hilton', 'John Smith', 'Cedric Moss',
#        'Wendy Yule'], dtype=object)

# %%
dfsales["Rep"].nunique()
# Out:
# 5

# %%
dfsales["Name"].unique()
# Out:
# array(['Trantow-Barrows', 'Fritsch, Russel and Anderson', 'Kiehn-Spinka',
#        'Kulas Inc', 'Jerde-Hilpert', 'Barton LLC', 'Herman LLC',
#        'Purdy-Kunde', 'Stokes LLC', 'Kassulke, Ondricka and Metz',
#        'Keeling LLC', 'Koepp Ltd'], dtype=object)

# %%
dfsales["Name"].nunique()
# Out:
# 12

# %%
dfsales["Product"].unique()
# Out:
# array(['CPU', 'Software', 'Maintenance', 'Monitor'], dtype=object)

# %%
gb_manager = dfsales.groupby("Manager")

# %%
gb_manager.groups
# Out:
# {'Debra Henley': [0, 1, 2, 3, 4, 5, 6, 7, 8], 'Fred Anderson': [9, 10, 11, 12, 13, 14, 15, 16]}

# %%
for x, y in gb_manager:
    print(x)
    print("__________________")
    print()
    print(y)
    print()
    print("********************************************")
    print()
# Out:
# Debra Henley
# __________________
#
#                            Name            Rep       Manager      Product  \
# 0               Trantow-Barrows   Craig Booker  Debra Henley          CPU
# 1               Trantow-Barrows   Craig Booker  Debra Henley     Software
# 2               Trantow-Barrows   Craig Booker  Debra Henley  Maintenance
# 3  Fritsch, Russel and Anderson   Craig Booker  Debra Henley          CPU
# 4                  Kiehn-Spinka  Daniel Hilton  Debra Henley          CPU
# 5                     Kulas Inc  Daniel Hilton  Debra Henley          CPU
# 6                     Kulas Inc  Daniel Hilton  Debra Henley     Software
# 7                 Jerde-Hilpert     John Smith  Debra Henley  Maintenance
# 8                    Barton LLC     John Smith  Debra Henley          CPU
#
#    Quantity  Price
# 0         1  30000
# 1         1  10000
# 2         2   5000
# 3         1  35000
# 4         2  65000
# 5         2  40000
# 6         1  10000
# 7         2   5000
# ...

# %%
gb_manager.get_group("Debra Henley")
# Out:
#                            Name            Rep       Manager      Product  \
# 0               Trantow-Barrows   Craig Booker  Debra Henley          CPU
# 1               Trantow-Barrows   Craig Booker  Debra Henley     Software
# 2               Trantow-Barrows   Craig Booker  Debra Henley  Maintenance
# 3  Fritsch, Russel and Anderson   Craig Booker  Debra Henley          CPU
# 4                  Kiehn-Spinka  Daniel Hilton  Debra Henley          CPU
# 5                     Kulas Inc  Daniel Hilton  Debra Henley          CPU
# 6                     Kulas Inc  Daniel Hilton  Debra Henley     Software
# 7                 Jerde-Hilpert     John Smith  Debra Henley  Maintenance
# 8                    Barton LLC     John Smith  Debra Henley          CPU
#
#    Quantity  Price
# 0         1  30000
# 1         1  10000
# 2         2   5000
# 3         1  35000
# 4         2  65000
# 5         2  40000
# 6         1  10000
# 7         2   5000
# 8         1  35000

# %%
dfdebra = gb_manager.get_group("Debra Henley")

# %%
dfdebra["Rep"].unique()
# Out:
# array(['Craig Booker', 'Daniel Hilton', 'John Smith'], dtype=object)

# %%
dfdebra
# Out:
#                            Name            Rep       Manager      Product  \
# 0               Trantow-Barrows   Craig Booker  Debra Henley          CPU
# 1               Trantow-Barrows   Craig Booker  Debra Henley     Software
# 2               Trantow-Barrows   Craig Booker  Debra Henley  Maintenance
# 3  Fritsch, Russel and Anderson   Craig Booker  Debra Henley          CPU
# 4                  Kiehn-Spinka  Daniel Hilton  Debra Henley          CPU
# 5                     Kulas Inc  Daniel Hilton  Debra Henley          CPU
# 6                     Kulas Inc  Daniel Hilton  Debra Henley     Software
# 7                 Jerde-Hilpert     John Smith  Debra Henley  Maintenance
# 8                    Barton LLC     John Smith  Debra Henley          CPU
#
#    Quantity  Price
# 0         1  30000
# 1         1  10000
# 2         2   5000
# 3         1  35000
# 4         2  65000
# 5         2  40000
# 6         1  10000
# 7         2   5000
# 8         1  35000

# %%
gb_rep = dfdebra.groupby("Rep")

# %%
for m, n in gb_rep:
    print(m)
    print("__________________")
    print()
    print(n)
    print()
    p = n["Price"].sum()
    print("Total Sales : ",p)
    print("********************************************")
    print()
# Out:
# Craig Booker
# __________________
#
#                            Name           Rep       Manager      Product  \
# 0               Trantow-Barrows  Craig Booker  Debra Henley          CPU
# 1               Trantow-Barrows  Craig Booker  Debra Henley     Software
# 2               Trantow-Barrows  Craig Booker  Debra Henley  Maintenance
# 3  Fritsch, Russel and Anderson  Craig Booker  Debra Henley          CPU
#
#    Quantity  Price
# 0         1  30000
# 1         1  10000
# 2         2   5000
# 3         1  35000
#
# Total Sales :  80000
# ********************************************
#
# Daniel Hilton
# __________________
#
#            Name            Rep       Manager   Product  Quantity  Price
# 4  Kiehn-Spinka  Daniel Hilton  Debra Henley       CPU         2  65000
# 5     Kulas Inc  Daniel Hilton  Debra Henley       CPU         2  40000
# 6     Kulas Inc  Daniel Hilton  Debra Henley  Software         1  10000
#
# Total Sales :  115000
# ...
