# %%
#PYTHON IS A VERY POPULAR SCRIPTING LANGUAGE. IT WAS CREATED BY BY GUIDO VAN ROSSUM IN THE LATE 1980S AND IT GOT RELASED IN 1991.
#PYTHON IS OFTEN USED IN A WIDE RANGE OF INDUSTRY PURPOSE (WEB DEV, DATA ANALYICS, DATA SCIENCE, AI)
#MAIN ADVANTAGE OF PYTHON IS, IT IS A OPEN SOURCE LANGUAGE

# %%
#WE CAN CODE PYTHON IN DIFFERENT DIFFERENT ENVIRONMENT.
# AWS, GOGGLE COLAB, ANACONDA (JUPYTER NOTEBOOK)

# %%
from platform import python_version
print(python_version())
# Out:
# 3.9.12

# %%
#addition
45+45
# Out:
# 90

# %%
#Multiplication
2*5
# Out:
# 10

# %%
#Power
A=2
B=5
C=A**B
C
# Out:
# 32

# %%
#Remainder
A=13
B=5
C=A%B
C
# Out:
# 3

# %%
#Quotient
A=21
B=3
C=A//B
C
# Out:
# 7

# %%
12+2
13+5
11+2
# Out:
# 13

# %%
#Use of print statement
print(12+4)
print(13+7)
# Out:
# 16
# 20

# %% [markdown]
# # Is python a case sensitive language?

# %%
Print(14+5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 Print(14+5)
#
# NameError: name 'Print' is not defined

# %% [markdown]
# # Naming convention of variables

# %%
#1- VARIABLE NAMES CAN ONLY CONTAIN LETTERS, NUMBERS, AND UNDERSCORES. THEY CANNOT CONTAIN SPACES OR SPECIAL CHARACTERS.
#2- VARIABLE NAMES MUST START WITH A LETTER OR UNDERSCORES. THEY CANNOT START WITH A NUMBER.
#3- AVIOD USING RESERVED KEYWORDS WHILE DEFINING A VARIABLE

# %%
x=21
print(x)
# Out:
# 21

# %%
x=21
print("x is 25")
# Out:
# x is 25

# %%
del x

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
1x=67
# Out:
#   Input In [17]
#     1x=67
#      ^
# SyntaxError: invalid syntax

# %%
1_x=61
# Out:
#   Input In [18]
#     1_x=61
#      ^
# SyntaxError: invalid decimal literal

# %%
x_1=34
print(x_1)
# Out:
# 34

# %% [markdown]
# # Data Structures

# %%
salary=120
print(type(salary))
# Out:
# <class 'int'>

# %%
salary1=120.54
type(salary1)
# Out:
# float

# %%
a= 100 + 250j
type(a)
# Out:
# complex

# %%
b=range(0,100)
type(b)
# Out:
# range

# %% [markdown]
# # Strings

# %%
name="DV analytics"

# %%
type(name)
# Out:
# str

# %%
#How to get the number of characters present in a string
len(name)
# Out:
# 12

# %% [markdown]
# # Slicing of strings

# %%
name="DV analytics"

# %%
#Positive indexing in python starts with zero from left and negative indexing starts with -1 from right.

# %%
name[0]
# Out:
# 'D'

# %%
name[6]
# Out:
# 'l'

# %%
name[2]
# Out:
# ' '

# %%
# (DV)
name[0:2]
# Out:
# 'DV'

# %%
name[0:4]
# Out:
# 'DV a'

# %%
name[6:9]
# Out:
# 'lyt'

# %%
name[:]
# Out:
# 'DV analytics'

# %%
#How to concatenate two strings
First_name= "Ganesh"
Last_name="Rath"
full_name= First_name + " "+ Last_name
full_name
# Out:
# 'Ganesh Rath'

# %% [markdown]
# # Boolean

# %%
x= 5 > 6
print(x)
# Out:
# False

# %%
type(x)
# Out:
# bool

# %%
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %% [markdown]
# # List

# %%
age=[18,23,34,45,56,67]

# %%
type(age)
# Out:
# list

# %%
cust1=["Ganesh",45,56,31,"Grace"]

# %%
type(cust1)
# Out:
# list

# %% [markdown]
# # Indexing in list

# %%
age=[18,23,34,45,56,67]

# %%
age[0:2]
# Out:
# [18, 23]

# %%
age[2:0]
# Out:
# []

# %%
age[1:4]
# Out:
# [23, 34, 45]

# %%
age[2:]
# Out:
# [34, 45, 56, 67]

# %%
age[-4:-2]
# Out:
# [34, 45]

# %%
age[3:]
# Out:
# [45, 56, 67]

# %%
age[-3:]
# Out:
# [45, 56, 67]

# %%
age[-2:]
# Out:
# [56, 67]

# %% [markdown]
# # Mutability of List

# %%
age
# Out:
# [18, 23, 34, 45, 56, 67]

# %%
age[1]=55

# %%
age
# Out:
# [18, 55, 34, 45, 56, 67]

# %%
#Append function
age.append(57)

# %%
age
# Out:
# [18, 55, 34, 45, 56, 67, 57]

# %%
age.append([55,66,67])
age
# Out:
# [18, 55, 34, 45, 56, 67, 57, [55, 66, 67]]

# %%
age2=[23,21,34,[55,61,67,78]]

# %%
age2[3][1]
# Out:
# 61

# %%
age2[3][-1]
# Out:
# 78

# %%
age
# Out:
# [18, 55, 34, 45, 56, 67, 57, [55, 66, 67]]

# %%
#Insert function
age.insert(2,88)

# %%
age
# Out:
# [18, 55, 88, 34, 45, 56, 67, 57, [55, 66, 67]]

# %% [markdown]
# # Tuples

# %%
cust_id=(23,34,56,77)

# %%
type(cust_id)
# Out:
# tuple

# %%
cust_id[1]=79
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 cust_id[1]=79
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Differences between list and tuples

# %%
#Tuples are immutable while list are mututable
#Copying any tuple n number of time would take lesser time than a copying a list n number of times
#Memory allocation of a tuple is lesser than a list

# %% [markdown]
# # Packing and unpacking of tuples

# %%
region= "E","W","N","S"

# %%
region
# Out:
# ('E', 'W', 'N', 'S')

# %%
type(region)
# Out:
# tuple

# %%
q1,q2,q3,q4= region

# %%
print(q2)
# Out:
# W

# %%
print(q3)
# Out:
# N

# %%
q1,q2=region
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 q1,q2=region
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # Dictionaries

# %%
city={1:"L.A",9:"P.A",7:"FL"}

# %%
type(city)
# Out:
# dict

# %%
city[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 city[0]
#
# KeyError: 0

# %%
city[1]
# Out:
# 'L.A'

# %%
city[7]
# Out:
# 'FL'

# %%
#Let us check if dictionaries are mutuable or not
city[1]="Mumbai"

# %%
city
# Out:
# {1: 'Mumbai', 9: 'P.A', 7: 'FL'}

# %%
#How to add a key and value pair to a dict
city[45]="Blr"

# %%
city
# Out:
# {1: 'Mumbai', 9: 'P.A', 7: 'FL', 45: 'Blr'}

# %%
del city[1]

# %%
city
# Out:
# {9: 'P.A', 7: 'FL', 45: 'Blr'}

# %% [markdown]
# # How create a table of our own

# %%
import pandas as pd

stu_enq_2023=pd.DataFrame ({'stu_id':['s1','s2','s3','s4','s5','s6'],
                           'stu_name':['divya','amit','sidharth','ravi','pragya','mohit'],
                           'gender':['female','male','male','male','female','male'],
                           'education':['mba','be','mca','mcom','mba','be'],
                           'date_of_enq':['23/02/2023','11/01/2023','23/03/2023','12/01/2023','01/08/2023','09/02/2023'],
                           'course':['mpids','mpids','mpaa','mpids','mpaa','mpaa']})
stu_enq_2023
# Out:
#   stu_id  stu_name  gender education date_of_enq course
# 0     s1     divya  female       mba  23/02/2023  mpids
# 1     s2      amit    male        be  11/01/2023  mpids
# 2     s3  sidharth    male       mca  23/03/2023   mpaa
# 3     s4      ravi    male      mcom  12/01/2023  mpids
# 4     s5    pragya  female       mba  01/08/2023   mpaa
# 5     s6     mohit    male        be  09/02/2023   mpaa

# %% [markdown]
# # Importing and exporting the datas

# %%
#Importing excel file
med_2022=pd.read_excel("E:\Python\SESSION-1\A2.RAW_DATA\MED_STORE_2022.xlsx",sheet_name="MED_AUS_DATA")
med_2022
# Out:
#       CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 0      1000032547      MED +  2006-09-12 00:00:00           Y
# 1      1000032548  DR.REDDYS  2006-09-12 00:00:00           Y
# 2      1000032549   RELEGARE  2006-09-12 00:00:00           Y
# 3      1000032550        GSK  2006-09-12 00:00:00           Y
# 4      1000032551        GSK  2006-09-12 00:00:00           Y
# ...           ...        ...                  ...         ...
# 5107   1000037830   RELEGARE  2008-05-06 00:00:00           Y
# 5108   1000037831     APPOLO  2008-05-06 00:00:00           Y
# 5109   1000037832        GSK  2008-05-06 00:00:00           Y
# 5110   1000037833      MED +  2008-05-06 00:00:00           Y
# 5111   1000037834    RANBAXY  2008-05-06 00:00:00           Y
#
#             FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 0     2007-05-12 00:00:00       2587  Mrs.  Female      56.31 1984-09-15  ...
# ...

# %%
#Import a text file
med_2022_t=pd.read_csv("E:\Python\SESSION-1\A2.RAW_DATA\MED_STORE_2022.txt",sep=',')
med_2022_t
# Out:
#       CUSTOMER_ID    Company     CARD_REG_DATE CARD_ACTIVE     FIRST_USE_DTE  \
# 0      1000032547      MED +  12-09-2006 00:00           Y  12-05-2007 00:00
# 1      1000032548  DR.REDDYS  12-09-2006 00:00           Y  12-03-2007 00:00
# 2      1000032549   RELEGARE  12-09-2006 00:00           Y  12-02-2007 00:00
# 3      1000032550        GSK  12-09-2006 00:00           Y  12-03-2007 00:00
# 4      1000032551        GSK  12-09-2006 00:00           Y  12-05-2007 00:00
# ...           ...        ...               ...         ...               ...
# 5107   1000037830   RELEGARE  06-05-2008 00:00           Y  02-05-2009 00:00
# 5108   1000037831     APPOLO  06-05-2008 00:00           Y  06-10-2008 00:00
# 5109   1000037832        GSK  06-05-2008 00:00           Y  04-05-2009 00:00
# 5110   1000037833      MED +  06-05-2008 00:00           Y  10-06-2009 00:00
# 5111   1000037834    RANBAXY  06-05-2008 00:00           Y  04-05-2009 00:00
#
# ...

# %%
#Exporting the data
med_2022_t.to_csv("E:\Python\SESSION-1\A4.OUTPUT\med_export_2022.txt",sep='|')

# %%
med_2022_t.to_excel("E:\Python\SESSION-1\A4.OUTPUT\med_export_2022_n.xlsx",sheet_name="xyz",index=None)

# %% [markdown]
# # How to copy a dataset to a new dataset

# %%
med_2022

med_new=med_2022

med_new
# Out:
#       CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 0      1000032547      MED +  2006-09-12 00:00:00           Y
# 1      1000032548  DR.REDDYS  2006-09-12 00:00:00           Y
# 2      1000032549   RELEGARE  2006-09-12 00:00:00           Y
# 3      1000032550        GSK  2006-09-12 00:00:00           Y
# 4      1000032551        GSK  2006-09-12 00:00:00           Y
# ...           ...        ...                  ...         ...
# 5107   1000037830   RELEGARE  2008-05-06 00:00:00           Y
# 5108   1000037831     APPOLO  2008-05-06 00:00:00           Y
# 5109   1000037832        GSK  2008-05-06 00:00:00           Y
# 5110   1000037833      MED +  2008-05-06 00:00:00           Y
# 5111   1000037834    RANBAXY  2008-05-06 00:00:00           Y
#
#             FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 0     2007-05-12 00:00:00       2587  Mrs.  Female      56.31 1984-09-15  ...
# ...

# %%
med_new1=med_2022.copy()
med_new1
# Out:
#       CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 0      1000032547      MED +  2006-09-12 00:00:00           Y
# 1      1000032548  DR.REDDYS  2006-09-12 00:00:00           Y
# 2      1000032549   RELEGARE  2006-09-12 00:00:00           Y
# 3      1000032550        GSK  2006-09-12 00:00:00           Y
# 4      1000032551        GSK  2006-09-12 00:00:00           Y
# ...           ...        ...                  ...         ...
# 5107   1000037830   RELEGARE  2008-05-06 00:00:00           Y
# 5108   1000037831     APPOLO  2008-05-06 00:00:00           Y
# 5109   1000037832        GSK  2008-05-06 00:00:00           Y
# 5110   1000037833      MED +  2008-05-06 00:00:00           Y
# 5111   1000037834    RANBAXY  2008-05-06 00:00:00           Y
#
#             FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 0     2007-05-12 00:00:00       2587  Mrs.  Female      56.31 1984-09-15  ...
# ...

# %% [markdown]
# # HOW TO CREATE A NEW DATASET FROM AN EXISTING DATASET BY SELECTING ONLY FEW VARIABLES

# %%
med_2022.columns.values
# Out:
# array(['CUSTOMER_ID', 'Company', 'CARD_REG_DATE', 'CARD_ACTIVE',
#        'FIRST_USE_DTE', 'firstSTOR', 'TITLE', 'GENDER', 'max spent',
#        'DOB', 'FTD', 'Age', 'STATE_CODE', 'POST_CODE', 'CUST_STAT',
#        'Avgsize spent', 'CARD_STAT', 'RGSTN_TYPE_IND', 'NO_OF_TRIPS',
#        'TOWN', 'EMAIL_IND', 'CONTACT_PREF', 'Average_Qty_PER_ACC',
#        'Spent amount'], dtype=object)

# %%
med_2023=med_2022[["CUSTOMER_ID",'Company']]
med_2023
# Out:
#       CUSTOMER_ID    Company
# 0      1000032547      MED +
# 1      1000032548  DR.REDDYS
# 2      1000032549   RELEGARE
# 3      1000032550        GSK
# 4      1000032551        GSK
# ...           ...        ...
# 5107   1000037830   RELEGARE
# 5108   1000037831     APPOLO
# 5109   1000037832        GSK
# 5110   1000037833      MED +
# 5111   1000037834    RANBAXY
#
# [5112 rows x 2 columns]

# %% [markdown]
# # HOW TO DROP VARIABLES TO CREATE A NEW DATASET FROM AN EXISTING DATASET

# %%
drop_var=["CUSTOMER_ID","Company"]
med_2023_v1=med_2022.drop(drop_var,axis=1)
med_2023_v1
# Out:
#             CARD_REG_DATE CARD_ACTIVE        FIRST_USE_DTE  firstSTOR TITLE  \
# 0     2006-09-12 00:00:00           Y  2007-05-12 00:00:00       2587  Mrs.
# 1     2006-09-12 00:00:00           Y  2007-03-12 00:00:00       4341   Ms.
# 2     2006-09-12 00:00:00           Y  2007-02-12 00:00:00       1090  Mrs.
# 3     2006-09-12 00:00:00           Y  2007-03-12 00:00:00       3179   Mr.
# 4     2006-09-12 00:00:00           Y  2007-05-12 00:00:00       3135   Mr.
# ...                   ...         ...                  ...        ...   ...
# 5107  2008-05-06 00:00:00           Y  2009-05-02 00:00:00       3381   Mr.
# 5108  2008-05-06 00:00:00           Y  2008-10-06 00:00:00       3244  Mrs.
# 5109  2008-05-06 00:00:00           Y  2009-05-04 00:00:00       3381  Mrs.
# 5110  2008-05-06 00:00:00           Y  2009-06-10 00:00:00       3130   Ms.
# 5111  2008-05-06 00:00:00           Y  2009-05-04 00:00:00       3363  Mrs.
#
# ...

# %% [markdown]
# # How to describe a dataset

# %%
med_2022
# Out:
#       CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 0      1000032547      MED +  2006-09-12 00:00:00           Y
# 1      1000032548  DR.REDDYS  2006-09-12 00:00:00           Y
# 2      1000032549   RELEGARE  2006-09-12 00:00:00           Y
# 3      1000032550        GSK  2006-09-12 00:00:00           Y
# 4      1000032551        GSK  2006-09-12 00:00:00           Y
# ...           ...        ...                  ...         ...
# 5107   1000037830   RELEGARE  2008-05-06 00:00:00           Y
# 5108   1000037831     APPOLO  2008-05-06 00:00:00           Y
# 5109   1000037832        GSK  2008-05-06 00:00:00           Y
# 5110   1000037833      MED +  2008-05-06 00:00:00           Y
# 5111   1000037834    RANBAXY  2008-05-06 00:00:00           Y
#
#             FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 0     2007-05-12 00:00:00       2587  Mrs.  Female      56.31 1984-09-15  ...
# ...

# %%
med_2022.shape
# Out:
# (5112, 24)

# %%
med_2022.head(10)
# Out:
#    CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 0   1000032547      MED +  2006-09-12 00:00:00           Y
# 1   1000032548  DR.REDDYS  2006-09-12 00:00:00           Y
# 2   1000032549   RELEGARE  2006-09-12 00:00:00           Y
# 3   1000032550        GSK  2006-09-12 00:00:00           Y
# 4   1000032551        GSK  2006-09-12 00:00:00           Y
# 5   1000032552     APPOLO  2007-07-09 00:00:00           Y
# 6   1000032553      CIPLA  2006-09-12 00:00:00           Y
# 7   1000032554     APPOLO  2006-09-12 00:00:00           Y
# 8   1000032555     APPOLO  2006-09-12 00:00:00           Y
# 9   1000032556      MED +  2006-09-12 00:00:00           Y
#
#          FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 0  2007-05-12 00:00:00       2587  Mrs.  Female      56.31 1984-09-15  ...
# 1  2007-03-12 00:00:00       4341   Ms.  Female     598.95 1974-07-15  ...
# 2  2007-02-12 00:00:00       1090  Mrs.  Female       1.56 1959-04-01  ...
# ...

# %%
med_2022.tail(15)
# Out:
#       CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 5097   1000037820       GENO  2008-05-06 00:00:00           Y
# 5098   1000037821        GSK  2008-05-06 00:00:00           Y
# 5099   1000037822  DR.REDDYS  2008-05-06 00:00:00           Y
# 5100   1000037823      CIPLA  2008-05-06 00:00:00           Y
# 5101   1000037824        GSK  2008-05-06 00:00:00           Y
# 5102   1000037825   GUARDIAN  2008-05-06 00:00:00           Y
# 5103   1000037826     APPOLO  2008-05-06 00:00:00           Y
# 5104   1000037827  DR.REDDYS  2008-05-06 00:00:00           Y
# 5105   1000037828        GSK  2008-05-06 00:00:00           Y
# 5106   1000037829       GENO  2008-05-06 00:00:00           Y
# 5107   1000037830   RELEGARE  2008-05-06 00:00:00           Y
# 5108   1000037831     APPOLO  2008-05-06 00:00:00           Y
# 5109   1000037832        GSK  2008-05-06 00:00:00           Y
# 5110   1000037833      MED +  2008-05-06 00:00:00           Y
# ...

# %%
med_2022.dtypes
# Out:
# CUSTOMER_ID                     int64
# Company                        object
# CARD_REG_DATE                  object
# CARD_ACTIVE                    object
# FIRST_USE_DTE                  object
# firstSTOR                       int64
# TITLE                          object
# GENDER                         object
# max spent                     float64
# DOB                    datetime64[ns]
# FTD                            object
# Age                             int64
# STATE_CODE                     object
# POST_CODE                       int64
# CUST_STAT                      object
# Avgsize spent                 float64
# CARD_STAT                      object
# RGSTN_TYPE_IND                 object
# NO_OF_TRIPS                     int64
# TOWN                           object
# EMAIL_IND                      object
# CONTACT_PREF                   object
# Average_Qty_PER_ACC           float64
# Spent amount                  float64
# dtype: object

# %%
med_2022.describe()
# Out:
#         CUSTOMER_ID   firstSTOR     max spent          Age    POST_CODE  \
# count  5.112000e+03  5112.00000   5097.000000  5112.000000  5112.000000
# mean   1.000035e+09  2909.16471    296.052700    50.214397  4245.047340
# std    1.516922e+03  1037.71011    364.136141    14.950142  1472.169558
# min    1.000033e+09  1008.00000      1.560000    20.000000     3.000000
# 25%    1.000034e+09  2558.00000     78.830000    39.000000  2902.000000
# 50%    1.000035e+09  2700.00000    183.240000    50.000000  4211.000000
# 75%    1.000037e+09  3271.00000    392.720000    62.000000  6020.000000
# max    1.000038e+09  5739.00000  11727.670000    84.000000  6992.000000
#
#        Avgsize spent  NO_OF_TRIPS  Average_Qty_PER_ACC  Spent amount
# count    5112.000000  5112.000000          5112.000000   5112.000000
# mean       68.308355     5.308881            19.300788    324.115914
# std        54.531575     5.676040            15.424253    385.269245
# ...

# %%
med_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5112 entries, 0 to 5111
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CUSTOMER_ID          5112 non-null   int64
#  1   Company              5112 non-null   object
#  2   CARD_REG_DATE        5112 non-null   object
#  3   CARD_ACTIVE          5112 non-null   object
#  4   FIRST_USE_DTE        5112 non-null   object
#  5   firstSTOR            5112 non-null   int64
#  6   TITLE                5112 non-null   object
#  7   GENDER               5112 non-null   object
#  8   max spent            5097 non-null   float64
#  9   DOB                  5112 non-null   datetime64[ns]
#  10  FTD                  5112 non-null   object
#  11  Age                  5112 non-null   int64
#  12  STATE_CODE           5112 non-null   object
#  13  POST_CODE            5112 non-null   int64
#  14  CUST_STAT            5112 non-null   object
# ...

# %%
med_2022.isnull().sum()
# Out:
# CUSTOMER_ID              0
# Company                  0
# CARD_REG_DATE            0
# CARD_ACTIVE              0
# FIRST_USE_DTE            0
# firstSTOR                0
# TITLE                    0
# GENDER                   0
# max spent               15
# DOB                      0
# FTD                      0
# Age                      0
# STATE_CODE               0
# POST_CODE                0
# CUST_STAT                0
# Avgsize spent            0
# CARD_STAT                0
# RGSTN_TYPE_IND           0
# NO_OF_TRIPS              0
# TOWN                     0
# EMAIL_IND                0
# CONTACT_PREF           893
# Average_Qty_PER_ACC      0
# Spent amount             0
# dtype: int64

# %%
med_2022.isnull().sum().sum()
# Out:
# 908

# %%
med_2022[100:201]
# Out:
#      CUSTOMER_ID    Company        CARD_REG_DATE CARD_ACTIVE  \
# 100   1000032647  DR.REDDYS    1/31/2008 0:00:00           Y
# 101   1000032648   GUARDIAN    1/31/2008 0:00:00           Y
# 102   1000032649    RANBAXY    1/31/2008 0:00:00           Y
# 103   1000032650   RELEGARE    1/31/2008 0:00:00           Y
# 104   1000032651      CIPLA    1/31/2008 0:00:00           Y
# ..           ...        ...                  ...         ...
# 196   1000032830  DR.REDDYS    2/28/2008 0:00:00           Y
# 197   1000032831   GUARDIAN    2/29/2008 0:00:00           Y
# 198   1000032832      MED +  2008-03-05 00:00:00           Y
# 199   1000032833   RELEGARE  2008-03-05 00:00:00           Y
# 200   1000032834   GUARDIAN  2008-03-05 00:00:00           Y
#
#            FIRST_USE_DTE  firstSTOR TITLE  GENDER  max spent        DOB  ...  \
# 100  2009-03-01 00:00:00       5646  Miss  Female     274.29 1982-11-01  ...
# ...
