# %%
import pandas as pd

# %%
import numpy as np

# %%
dfgen = pd.read_csv(r"C:/Users/hp/Desktop/DATASETS/Datasets/Groupby/Gb_gender.csv")

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
gb_gen = dfgen.groupby("Gender")

# %%
gb_gen

# %%
gb_gen.groups
# Out:
# {'Female': [1, 2, 6, 7, 8, 10, 12, 13, 17, 18, 19, 21, 22, 28, 29, 30, 32, 34, 35, 39, 40, 41, 42, 44, 46, 47, 51, 52, 53, 55, 56, 62, 63, 64, 66, 68, 70, 71, 73, 75, 76, 78], 'Male': [0, 3, 4, 5, 9, 11, 14, 15, 16, 20, 23, 24, 25, 26, 27, 31, 33, 36, 37, 38, 43, 45, 48, 49, 50, 54, 57, 58, 59, 60, 61, 65, 67, 69, 72, 74, 77, 79, 80]}

# %%
dfgen.head(10)
# Out:
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 1  Female  B.Tech     167     Chennai
# 2  Female     B.E     169       Vizag
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 6  Female  M.Tech     172     Lucknow
# 7  Female     MCA     172      Bhopal
# 8  Female    B.Sc     179   Bangalore
# 9    Male  B.Tech     166   Hyderabad

# %%
for i in gb_gen:
    print(i)
# Out:
# ('Female',     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# 44  Female     B.E     178      Bhopal
# 46  Female     MBA     172   Hyderabad
# 47  Female    M.Sc     179       Delhi
# 51  Female     MBA     174      Bhopal
# 52  Female    M.Sc     168   Bangalore
# 53  Female  M.Tech     166   Hyderabad
# 55  Female    B.Sc     166       Vizag
# 56  Female  B.Tech     178       Delhi
# 62  Female  M.Tech     173      Jaipur
# 63  Female     MCA     175  Chandigarh
# 64  Female    B.Sc     173     Lucknow
# 66  Female     B.E     178   Hyderabad
# 68  Female     MBA     172   Hyderabad
# 70  Female  M.Tech     179   Hyderabad
# 71  Female     MCA     175       Delhi
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 76  Female    B.Sc     176   Hyderabad
# 78  Female    B.Sc     178   Hyderabad)
# ('Male',    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 9    Male  B.Tech     166   Hyderabad
# 11   Male   B.Com     176       Vizag
# 14   Male  M.Tech     166  Chandigarh
# 15   Male     MCA     175     Lucknow
# 16   Male   B.Com     166      Bhopal
# 20   Male     MCA     171  Chandigarh
# 23   Male     B.E     173   Bangalore
# 24   Male   B.Com     175   Hyderabad
# 25   Male   B.Com     173       Delhi
# 26   Male     MBA     177      Jaipur
# 27   Male    M.Sc     178  Chandigarh
# 31   Male  B.Tech     173   Hyderabad
# 33   Male   B.Com     174       Vizag
# 36   Male  M.Tech     175  Chandigarh
# 37   Male     MCA     166     Lucknow
# 38   Male   B.Com     178      Bhopal
# 43   Male  B.Tech     177     Lucknow
# 45   Male   B.Com     172   Bangalore
# 48   Male  M.Tech     166      Jaipur
# 49   Male     MCA     173  Chandigarh
# 50   Male   B.Com     176     Lucknow
# 54   Male     MCA     175     Chennai
# 57   Male     B.E     175      Jaipur
# 58   Male   B.Com     177   Bangalore
# 59   Male   B.Com     171   Hyderabad
# 60   Male     MBA     171   Hyderabad
# 61   Male    M.Sc     167       Vizag
# 65   Male  B.Tech     177      Bhopal
# 67   Male   B.Com     172     Chennai
# 69   Male    M.Sc     177      Bhopal
# 72   Male   B.Com     178      Jaipur
# 74   Male    M.Sc     178       Vizag
# 77   Male     MCA     178     Chennai
# 79   Male  B.Tech     174  Chandigarh
# 80   Male  M.Tech     175     Lucknow)

# %%
for x, y in gb_gen:
    print(x)
    print("__________________")
    print()
    print(y)
    print()
    print("********************************************")
    print()
# Out:
# Female
# __________________
#
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# 44  Female     B.E     178      Bhopal
# 46  Female     MBA     172   Hyderabad
# 47  Female    M.Sc     179       Delhi
# 51  Female     MBA     174      Bhopal
# 52  Female    M.Sc     168   Bangalore
# 53  Female  M.Tech     166   Hyderabad
# 55  Female    B.Sc     166       Vizag
# 56  Female  B.Tech     178       Delhi
# 62  Female  M.Tech     173      Jaipur
# 63  Female     MCA     175  Chandigarh
# 64  Female    B.Sc     173     Lucknow
# 66  Female     B.E     178   Hyderabad
# 68  Female     MBA     172   Hyderabad
# 70  Female  M.Tech     179   Hyderabad
# 71  Female     MCA     175       Delhi
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 76  Female    B.Sc     176   Hyderabad
# 78  Female    B.Sc     178   Hyderabad
#
# ********************************************
#
# Male
# __________________
#
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 9    Male  B.Tech     166   Hyderabad
# 11   Male   B.Com     176       Vizag
# 14   Male  M.Tech     166  Chandigarh
# 15   Male     MCA     175     Lucknow
# 16   Male   B.Com     166      Bhopal
# 20   Male     MCA     171  Chandigarh
# 23   Male     B.E     173   Bangalore
# 24   Male   B.Com     175   Hyderabad
# 25   Male   B.Com     173       Delhi
# 26   Male     MBA     177      Jaipur
# 27   Male    M.Sc     178  Chandigarh
# 31   Male  B.Tech     173   Hyderabad
# 33   Male   B.Com     174       Vizag
# 36   Male  M.Tech     175  Chandigarh
# 37   Male     MCA     166     Lucknow
# 38   Male   B.Com     178      Bhopal
# 43   Male  B.Tech     177     Lucknow
# 45   Male   B.Com     172   Bangalore
# 48   Male  M.Tech     166      Jaipur
# 49   Male     MCA     173  Chandigarh
# 50   Male   B.Com     176     Lucknow
# 54   Male     MCA     175     Chennai
# 57   Male     B.E     175      Jaipur
# 58   Male   B.Com     177   Bangalore
# 59   Male   B.Com     171   Hyderabad
# 60   Male     MBA     171   Hyderabad
# 61   Male    M.Sc     167       Vizag
# 65   Male  B.Tech     177      Bhopal
# 67   Male   B.Com     172     Chennai
# 69   Male    M.Sc     177      Bhopal
# 72   Male   B.Com     178      Jaipur
# 74   Male    M.Sc     178       Vizag
# 77   Male     MCA     178     Chennai
# 79   Male  B.Tech     174  Chandigarh
# 80   Male  M.Tech     175     Lucknow
#
# ********************************************

# %%
gb_gen.get_group("Female")
# Out:
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# 44  Female     B.E     178      Bhopal
# 46  Female     MBA     172   Hyderabad
# 47  Female    M.Sc     179       Delhi
# 51  Female     MBA     174      Bhopal
# 52  Female    M.Sc     168   Bangalore
# 53  Female  M.Tech     166   Hyderabad
# 55  Female    B.Sc     166       Vizag
# 56  Female  B.Tech     178       Delhi
# 62  Female  M.Tech     173      Jaipur
# 63  Female     MCA     175  Chandigarh
# 64  Female    B.Sc     173     Lucknow
# 66  Female     B.E     178   Hyderabad
# 68  Female     MBA     172   Hyderabad
# 70  Female  M.Tech     179   Hyderabad
# 71  Female     MCA     175       Delhi
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 76  Female    B.Sc     176   Hyderabad
# 78  Female    B.Sc     178   Hyderabad

# %%
dffemale = gb_gen.get_group("Female")

# %%
dffemale
# Out:
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# 44  Female     B.E     178      Bhopal
# 46  Female     MBA     172   Hyderabad
# 47  Female    M.Sc     179       Delhi
# 51  Female     MBA     174      Bhopal
# 52  Female    M.Sc     168   Bangalore
# 53  Female  M.Tech     166   Hyderabad
# 55  Female    B.Sc     166       Vizag
# 56  Female  B.Tech     178       Delhi
# 62  Female  M.Tech     173      Jaipur
# 63  Female     MCA     175  Chandigarh
# 64  Female    B.Sc     173     Lucknow
# 66  Female     B.E     178   Hyderabad
# 68  Female     MBA     172   Hyderabad
# 70  Female  M.Tech     179   Hyderabad
# 71  Female     MCA     175       Delhi
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 76  Female    B.Sc     176   Hyderabad
# 78  Female    B.Sc     178   Hyderabad

# %%
gb_gen.get_group("Male")
# Out:
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 9    Male  B.Tech     166   Hyderabad
# 11   Male   B.Com     176       Vizag
# 14   Male  M.Tech     166  Chandigarh
# 15   Male     MCA     175     Lucknow
# 16   Male   B.Com     166      Bhopal
# 20   Male     MCA     171  Chandigarh
# 23   Male     B.E     173   Bangalore
# 24   Male   B.Com     175   Hyderabad
# 25   Male   B.Com     173       Delhi
# 26   Male     MBA     177      Jaipur
# 27   Male    M.Sc     178  Chandigarh
# 31   Male  B.Tech     173   Hyderabad
# 33   Male   B.Com     174       Vizag
# 36   Male  M.Tech     175  Chandigarh
# 37   Male     MCA     166     Lucknow
# 38   Male   B.Com     178      Bhopal
# 43   Male  B.Tech     177     Lucknow
# 45   Male   B.Com     172   Bangalore
# 48   Male  M.Tech     166      Jaipur
# 49   Male     MCA     173  Chandigarh
# 50   Male   B.Com     176     Lucknow
# 54   Male     MCA     175     Chennai
# 57   Male     B.E     175      Jaipur
# 58   Male   B.Com     177   Bangalore
# 59   Male   B.Com     171   Hyderabad
# 60   Male     MBA     171   Hyderabad
# 61   Male    M.Sc     167       Vizag
# 65   Male  B.Tech     177      Bhopal
# 67   Male   B.Com     172     Chennai
# 69   Male    M.Sc     177      Bhopal
# 72   Male   B.Com     178      Jaipur
# 74   Male    M.Sc     178       Vizag
# 77   Male     MCA     178     Chennai
# 79   Male  B.Tech     174  Chandigarh
# 80   Male  M.Tech     175     Lucknow

# %%
dfmale = gb_gen.get_group("Male")

# %%
dfmale
# Out:
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 9    Male  B.Tech     166   Hyderabad
# 11   Male   B.Com     176       Vizag
# 14   Male  M.Tech     166  Chandigarh
# 15   Male     MCA     175     Lucknow
# 16   Male   B.Com     166      Bhopal
# 20   Male     MCA     171  Chandigarh
# 23   Male     B.E     173   Bangalore
# 24   Male   B.Com     175   Hyderabad
# 25   Male   B.Com     173       Delhi
# 26   Male     MBA     177      Jaipur
# 27   Male    M.Sc     178  Chandigarh
# 31   Male  B.Tech     173   Hyderabad
# 33   Male   B.Com     174       Vizag
# 36   Male  M.Tech     175  Chandigarh
# 37   Male     MCA     166     Lucknow
# 38   Male   B.Com     178      Bhopal
# 43   Male  B.Tech     177     Lucknow
# 45   Male   B.Com     172   Bangalore
# 48   Male  M.Tech     166      Jaipur
# 49   Male     MCA     173  Chandigarh
# 50   Male   B.Com     176     Lucknow
# 54   Male     MCA     175     Chennai
# 57   Male     B.E     175      Jaipur
# 58   Male   B.Com     177   Bangalore
# 59   Male   B.Com     171   Hyderabad
# 60   Male     MBA     171   Hyderabad
# 61   Male    M.Sc     167       Vizag
# 65   Male  B.Tech     177      Bhopal
# 67   Male   B.Com     172     Chennai
# 69   Male    M.Sc     177      Bhopal
# 72   Male   B.Com     178      Jaipur
# 74   Male    M.Sc     178       Vizag
# 77   Male     MCA     178     Chennai
# 79   Male  B.Tech     174  Chandigarh
# 80   Male  M.Tech     175     Lucknow

# %%
dffemale
# Out:
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# 44  Female     B.E     178      Bhopal
# 46  Female     MBA     172   Hyderabad
# 47  Female    M.Sc     179       Delhi
# 51  Female     MBA     174      Bhopal
# 52  Female    M.Sc     168   Bangalore
# 53  Female  M.Tech     166   Hyderabad
# 55  Female    B.Sc     166       Vizag
# 56  Female  B.Tech     178       Delhi
# 62  Female  M.Tech     173      Jaipur
# 63  Female     MCA     175  Chandigarh
# 64  Female    B.Sc     173     Lucknow
# 66  Female     B.E     178   Hyderabad
# 68  Female     MBA     172   Hyderabad
# 70  Female  M.Tech     179   Hyderabad
# 71  Female     MCA     175       Delhi
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 76  Female    B.Sc     176   Hyderabad
# 78  Female    B.Sc     178   Hyderabad

# %%
dffemale["Height"]
# Out:
# 1     167
# 2     169
# 6     172
# 7     172
# 8     179
# 10    173
# 12    174
# 13    168
# 17    178
# 18    175
# 19    177
# 21    171
# 22    167
# 28    172
# 29    172
# 30    166
# 32    176
# 34    168
# 35    166
# 39    175
# 40    177
# 41    171
# 42    173
# 44    178
# 46    172
# 47    179
# 51    174
# 52    168
# 53    166
# 55    166
# 56    178
# 62    173
# 63    175
# 64    173
# 66    178
# 68    172
# 70    179
# 71    175
# 73    179
# 75    179
# 76    176
# 78    178
# Name: Height, dtype: int64

# %%
dffemale["Height"].max()
# Out:
# 179

# %%
dffemale["Height"]
# Out:
# 1     167
# 2     169
# 6     172
# 7     172
# 8     179
# 10    173
# 12    174
# 13    168
# 17    178
# 18    175
# 19    177
# 21    171
# 22    167
# 28    172
# 29    172
# 30    166
# 32    176
# 34    168
# 35    166
# 39    175
# 40    177
# 41    171
# 42    173
# 44    178
# 46    172
# 47    179
# 51    174
# 52    168
# 53    166
# 55    166
# 56    178
# 62    173
# 63    175
# 64    173
# 66    178
# 68    172
# 70    179
# 71    175
# 73    179
# 75    179
# 76    176
# 78    178
# Name: Height, dtype: int64

# %%
dffemale["Height"] == dffemale["Height"].max()
# Out:
# 1     False
# 2     False
# 6     False
# 7     False
# 8      True
# 10    False
# 12    False
# 13    False
# 17    False
# 18    False
# 19    False
# 21    False
# 22    False
# 28    False
# 29    False
# 30    False
# 32    False
# 34    False
# 35    False
# 39    False
# 40    False
# 41    False
# 42    False
# 44    False
# 46    False
# 47     True
# 51    False
# 52    False
# 53    False
# 55    False
# 56    False
# 62    False
# 63    False
# 64    False
# 66    False
# 68    False
# 70     True
# 71    False
# 73     True
# 75     True
# 76    False
# 78    False
# Name: Height, dtype: bool

# %%
filt = dffemale["Height"] == dffemale["Height"].max()   # 179

# %%
filt
# Out:
# 1     False
# 2     False
# 6     False
# 7     False
# 8      True
# 10    False
# 12    False
# 13    False
# 17    False
# 18    False
# 19    False
# 21    False
# 22    False
# 28    False
# 29    False
# 30    False
# 32    False
# 34    False
# 35    False
# 39    False
# 40    False
# 41    False
# 42    False
# 44    False
# 46    False
# 47     True
# 51    False
# 52    False
# 53    False
# 55    False
# 56    False
# 62    False
# 63    False
# 64    False
# 66    False
# 68    False
# 70     True
# 71    False
# 73     True
# 75     True
# 76    False
# 78    False
# Name: Height, dtype: bool

# %%
dffemale[ filt]
# Out:
#     Gender  Degree  Height       City
# 8   Female    B.Sc     179  Bangalore
# 47  Female    M.Sc     179      Delhi
# 70  Female  M.Tech     179  Hyderabad
# 73  Female     MBA     179     Bhopal
# 75  Female  M.Tech     179      Vizag

# %%
dffinal1 = dffemale[ filt]

# %%
dfmale
# Out:
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 9    Male  B.Tech     166   Hyderabad
# 11   Male   B.Com     176       Vizag
# 14   Male  M.Tech     166  Chandigarh
# 15   Male     MCA     175     Lucknow
# 16   Male   B.Com     166      Bhopal
# 20   Male     MCA     171  Chandigarh
# 23   Male     B.E     173   Bangalore
# 24   Male   B.Com     175   Hyderabad
# 25   Male   B.Com     173       Delhi
# 26   Male     MBA     177      Jaipur
# 27   Male    M.Sc     178  Chandigarh
# 31   Male  B.Tech     173   Hyderabad
# 33   Male   B.Com     174       Vizag
# 36   Male  M.Tech     175  Chandigarh
# 37   Male     MCA     166     Lucknow
# 38   Male   B.Com     178      Bhopal
# 43   Male  B.Tech     177     Lucknow
# 45   Male   B.Com     172   Bangalore
# 48   Male  M.Tech     166      Jaipur
# 49   Male     MCA     173  Chandigarh
# 50   Male   B.Com     176     Lucknow
# 54   Male     MCA     175     Chennai
# 57   Male     B.E     175      Jaipur
# 58   Male   B.Com     177   Bangalore
# 59   Male   B.Com     171   Hyderabad
# 60   Male     MBA     171   Hyderabad
# 61   Male    M.Sc     167       Vizag
# 65   Male  B.Tech     177      Bhopal
# 67   Male   B.Com     172     Chennai
# 69   Male    M.Sc     177      Bhopal
# 72   Male   B.Com     178      Jaipur
# 74   Male    M.Sc     178       Vizag
# 77   Male     MCA     178     Chennai
# 79   Male  B.Tech     174  Chandigarh
# 80   Male  M.Tech     175     Lucknow

# %%
dfmale["Height"].max()
# Out:
# 178

# %%
dfmale["Height"] == dfmale["Height"].max()
# Out:
# 0     False
# 3     False
# 4     False
# 5      True
# 9     False
# 11    False
# 14    False
# 15    False
# 16    False
# 20    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 31    False
# 33    False
# 36    False
# 37    False
# 38     True
# 43    False
# 45    False
# 48    False
# 49    False
# 50    False
# 54    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 65    False
# 67    False
# 69    False
# 72     True
# 74     True
# 77     True
# 79    False
# 80    False
# Name: Height, dtype: bool

# %%
dfmale[dfmale["Height"] == dfmale["Height"].max()]
# Out:
#    Gender Degree  Height        City
# 5    Male   M.Sc     178  Chandigarh
# 27   Male   M.Sc     178  Chandigarh
# 38   Male  B.Com     178      Bhopal
# 72   Male  B.Com     178      Jaipur
# 74   Male   M.Sc     178       Vizag
# 77   Male    MCA     178     Chennai

# %%
dffinal2 =  dfmale[dfmale["Height"] == dfmale["Height"].max()]

# %%
dffinal1
# Out:
#     Gender  Degree  Height       City
# 8   Female    B.Sc     179  Bangalore
# 47  Female    M.Sc     179      Delhi
# 70  Female  M.Tech     179  Hyderabad
# 73  Female     MBA     179     Bhopal
# 75  Female  M.Tech     179      Vizag

# %%
dffinal2
# Out:
#    Gender Degree  Height        City
# 5    Male   M.Sc     178  Chandigarh
# 27   Male   M.Sc     178  Chandigarh
# 38   Male  B.Com     178      Bhopal
# 72   Male  B.Com     178      Jaipur
# 74   Male   M.Sc     178       Vizag
# 77   Male    MCA     178     Chennai

# %%
pd.concat([dffinal1, dffinal2])
# Out:
#     Gender  Degree  Height        City
# 8   Female    B.Sc     179   Bangalore
# 47  Female    M.Sc     179       Delhi
# 70  Female  M.Tech     179   Hyderabad
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 5     Male    M.Sc     178  Chandigarh
# 27    Male    M.Sc     178  Chandigarh
# 38    Male   B.Com     178      Bhopal
# 72    Male   B.Com     178      Jaipur
# 74    Male    M.Sc     178       Vizag
# 77    Male     MCA     178     Chennai

# %%
dfselected = pd.concat([dffinal1, dffinal2])

# %%
dfselected
# Out:
#     Gender  Degree  Height        City
# 8   Female    B.Sc     179   Bangalore
# 47  Female    M.Sc     179       Delhi
# 70  Female  M.Tech     179   Hyderabad
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 5     Male    M.Sc     178  Chandigarh
# 27    Male    M.Sc     178  Chandigarh
# 38    Male   B.Com     178      Bhopal
# 72    Male   B.Com     178      Jaipur
# 74    Male    M.Sc     178       Vizag
# 77    Male     MCA     178     Chennai

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
dfgen["City"].unique()
# Out:
# array(['Hyderabad', 'Chennai', 'Vizag', 'Delhi', 'Jaipur', 'Chandigarh',
#        'Lucknow', 'Bhopal', 'Bangalore'], dtype=object)

# %%
dfgen["City"].nunique()
# Out:
# 9

# %%
dfgen["City"].value_counts()
# Out:
# Hyderabad     13
# Jaipur        10
# Bhopal        10
# Vizag          9
# Delhi          9
# Chandigarh     9
# Lucknow        9
# Chennai        6
# Bangalore      6
# Name: City, dtype: int64

# %%
dfgen["City"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###  Group by based on two columns

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
gb_gc = dfgen.groupby(["Gender","City"])

# %%
gb_gc

# %%
gb_gc.groups
# Out:
# {('Female', 'Bangalore'): [8, 30, 52], ('Female', 'Bhopal'): [7, 22, 29, 44, 51, 73], ('Female', 'Chandigarh'): [42, 63], ('Female', 'Chennai'): [1, 10, 32], ('Female', 'Delhi'): [12, 18, 34, 40, 47, 56, 71], ('Female', 'Hyderabad'): [46, 53, 66, 68, 70, 76, 78], ('Female', 'Jaipur'): [13, 19, 35, 41, 62], ('Female', 'Lucknow'): [6, 21, 28, 64], ('Female', 'Vizag'): [2, 17, 39, 55, 75], ('Male', 'Bangalore'): [23, 45, 58], ('Male', 'Bhopal'): [16, 38, 65, 69], ('Male', 'Chandigarh'): [5, 14, 20, 27, 36, 49, 79], ('Male', 'Chennai'): [54, 67, 77], ('Male', 'Delhi'): [3, 25], ('Male', 'Hyderabad'): [0, 9, 24, 31, 59, 60], ('Male', 'Jaipur'): [4, 26, 48, 57, 72], ('Male', 'Lucknow'): [15, 37, 43, 50, 80], ('Male', 'Vizag'): [11, 33, 61, 74]}

# %%
gb_cg = dfgen.groupby(["City", "Gender"])

# %%
gb_cg.groups
# Out:
# {('Bangalore', 'Female'): [8, 30, 52], ('Bangalore', 'Male'): [23, 45, 58], ('Bhopal', 'Female'): [7, 22, 29, 44, 51, 73], ('Bhopal', 'Male'): [16, 38, 65, 69], ('Chandigarh', 'Female'): [42, 63], ('Chandigarh', 'Male'): [5, 14, 20, 27, 36, 49, 79], ('Chennai', 'Female'): [1, 10, 32], ('Chennai', 'Male'): [54, 67, 77], ('Delhi', 'Female'): [12, 18, 34, 40, 47, 56, 71], ('Delhi', 'Male'): [3, 25], ('Hyderabad', 'Female'): [46, 53, 66, 68, 70, 76, 78], ('Hyderabad', 'Male'): [0, 9, 24, 31, 59, 60], ('Jaipur', 'Female'): [13, 19, 35, 41, 62], ('Jaipur', 'Male'): [4, 26, 48, 57, 72], ('Lucknow', 'Female'): [6, 21, 28, 64], ('Lucknow', 'Male'): [15, 37, 43, 50, 80], ('Vizag', 'Female'): [2, 17, 39, 55, 75], ('Vizag', 'Male'): [11, 33, 61, 74]}

# %%
for a, b in gb_gc :
    print(a)
    print("__________________")
    print()
    print(b)
    print()
    print("********************************************")
    print()
# Out:
# ('Female', 'Bangalore')
# __________________
#
#     Gender Degree  Height       City
# 8   Female   B.Sc     179  Bangalore
# 30  Female   B.Sc     166  Bangalore
# 52  Female   M.Sc     168  Bangalore
#
# ********************************************
#
# ('Female', 'Bhopal')
# __________________
#
#     Gender  Degree  Height    City
# 7   Female     MCA     172  Bhopal
# 22  Female  B.Tech     167  Bhopal
# 29  Female     MCA     172  Bhopal
# 44  Female     B.E     178  Bhopal
# 51  Female     MBA     174  Bhopal
# 73  Female     MBA     179  Bhopal
#
# ********************************************
#
# ('Female', 'Chandigarh')
# __________________
#
#     Gender Degree  Height        City
# 42  Female   B.Sc     173  Chandigarh
# 63  Female    MCA     175  Chandigarh
#
# ********************************************
#
# ('Female', 'Chennai')
# __________________
#
#     Gender  Degree  Height     City
# 1   Female  B.Tech     167  Chennai
# 10  Female     B.E     173  Chennai
# 32  Female     B.E     176  Chennai
#
# ********************************************
#
# ('Female', 'Delhi')
# __________________
#
#     Gender  Degree  Height   City
# 12  Female     MBA     174  Delhi
# 18  Female    M.Sc     175  Delhi
# 34  Female     MBA     168  Delhi
# 40  Female    M.Sc     177  Delhi
# 47  Female    M.Sc     179  Delhi
# 56  Female  B.Tech     178  Delhi
# 71  Female     MCA     175  Delhi
#
# ********************************************
#
# ('Female', 'Hyderabad')
# __________________
#
#     Gender  Degree  Height       City
# 46  Female     MBA     172  Hyderabad
# 53  Female  M.Tech     166  Hyderabad
# 66  Female     B.E     178  Hyderabad
# 68  Female     MBA     172  Hyderabad
# 70  Female  M.Tech     179  Hyderabad
# 76  Female    B.Sc     176  Hyderabad
# 78  Female    B.Sc     178  Hyderabad
#
# ********************************************
#
# ('Female', 'Jaipur')
# __________________
#
#     Gender  Degree  Height    City
# 13  Female    M.Sc     168  Jaipur
# 19  Female  M.Tech     177  Jaipur
# 35  Female    M.Sc     166  Jaipur
# 41  Female  M.Tech     171  Jaipur
# 62  Female  M.Tech     173  Jaipur
#
# ********************************************
#
# ('Female', 'Lucknow')
# __________________
#
#     Gender  Degree  Height     City
# 6   Female  M.Tech     172  Lucknow
# 21  Female    B.Sc     171  Lucknow
# 28  Female  M.Tech     172  Lucknow
# 64  Female    B.Sc     173  Lucknow
#
# ********************************************
#
# ('Female', 'Vizag')
# __________________
#
#     Gender  Degree  Height   City
# 2   Female     B.E     169  Vizag
# 17  Female     MBA     178  Vizag
# 39  Female     MBA     175  Vizag
# 55  Female    B.Sc     166  Vizag
# 75  Female  M.Tech     179  Vizag
#
# ********************************************
#
# ('Male', 'Bangalore')
# __________________
#
#    Gender Degree  Height       City
# 23   Male    B.E     173  Bangalore
# 45   Male  B.Com     172  Bangalore
# 58   Male  B.Com     177  Bangalore
#
# ********************************************
#
# ('Male', 'Bhopal')
# __________________
#
#    Gender  Degree  Height    City
# 16   Male   B.Com     166  Bhopal
# 38   Male   B.Com     178  Bhopal
# 65   Male  B.Tech     177  Bhopal
# 69   Male    M.Sc     177  Bhopal
#
# ********************************************
#
# ('Male', 'Chandigarh')
# __________________
#
#    Gender  Degree  Height        City
# 5    Male    M.Sc     178  Chandigarh
# 14   Male  M.Tech     166  Chandigarh
# 20   Male     MCA     171  Chandigarh
# 27   Male    M.Sc     178  Chandigarh
# 36   Male  M.Tech     175  Chandigarh
# 49   Male     MCA     173  Chandigarh
# 79   Male  B.Tech     174  Chandigarh
#
# ********************************************
#
# ('Male', 'Chennai')
# __________________
#
#    Gender Degree  Height     City
# 54   Male    MCA     175  Chennai
# 67   Male  B.Com     172  Chennai
# 77   Male    MCA     178  Chennai
#
# ********************************************
#
# ('Male', 'Delhi')
# __________________
#
#    Gender Degree  Height   City
# 3    Male  B.Com     173  Delhi
# 25   Male  B.Com     173  Delhi
#
# ********************************************
#
# ('Male', 'Hyderabad')
# __________________
#
#    Gender  Degree  Height       City
# 0    Male    B.Sc     174  Hyderabad
# 9    Male  B.Tech     166  Hyderabad
# 24   Male   B.Com     175  Hyderabad
# 31   Male  B.Tech     173  Hyderabad
# 59   Male   B.Com     171  Hyderabad
# 60   Male     MBA     171  Hyderabad
#
# ********************************************
#
# ('Male', 'Jaipur')
# __________________
#
#    Gender  Degree  Height    City
# 4    Male     MBA     177  Jaipur
# 26   Male     MBA     177  Jaipur
# 48   Male  M.Tech     166  Jaipur
# 57   Male     B.E     175  Jaipur
# 72   Male   B.Com     178  Jaipur
#
# ********************************************
#
# ('Male', 'Lucknow')
# __________________
#
#    Gender  Degree  Height     City
# 15   Male     MCA     175  Lucknow
# 37   Male     MCA     166  Lucknow
# 43   Male  B.Tech     177  Lucknow
# 50   Male   B.Com     176  Lucknow
# 80   Male  M.Tech     175  Lucknow
#
# ********************************************
#
# ('Male', 'Vizag')
# __________________
#
#    Gender Degree  Height   City
# 11   Male  B.Com     176  Vizag
# 33   Male  B.Com     174  Vizag
# 61   Male   M.Sc     167  Vizag
# 74   Male   M.Sc     178  Vizag
#
# ********************************************
