# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <font color="red">TASK-2:--

# %% [markdown]
# #### <font color="brown">Q1	IMPORT ACCOUNT_PERF_DATA.XLSX FILE AND GIVE THE DATASET NAME AS PORTFOLIO_PERF_DATA_2022

# %%
PORTFOLIO_PERF_DATA_2022=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-2\ASSIGNMENTS ANS\DATA\ACCOUNT_PERF_DATA.xlsx")

# %%
PORTFOLIO_PERF_DATA_2022
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# #### <font color="brwon">Q2	PRINT TOP 100 RECORDS OF THE DATASET

# %%
PORTFOLIO_PERF_DATA_2022.head(100)
# Out:
#     Account_number      PORTFOLIO          SSN    Phone No.       Place Name  \
# 0         38673575    CREDIT CARD  640-29-9264  405-775-9884         Bromide
# 1         38673576  PERSONAL LOAN  375-37-8517  212-786-7533  Reading Center
# 2         38673577  PERSONAL LOAN  073-02-5563  385-775-0225          Ibapah
# 3         38673578       MORTGAGE  106-98-7919  216-984-8974       Wickliffe
# 4         38673579    CREDIT CARD  753-07-4655  217-307-8597         Forrest
# ..             ...            ...          ...           ...             ...
# 95        38673670    CREDIT CARD  119-98-5733  215-753-6443    Conshohocken
# 96        38673671    CREDIT CARD  510-33-2272  209-685-5524         Klamath
# 97        38673672    CREDIT CARD  168-86-4252  303-439-4051     Westminster
# 98        38673673    CREDIT CARD  730-28-5224  302-854-2835         Yorklyn
# 99        38673674  PERSONAL LOAN  381-37-7296  210-580-0080     San Antonio
#
# ...

# %% [markdown]
# #### <font color="brown">Q3	PRINT LAST 100 RECORDS OF THE DATASET

# %%
PORTFOLIO_PERF_DATA_2022.tail(100)
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.    Place Name  \
# 24904        38698479    CREDIT CARD  092-02-0144  803-448-0539        Lando
# 24905        38698480       MORTGAGE  673-48-6681  314-448-4803        Briar
# 24906        38698481       MORTGAGE  127-98-1326  205-604-2328  Hazel Green
# 24907        38698482    CREDIT CARD  540-83-0348  201-848-6649      Absecon
# 24908        38698483       MORTGAGE  069-02-1613  210-994-6664    Arlington
# ...               ...            ...          ...           ...          ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904      Wenonah
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762   West Point
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318     Syracuse
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734     Woodbury
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770    Grovetown
#
# ...

# %% [markdown]
# #### <font color="brown">Q4	PRINT TOP 100 AND LAST 100 RECORDS OF THE DATASET

# %%
# TOP 100 RECORDS
PORTFOLIO_PERF_DATA_2022[:100]
# Out:
#     Account_number      PORTFOLIO          SSN    Phone No.       Place Name  \
# 0         38673575    CREDIT CARD  640-29-9264  405-775-9884         Bromide
# 1         38673576  PERSONAL LOAN  375-37-8517  212-786-7533  Reading Center
# 2         38673577  PERSONAL LOAN  073-02-5563  385-775-0225          Ibapah
# 3         38673578       MORTGAGE  106-98-7919  216-984-8974       Wickliffe
# 4         38673579    CREDIT CARD  753-07-4655  217-307-8597         Forrest
# ..             ...            ...          ...           ...             ...
# 95        38673670    CREDIT CARD  119-98-5733  215-753-6443    Conshohocken
# 96        38673671    CREDIT CARD  510-33-2272  209-685-5524         Klamath
# 97        38673672    CREDIT CARD  168-86-4252  303-439-4051     Westminster
# 98        38673673    CREDIT CARD  730-28-5224  302-854-2835         Yorklyn
# 99        38673674  PERSONAL LOAN  381-37-7296  210-580-0080     San Antonio
#
# ...

# %%
# LAST 100 RECORDS
PORTFOLIO_PERF_DATA_2022[-100:]
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.    Place Name  \
# 24904        38698479    CREDIT CARD  092-02-0144  803-448-0539        Lando
# 24905        38698480       MORTGAGE  673-48-6681  314-448-4803        Briar
# 24906        38698481       MORTGAGE  127-98-1326  205-604-2328  Hazel Green
# 24907        38698482    CREDIT CARD  540-83-0348  201-848-6649      Absecon
# 24908        38698483       MORTGAGE  069-02-1613  210-994-6664    Arlington
# ...               ...            ...          ...           ...          ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904      Wenonah
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762   West Point
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318     Syracuse
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734     Woodbury
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770    Grovetown
#
# ...

# %% [markdown]
# #### <font color="brown">Q5	PRINT NUMBER OF RECORDS AND VARIABLES IN THE DATASET

# %%
PORTFOLIO_PERF_DATA_2022.shape
# Out:
# (25004, 17)

# %% [markdown]
# #### <font color="brown">Q6	PRINT EACH VARIABLES AND THEIR DATA TYPES

# %%
PORTFOLIO_PERF_DATA_2022.dtypes
# Out:
# Account_number                     int64
# PORTFOLIO                         object
# SSN                               object
# Phone No.                         object
# Place Name                        object
# County                            object
# City                              object
# State                             object
# Zip                                int64
# Region                            object
# Account Open Date         datetime64[ns]
# Loan_amount                        int64
# Loan_status                       object
# Last_payment_date         datetime64[ns]
# Origination_fico_score             int64
# Current_fico_score                 int64
# Current_outstanding              float64
# dtype: object

# %% [markdown]
# #### <font color="brown">Q7	PRINT THE HEADERS OF THE DATASET

# %%
PORTFOLIO_PERF_DATA_2022.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'Phone No. ', 'Place Name',
#        'County', 'City', 'State', 'Zip', 'Region', 'Account Open Date',
#        'Loan_amount', 'Loan_status', 'Last_payment_date',
#        'Origination_fico_score', 'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %% [markdown]
# #### <font color="brown">Q8	PRINT COUNT OF RECORDS BY EACH VARIABLES

# %%
PORTFOLIO_PERF_DATA_2022.count()
# Out:
# Account_number            25004
# PORTFOLIO                 25004
# SSN                       25004
# Phone No.                 24879
# Place Name                25004
# County                    25004
# City                      24993
# State                     25004
# Zip                       25004
# Region                    25004
# Account Open Date         25004
# Loan_amount               25004
# Loan_status               24998
# Last_payment_date         25004
# Origination_fico_score    25004
# Current_fico_score        25004
# Current_outstanding       24990
# dtype: int64

# %% [markdown]
# #### <font color="brown">Q9	PRINT COUNT OF MISSING RECORDS BY EACH VARIABLES

# %%
PORTFOLIO_PERF_DATA_2022.isnull().sum()
# Out:
# Account_number              0
# PORTFOLIO                   0
# SSN                         0
# Phone No.                 125
# Place Name                  0
# County                      0
# City                       11
# State                       0
# Zip                         0
# Region                      0
# Account Open Date           0
# Loan_amount                 0
# Loan_status                 6
# Last_payment_date           0
# Origination_fico_score      0
# Current_fico_score          0
# Current_outstanding        14
# dtype: int64

# %% [markdown]
# #### <font color="brown">Q10	PRINT COUNT OF ALL MISSING RECORDS BY EACH VARIABLES

# %%
PORTFOLIO_PERF_DATA_2022.isnull().sum().sum()
# Out:
# 156

# %% [markdown]
# #### <font color="brown">Q11	CREATE A NEW DATASET PORTFOLIO_PERF_DATA_2022_V1 FROM PORTFOLIO_PERF_DATA_2022
#
# 		SELECT LIST OF VARIABLES LIKE
#             Account_number
# 			PORTFOLIO
# 			SSN
# 			Phone No.
# 			Region
# 			Account Open Date
# 			Loan_amount
# 			Loan_status
# 			Current_fico_score
# 			Current_outstanding

# %%
PORTFOLIO_PERF_DATA_2022.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'Phone No. ', 'Place Name',
#        'County', 'City', 'State', 'Zip', 'Region', 'Account Open Date',
#        'Loan_amount', 'Loan_status', 'Last_payment_date',
#        'Origination_fico_score', 'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %%
PORTFOLIO_PERF_DATA_2022_V1=PORTFOLIO_PERF_DATA_2022[['Account_number', 'PORTFOLIO', 'SSN', 'Phone No. ','Region', 'Account Open Date',
       'Loan_amount', 'Loan_status','Current_fico_score', 'Current_outstanding']]

# %%
PORTFOLIO_PERF_DATA_2022_V1
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.      Region  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884      South
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533  Northeast
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225       West
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974    Midwest
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597    Midwest
# ...               ...            ...          ...           ...        ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904  Northeast
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762       West
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318  Northeast
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734  Northeast
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770      South
#
# ...

# %% [markdown]
# #### <font color="brown">Q12	CREATE A NEW DATASET PORTFOLIO_PERF_DATA_2022_V2 FROM PORTFOLIO_PERF_DATA_2022
#       DROP VARIABLES
#         Place Name
# 		County
# 		City
# 		Zip
# 		Region
# 		Last_payment_date
# 		Origination_fico_score

# %%
PORTFOLIO_PERF_DATA_2022.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'Phone No. ', 'Place Name',
#        'County', 'City', 'State', 'Zip', 'Region', 'Account Open Date',
#        'Loan_amount', 'Loan_status', 'Last_payment_date',
#        'Origination_fico_score', 'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %%
PORTFOLIO_PERF_DATA_2022_V2=PORTFOLIO_PERF_DATA_2022.drop(['Place Name','County', 'City','Zip', 'Region','Last_payment_date','Origination_fico_score'],axis=1)

# %%
PORTFOLIO_PERF_DATA_2022_V2
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.  State  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884    OK
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533    NY
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225    UT
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974    OH
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597    IL
# ...               ...            ...          ...           ...   ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904    NJ
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762    CA
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318    NY
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734    NY
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770    GA
#
#       Account Open Date  Loan_amount  Loan_status  Current_fico_score  \
# ...

# %% [markdown]
# #### <font color="brown">Q13	CREATE A NEW DATASET PORTFOLIO_PERF_DATA_2022_V3 FROM PORTFOLIO_PERF_DATA_2022
# 	SORT DATASET BY
#         PORTFOLIO
# 		County
# 		Loan_amount
# 		Current_outstanding IN DESCENDING ORDER

# %%
PORTFOLIO_PERF_DATA_2022[['PORTFOLIO','County','Loan_amount','Current_outstanding']].sort_values(by=['PORTFOLIO','County','Loan_amount','Current_outstanding'],ascending=[True,True,True,False])
# Out:
#            PORTFOLIO              County  Loan_amount  Current_outstanding
# 6165     CREDIT CARD              Acadia        38233             11087.57
# 15292    CREDIT CARD              Acadia        61305              6743.55
# 9284     CREDIT CARD              Acadia        95526             15284.16
# 20939    CREDIT CARD            Accomack        26389               527.78
# 11344    CREDIT CARD            Accomack        26672              3467.36
# ...              ...                 ...          ...                  ...
# 6209   PERSONAL LOAN  Yukon-Koyukuk (CA)       144942              4348.26
# 20078  PERSONAL LOAN                Yuma        93075             15822.75
# 14258  PERSONAL LOAN               Zeona        73056             27761.28
# 22850  PERSONAL LOAN             Ziebach       118041             35412.30
# 20638  PERSONAL LOAN             Ziebach       172855             31113.90
#
# [25004 rows x 4 columns]

# %% [markdown]
# #### <font color="brown">Q14	CREATE SEPARATE DATASET AS CREDIT_CARD, PERSONAL_LOAN AND MORTGAGE

# %% [markdown]
# ##### <font color="blue">CREDIT_CARD DATASET

# %%
CREDI_CARD=PORTFOLIO_PERF_DATA_2022[PORTFOLIO_PERF_DATA_2022['PORTFOLIO']=="CREDIT CARD"]

# %%
CREDI_CARD
# Out:
#        Account_number    PORTFOLIO          SSN    Phone No.    Place Name  \
# 0            38673575  CREDIT CARD  640-29-9264  405-775-9884      Bromide
# 4            38673579  CREDIT CARD  753-07-4655  217-307-8597      Forrest
# 6            38673581  CREDIT CARD  090-02-6498  339-289-4655       Newton
# 8            38673583  CREDIT CARD  276-17-0083  209-252-3832  Pico Rivera
# 12           38673587  CREDIT CARD  556-99-2038  339-922-2190     Pembroke
# ...               ...          ...          ...           ...          ...
# 24983        38698558  CREDIT CARD  579-53-4759  218-645-6825       Watson
# 24987        38698562  CREDIT CARD  539-71-5515  219-506-1015  Bloomington
# 24990        38698565  CREDIT CARD  721-18-1919  206-717-5311  Leavenworth
# 24993        38698568  CREDIT CARD  406-73-7119  210-227-8906        Simms
# 24999        38698574  CREDIT CARD  112-98-5765  201-857-6904      Wenonah
#
# ...

# %% [markdown]
# ##### <font color="blue">PERSONAL_LOAN DATASET

# %%
PERSONAL_LOAN=PORTFOLIO_PERF_DATA_2022[PORTFOLIO_PERF_DATA_2022['PORTFOLIO']=="PERSONAL LOAN"]

# %%
PERSONAL_LOAN
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 7            38673582  PERSONAL LOAN  390-33-0765  218-314-7370
# 15           38673590  PERSONAL LOAN  233-57-1697  219-545-4790
# 16           38673591  PERSONAL LOAN  668-48-6539  314-754-2773
# ...               ...            ...          ...           ...
# 24981        38698556  PERSONAL LOAN  492-29-1690  304-457-9114
# 24992        38698567  PERSONAL LOAN  016-94-9378  303-873-8569
# 24994        38698569  PERSONAL LOAN  596-94-1180  209-366-9348
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
#
#            Place Name     County            City State    Zip     Region  \
# 1      Reading Center   Schuyler  Reading Center    NY  14876  Northeast
# ...

# %% [markdown]
# ##### <font color="blue"> MORTGAGE DATASET

# %%
MORTGAGE=PORTFOLIO_PERF_DATA_2022[PORTFOLIO_PERF_DATA_2022['PORTFOLIO']=="MORTGAGE"]

# %%
MORTGAGE
# Out:
#        Account_number PORTFOLIO          SSN    Phone No.       Place Name  \
# 3            38673578  MORTGAGE  106-98-7919  216-984-8974       Wickliffe
# 5            38673580  MORTGAGE  770-02-0049  201-312-1614  Highland Lakes
# 9            38673584  MORTGAGE  677-22-7228  307-872-6444          Casper
# 10           38673585  MORTGAGE  149-23-6087  479-493-2345       Van Buren
# 11           38673586  MORTGAGE  211-84-1802  319-658-2317         Moville
# ...               ...       ...          ...           ...             ...
# 24996        38698571  MORTGAGE  482-41-8559  215-432-2028          Warren
# 24997        38698572  MORTGAGE  725-18-5262  239-778-5164          Deland
# 24998        38698573  MORTGAGE  500-29-4129  218-634-3018        Foreston
# 25001        38698576  MORTGAGE  094-02-7375  212-698-6318        Syracuse
# 25003        38698578  MORTGAGE  191-86-1363  229-974-6770       Grovetown
#
# ...

# %% [markdown]
# ## <font color="red">TASK-3:--

# %% [markdown]
# #### <font color="brown">Q1	IMPORT ACCOUNT_PERF_DATA.XLSX FILE AND GIVE THE DATASET NAME AS PORTFOLIO_DATA

# %%
PORTFOLIO_DATA=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-2\ASSIGNMENTS ANS\DATA\ACCOUNT_PERF_DATA.xlsx")

# %%
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# #### <font color="brown">Q2	CREATE A NEW DATASET CALLED NY_CREDIT_CARD_SOUTH_REGION FROM PORTFOLIO_DATA
# 	CRTERIA
#         PORTFOLIO='CREDIT CARD'
# 		State='NY'
# 		Region='SOUTH'
# 		Loan_status='DEFAULT'
# 		Current_outstanding BETWEEN 10000 TO 30000

# %%
NY_CREDIT_CARD_SOUTH_REGION=PORTFOLIO_DATA[(PORTFOLIO_DATA["PORTFOLIO"]=='CREDIT CARD') & (PORTFOLIO_DATA['State']=='NY') & (PORTFOLIO_DATA['Region']=='South') & (PORTFOLIO_DATA['Loan_status']=='Default') & (PORTFOLIO_DATA['Current_outstanding'].between(10000,30000))]

# %%
NY_CREDIT_CARD_SOUTH_REGION
# Out:
# Empty DataFrame
# Columns: [Account_number, PORTFOLIO, SSN, Phone No. , Place Name, County, City, State, Zip, Region, Account Open Date, Loan_amount, Loan_status, Last_payment_date, Origination_fico_score, Current_fico_score, Current_outstanding]
# Index: []

# %%
NY_CREDIT_CARD_SOUTH_REGION_V1=PORTFOLIO_DATA[(PORTFOLIO_DATA["PORTFOLIO"]=='CREDIT CARD') | (PORTFOLIO_DATA['State']=='NY') | (PORTFOLIO_DATA['Region']=='South') | (PORTFOLIO_DATA['Loan_status']=='Default') | (PORTFOLIO_DATA['Current_outstanding'].between(10000,30000))]

# %%
NY_CREDIT_CARD_SOUTH_REGION_V1
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# 6            38673581    CREDIT CARD  090-02-6498  339-289-4655
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# #### <font color="brown">Q3	SUMMARIZE THE DATA FROM PORTFOLIO_DATA TO GET

# %% [markdown]
# ![Screenshot%202024-01-27%20113458.png](attachment:Screenshot%202024-01-27%20113458.png)

# %%
summ_Portfolio=PORTFOLIO_DATA.groupby(["State","PORTFOLIO","Loan_status"],as_index=False).agg(No_Of_Account=("Account_number","count"),Total_Loan_Amount=("Loan_amount","sum"),Total_Outstanding=("Current_outstanding","sum"))

# %%
summ_Portfolio
# Out:
#     State      PORTFOLIO  Loan_status  No_Of_Account  Total_Loan_Amount  \
# 0      AK    CREDIT CARD      Default             16             964129
# 1      AK    CREDIT CARD  Non-Default             41            2641685
# 2      AK       MORTGAGE      Default             20           11235393
# 3      AK       MORTGAGE  Non-Default             44           23109130
# 4      AK  PERSONAL LOAN      Default             13            1332221
# ..    ...            ...          ...            ...                ...
# 301    WY    CREDIT CARD  Non-Default             35            2167758
# 302    WY       MORTGAGE      Default              8            3411185
# 303    WY       MORTGAGE  Non-Default             32           15112644
# 304    WY  PERSONAL LOAN      Default              4             548174
# 305    WY  PERSONAL LOAN  Non-Default             13            1531118
#
#      Total_Outstanding
# 0            224444.87
# 1            751356.24
# 2           2600385.92
# ...

# %%
summ_Portfolio.columns
# Out:
# Index(['State', 'PORTFOLIO', 'Loan_status', 'No_Of_Account',
#        'Total_Loan_Amount', 'Total_Outstanding'],
#       dtype='object')

# %%
summ_Portfolio['Total_Loan_Amount']=summ_Portfolio['Total_Loan_Amount'].map("${:,.2f}".format)

# %%
summ_Portfolio['Total_Outstanding']=summ_Portfolio['Total_Outstanding'].map("${:,.2f}".format)

# %%
summ_Portfolio
# Out:
#     State      PORTFOLIO  Loan_status  No_Of_Account Total_Loan_Amount  \
# 0      AK    CREDIT CARD      Default             16       $964,129.00
# 1      AK    CREDIT CARD  Non-Default             41     $2,641,685.00
# 2      AK       MORTGAGE      Default             20    $11,235,393.00
# 3      AK       MORTGAGE  Non-Default             44    $23,109,130.00
# 4      AK  PERSONAL LOAN      Default             13     $1,332,221.00
# ..    ...            ...          ...            ...               ...
# 301    WY    CREDIT CARD  Non-Default             35     $2,167,758.00
# 302    WY       MORTGAGE      Default              8     $3,411,185.00
# 303    WY       MORTGAGE  Non-Default             32    $15,112,644.00
# 304    WY  PERSONAL LOAN      Default              4       $548,174.00
# 305    WY  PERSONAL LOAN  Non-Default             13     $1,531,118.00
#
#     Total_Outstanding
# 0         $224,444.87
# 1         $751,356.24
# 2       $2,600,385.92
# ...

# %% [markdown]
# #### <font color="brown">Q4	FROM PORTFOLIO_DATA GET THE UNIQUE VALUES FOR VARIABLES LIKE
#         PORTFOLIO
# 		County
# 		State

# %% [markdown]
# ##### <font color="blue">UNIQUE VALUES WITH COUNT

# %%
PORTFOLIO_DATA.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'Phone No. ', 'Place Name',
#        'County', 'City', 'State', 'Zip', 'Region', 'Account Open Date',
#        'Loan_amount', 'Loan_status', 'Last_payment_date',
#        'Origination_fico_score', 'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %%
PORTFOLIO_DATA['PORTFOLIO'].value_counts()
# Out:
# CREDIT CARD      10180
# MORTGAGE          9788
# PERSONAL LOAN     5036
# Name: PORTFOLIO, dtype: int64

# %%
PORTFOLIO_DATA['County'].value_counts()
# Out:
# Los Angeles    329
# Jefferson      295
# Montgomery     256
# Washington     256
# Orange         214
#               ...
# Node             1
# Bartlett         1
# White Oak        1
# Reform           1
# Archuleta        1
# Name: County, Length: 2174, dtype: int64

# %%
PORTFOLIO_DATA['State'].value_counts()
# Out:
# CA    1674
# TX    1614
# NY    1356
# PA    1279
# IL     925
# FL     902
# OH     859
# VA     768
# KY     706
# MI     701
# MO     691
# MN     653
# NC     638
# IA     633
# GA     598
# IN     569
# WV     565
# WI     552
# AL     495
# KS     491
# TN     490
# NJ     453
# LA     438
# WA     428
# MA     422
# OK     420
# AR     396
# CO     384
# MD     381
# NE     360
# ME     339
# AZ     306
# SC     305
# MS     304
# OR     248
# CT     241
# SD     234
# MT     230
# ND     229
# NM     221
# UT     195
# ID     194
# VT     183
# NH     161
# DC     156
# NV     156
# AK     148
# WY     102
# HI      81
# RI      72
# DE      58
# Name: State, dtype: int64

# %% [markdown]
# ##### <font color="blue">UNIQUE VALUES

# %%
PORTFOLIO_DATA['PORTFOLIO'].unique()
# Out:
# array(['CREDIT CARD', 'PERSONAL LOAN', 'MORTGAGE'], dtype=object)

# %%
PORTFOLIO_DATA['County'].unique()
# Out:
# array(['Johnston', 'Schuyler', 'Tooele', ..., 'Heard', 'Meagher',
#        'Archuleta'], dtype=object)

# %%
PORTFOLIO_DATA['State'].unique()
# Out:
# array(['OK', 'NY', 'UT', 'OH', 'IL', 'NJ', 'MA', 'MN', 'CA', 'WY', 'AR',
#        'IA', 'MI', 'MO', 'IN', 'FL', 'TX', 'ID', 'NE', 'OR', 'AL', 'TN',
#        'PA', 'MT', 'KY', 'WI', 'WV', 'MS', 'MD', 'GA', 'AZ', 'AK', 'ME',
#        'NV', 'LA', 'KS', 'CO', 'HI', 'SC', 'WA', 'DE', 'NC', 'VT', 'NM',
#        'VA', 'DC', 'SD', 'CT', 'ND', 'NH', 'RI'], dtype=object)

# %% [markdown]
# #### <font color="brown">Q5	IN PORTFOLIO_DATA CREATE NEW VARIABLE AS TOTAL_PAID_AMOUNT=Loan_amount-Current_outstanding
# 	PRESENT THE VALUES IN DOLLAR FORMAT WITH 0 DECIMALS

# %%
PORTFOLIO_DATA["Total_Paid_amount"]=(PORTFOLIO_DATA["Loan_amount"]/PORTFOLIO_DATA["Current_outstanding"]).map("${:,.0f}".format)

# %%
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# #### <font color="brown">IN PORTFOLIO_DATA CREATE NEW VARIABLE AS BALANCE_PERCENTAGE=Current_outstanding/Loan_amount
#         PRESENT THE VALUES IN PERCENTAGE FORMAT WITH 0 DECIMALS

# %%
PORTFOLIO_DATA["Balance_Percentage"]=(PORTFOLIO_DATA["Current_outstanding"]/PORTFOLIO_DATA["Loan_amount"]).map("{:,.0%}".format)

# %%
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# #### <font color="brown">Q6	IN PORTFOLIO_DATA CREATE NEW VARIABLE AS RISK_SEGMENT
#
#             IF BALANCE_PERCENTAGE >= 50% THEN 'CRITICAL'
# 			IF BALANCE_PERCENTAGE >= 30% AND  BALANCE_PERCENTAGE  <50% THEN 'HIGH RIK'
# 			IF BALANCE_PERCENTAGE >= 20% AND  BALANCE_PERCENTAGE  <30% THEN 'MID RIK'
# 			ELSE 'LOW RISK'

# %%
PORTFOLIO_DATA["Risk_Segment"]="Low Risk"
PORTFOLIO_DATA["Risk_Segment"][PORTFOLIO_DATA["Balance_Percentage"].str.rstrip("%").astype("float")>=20]="Mid Risk"
PORTFOLIO_DATA["Risk_Segment"][PORTFOLIO_DATA["Balance_Percentage"].str.rstrip("%").astype("float")>=30]="High Risk"
PORTFOLIO_DATA["Risk_Segment"][PORTFOLIO_DATA["Balance_Percentage"].str.rstrip("%").astype("float")>=50]="Critical"

# %%
PORTFOLIO_DATA
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# ## <font color="red">TASK-4:---

# %% [markdown]
# #### <font color="brown">Q1	CREATE A NEW TABLE MED_SELECT_V6 AND ADD THE FOLLOING COLUMNS AS
#
# 		AGE_BUCKET
# 			LEAA THAN 30
# 			30 TO 50
# 			51 TO 70
# 			70+
#
# 		SPENT_BUCKET
# 			LESS THAN 300
# 			301 TO 500
# 			501 TO 700
# 			701 TO 1000
# 			1000+
#
# 		CUSTOMER_SEGMENT
# 		IF AGE BETWEEN 30 AN 70 AND GENDER=FEMALE AND SPENT_AMOUNT >=300	PREMIER
# 		IF AGE BETWEEN 30 AN 70 AND GENDER=MALE AND SPENT_AMOUNT >=300	PREMIER
# 		ELSE 	NON-PREMIER

# %%
med_select_v6=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-2\ASSIGNMENTS ANS\DATA\A1.MED_STORE_2022.xlsx")

# %%
med_select_v6
# Out:
#       CUSTOMER_ID    Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  \
# 0      1000032547      MED +    2006-09-12           Y    2007-05-12
# 1      1000032548  DR.REDDYS    2006-09-12           Y    2007-03-12
# 2      1000032549   RELEGARE    2006-09-12           Y    2007-02-12
# 3      1000032550        GSK    2006-09-12           Y    2007-03-12
# 4      1000032551        GSK    2006-09-12           Y    2007-05-12
# ...           ...        ...           ...         ...           ...
# 5107   1000037830   RELEGARE    2008-05-06           Y    2009-05-02
# 5108   1000037831     APPOLO    2008-05-06           Y    2008-10-06
# 5109   1000037832        GSK    2008-05-06           Y    2009-05-04
# 5110   1000037833      MED +    2008-05-06           Y    2009-06-10
# 5111   1000037834    RANBAXY    2008-05-06           Y    2009-05-04
#
#       firstSTOR TITLE  GENDER  max_spent        DOB  ... CUST_STAT  \
# 0          2587  Mrs.  Female      56.31 1984-09-15  ...    Active
# ...

# %%
med_select_v6.columns
# Out:
# Index(['CUSTOMER_ID', 'Company', 'CARD_REG_DATE', 'CARD_ACTIVE',
#        'FIRST_USE_DTE', 'firstSTOR', 'TITLE', 'GENDER', 'max_spent', 'DOB',
#        'FTD', 'Age', 'STATE_CODE', 'POST_CODE', 'CUST_STAT', 'Avgsize_spent',
#        'CARD_STAT', 'RGSTN_TYPE_IND', 'NO_OF_TRIPS', 'TOWN', 'EMAIL_IND',
#        'CONTACT_PREF', 'Average_Qty_PER_ACC', 'Spent_amount'],
#       dtype='object')

# %% [markdown]
# ##### 	<font color="blue">AGE_BUCKET
# 			LEAA THAN 30
# 			30 TO 50
# 			51 TO 70
# 			70+

# %%
med_select_v6["Age_Bucket"]="Young_Age"
med_select_v6["Age_Bucket"][med_select_v6["Age"]>30]="Mid_Young_Age"
med_select_v6["Age_Bucket"][med_select_v6["Age"]>50]="Mid_Old_Age"
med_select_v6["Age_Bucket"][med_select_v6["Age"]>=70]="Old_Age"

# %% [markdown]
# ##### <font color="blue">SPENT_BUCKET
# 			LESS THAN 300
# 			301 TO 500
# 			501 TO 700
# 			701 TO 1000
# 			1000+

# %%
med_select_v6["Spent_Bucket"]="Casual"
med_select_v6["Spent_Bucket"][med_select_v6["Spent_amount"]>300]="Good"
med_select_v6["Spent_Bucket"][med_select_v6["Spent_amount"]>500]="Temporary"
med_select_v6["Spent_Bucket"][med_select_v6["Spent_amount"]>700]="Gold"
med_select_v6["Spent_Bucket"][med_select_v6["Spent_amount"]>1000]="Primary"

# %% [markdown]
# ##### <font color="blue">CUSTOMER_SEGMENT
#     IF AGE BETWEEN 30 AN 70 AND GENDER=FEMALE AND SPENT_AMOUNT >=300    PREMIER
#     IF AGE BETWEEN 30 AN 70 AND GENDER=MALE AND SPENT_AMOUNT >=300    PREMIER
#     ELSE     NON-PREMIER

# %%
med_select_v6["Customer_Segment"]="Non_Premier"
med_select_v6["Customer_Segment"][(med_select_v6["Age"].between(30,70)) & (med_select_v6['GENDER']=="Male") & (med_select_v6['Spent_amount']>=300)]="Premier"
med_select_v6["Customer_Segment"][(med_select_v6["Age"].between(30,70)) & (med_select_v6['GENDER']=="Female") & (med_select_v6['Spent_amount']>=300)]="Premier"

# %%
med_select_v6
# Out:
#       CUSTOMER_ID    Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  \
# 0      1000032547      MED +    2006-09-12           Y    2007-05-12
# 1      1000032548  DR.REDDYS    2006-09-12           Y    2007-03-12
# 2      1000032549   RELEGARE    2006-09-12           Y    2007-02-12
# 3      1000032550        GSK    2006-09-12           Y    2007-03-12
# 4      1000032551        GSK    2006-09-12           Y    2007-05-12
# ...           ...        ...           ...         ...           ...
# 5107   1000037830   RELEGARE    2008-05-06           Y    2009-05-02
# 5108   1000037831     APPOLO    2008-05-06           Y    2008-10-06
# 5109   1000037832        GSK    2008-05-06           Y    2009-05-04
# 5110   1000037833      MED +    2008-05-06           Y    2009-06-10
# 5111   1000037834    RANBAXY    2008-05-06           Y    2009-05-04
#
#       firstSTOR TITLE  GENDER  max_spent        DOB  ... RGSTN_TYPE_IND  \
# ...

# %% [markdown]
# #### <font color="brown">Q2	GET THE VALUE AS GIVEN BELOW FROM MED_SELECT_V6

# %% [markdown]
# ![Screenshot%202.png](attachment:Screenshot%202.png)

# %%
med_select_v6.columns
# Out:
# Index(['CUSTOMER_ID', 'Company', 'CARD_REG_DATE', 'CARD_ACTIVE',
#        'FIRST_USE_DTE', 'firstSTOR', 'TITLE', 'GENDER', 'max_spent', 'DOB',
#        'FTD', 'Age', 'STATE_CODE', 'POST_CODE', 'CUST_STAT', 'Avgsize_spent',
#        'CARD_STAT', 'RGSTN_TYPE_IND', 'NO_OF_TRIPS', 'TOWN', 'EMAIL_IND',
#        'CONTACT_PREF', 'Average_Qty_PER_ACC', 'Spent_amount', 'Age_Bucket',
#        'Spent_Bucket', 'Customer_Segment'],
#       dtype='object')

# %%
med_select_v6["CUSTOMER_ID"].count()
# Out:
# 5112

# %%
'{:,.0f}'.format(med_select_v6["CUSTOMER_ID"].count())
# Out:
# '5,112'

# %%
med_select_v6['NO_OF_TRIPS'].sum()
# Out:
# 27139

# %%
'{:,.0f}'.format(med_select_v6['NO_OF_TRIPS'].sum())
# Out:
# '27,139'

# %%
med_select_v6['Spent_amount'].sum()
# Out:
# 1656880.55

# %%
'${:,.0f}'.format(med_select_v6['Spent_amount'].sum())
# Out:
# '$1,656,881'

# %%
pd.DataFrame({"SUBS":['{:,.0f}'.format(med_select_v6["CUSTOMER_ID"].count())],
              "VISITS":['{:,.0f}'.format(med_select_v6['NO_OF_TRIPS'].sum())],
               "TOTAL_SPENT":['${:,.0f}'.format(med_select_v6['Spent_amount'].sum())]
             
             },)
# Out:
#     SUBS  VISITS TOTAL_SPENT
# 0  5,112  27,139  $1,656,881

# %% [markdown]
# #### <font color="brown">Q3	GET THE VALUE AS GIVEN BELOW FROM MED_SELECT_V6

# %% [markdown]
# ![Screenshot%203.png](attachment:Screenshot%203.png)

# %%
med_select_v6
# Out:
#       CUSTOMER_ID    Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  \
# 0      1000032547      MED +    2006-09-12           Y    2007-05-12
# 1      1000032548  DR.REDDYS    2006-09-12           Y    2007-03-12
# 2      1000032549   RELEGARE    2006-09-12           Y    2007-02-12
# 3      1000032550        GSK    2006-09-12           Y    2007-03-12
# 4      1000032551        GSK    2006-09-12           Y    2007-05-12
# ...           ...        ...           ...         ...           ...
# 5107   1000037830   RELEGARE    2008-05-06           Y    2009-05-02
# 5108   1000037831     APPOLO    2008-05-06           Y    2008-10-06
# 5109   1000037832        GSK    2008-05-06           Y    2009-05-04
# 5110   1000037833      MED +    2008-05-06           Y    2009-06-10
# 5111   1000037834    RANBAXY    2008-05-06           Y    2009-05-04
#
#       firstSTOR TITLE  GENDER  max_spent        DOB  ... RGSTN_TYPE_IND  \
# ...

# %%
medd=med_select_v6.groupby(med_select_v6["Company"],as_index=False).agg(SUBS=("CUSTOMER_ID","count"),VISITS=("NO_OF_TRIPS","sum"),Total_Spent=("Spent_amount","sum"))

# %%
medd
# Out:
#      Company  SUBS  VISITS  Total_Spent
# 0     APPOLO   580    3154    190591.82
# 1      CIPLA   571    2943    178281.49
# 2  DR.REDDYS   576    3326    195327.57
# 3       GENO   571    2737    162880.19
# 4        GSK   602    3395    200580.19
# 5   GUARDIAN   547    2979    186093.95
# 6      MED +   584    3060    190843.32
# 7    RANBAXY   529    2839    172571.72
# 8   RELEGARE   552    2706    179710.30

# %%
medd.columns
# Out:
# Index(['Company', 'SUBS', 'VISITS', 'Total_Spent'], dtype='object')

# %%
medd['VISITS']=medd['VISITS'].map('{:,.0f}'.format)

# %%
medd['Total_Spent']=medd['Total_Spent'].map('${:,.0f}'.format)

# %%
medd # Final Output
# Out:
#      Company  SUBS VISITS Total_Spent
# 0     APPOLO   580  3,154    $190,592
# 1      CIPLA   571  2,943    $178,281
# 2  DR.REDDYS   576  3,326    $195,328
# 3       GENO   571  2,737    $162,880
# 4        GSK   602  3,395    $200,580
# 5   GUARDIAN   547  2,979    $186,094
# 6      MED +   584  3,060    $190,843
# 7    RANBAXY   529  2,839    $172,572
# 8   RELEGARE   552  2,706    $179,710

# %% [markdown]
# #### <font color="brown">Q4	GET THE VALUE AS GIVEN BELOW FROM MED_SELECT_V6

# %% [markdown]
# ![Screenshot%204.png](attachment:Screenshot%204.png)

# %%
med_select_v6.columns
# Out:
# Index(['CUSTOMER_ID', 'Company', 'CARD_REG_DATE', 'CARD_ACTIVE',
#        'FIRST_USE_DTE', 'firstSTOR', 'TITLE', 'GENDER', 'max_spent', 'DOB',
#        'FTD', 'Age', 'STATE_CODE', 'POST_CODE', 'CUST_STAT', 'Avgsize_spent',
#        'CARD_STAT', 'RGSTN_TYPE_IND', 'NO_OF_TRIPS', 'TOWN', 'EMAIL_IND',
#        'CONTACT_PREF', 'Average_Qty_PER_ACC', 'Spent_amount', 'Age_Bucket',
#        'Spent_Bucket', 'Customer_Segment'],
#       dtype='object')

# %%
med_vv=med_select_v6.groupby(["Company","GENDER"],as_index=False).agg(SUBS=("CUSTOMER_ID","count"),VISITS=("NO_OF_TRIPS","sum"),TOTAL_SPENT=("Spent_amount","sum"))

# %%
med_vv
# Out:
#       Company  GENDER  SUBS  VISITS  TOTAL_SPENT
# 0      APPOLO  Female   388    2174    131269.92
# 1      APPOLO    Male   189     921     56645.18
# 2      APPOLO  Unisex     3      59      2676.72
# 3       CIPLA  Female   369    1955    120123.00
# 4       CIPLA    Male   197     955     55503.51
# 5       CIPLA  Unisex     5      33      2654.98
# 6   DR.REDDYS  Female   367    2133    130478.89
# 7   DR.REDDYS    Male   208    1191     64681.05
# 8   DR.REDDYS  Unisex     1       2       167.63
# 9        GENO  Female   384    1814    109583.44
# 10       GENO    Male   186     921     53253.25
# 11       GENO  Unisex     1       2        43.50
# 12        GSK  Female   402    2307    133568.99
# 13        GSK    Male   196    1065     65863.14
# 14        GSK  Unisex     4      23      1148.06
# 15   GUARDIAN  Female   357    1900    113374.92
# 16   GUARDIAN    Male   188    1067     71298.11
# 17   GUARDIAN  Unisex     2      12      1420.92
# ...

# %%
med_vv.columns
# Out:
# Index(['Company', 'GENDER', 'SUBS', 'VISITS', 'TOTAL_SPENT'], dtype='object')

# %%
med_vv['VISITS']=med_vv['VISITS'].map("{:,.0f}".format)

# %%
med_vv['TOTAL_SPENT']=med_vv['TOTAL_SPENT'].map("${:,.0f}".format)

# %%
med_vv # Final Output
# Out:
#       Company  GENDER  SUBS VISITS TOTAL_SPENT
# 0      APPOLO  Female   388  2,174    $131,270
# 1      APPOLO    Male   189    921     $56,645
# 2      APPOLO  Unisex     3     59      $2,677
# 3       CIPLA  Female   369  1,955    $120,123
# 4       CIPLA    Male   197    955     $55,504
# 5       CIPLA  Unisex     5     33      $2,655
# 6   DR.REDDYS  Female   367  2,133    $130,479
# 7   DR.REDDYS    Male   208  1,191     $64,681
# 8   DR.REDDYS  Unisex     1      2        $168
# 9        GENO  Female   384  1,814    $109,583
# 10       GENO    Male   186    921     $53,253
# 11       GENO  Unisex     1      2         $44
# 12        GSK  Female   402  2,307    $133,569
# 13        GSK    Male   196  1,065     $65,863
# 14        GSK  Unisex     4     23      $1,148
# 15   GUARDIAN  Female   357  1,900    $113,375
# 16   GUARDIAN    Male   188  1,067     $71,298
# 17   GUARDIAN  Unisex     2     12      $1,421
# 18      MED +  Female   407  2,030    $122,460
# ...

# %% [markdown]
# #### <font color="brown">Q5	FROM TABLE MED_SELECT_V6 GET STATE_CODE (QLD AND VIC) AND COMPANY WISE SUM OF SPENT_AMOUNT >= 20000

# %% [markdown]
# ![Screenshot%205.png](attachment:Screenshot%205.png)

# %%
med_summ_v1=med_select_v6[med_select_v6["STATE_CODE"].isin(["QLD","VIC"])]

# %%
med_summ_v2=med_summ_v1.groupby(["STATE_CODE","Company"],as_index=False).agg(TOTAL_SPENT=("Spent_amount","sum"))

# %%
med_summ_v2
# Out:
#    STATE_CODE    Company  TOTAL_SPENT
# 0         QLD     APPOLO     51824.18
# 1         QLD      CIPLA     53111.78
# 2         QLD  DR.REDDYS     57667.24
# 3         QLD       GENO     37226.59
# 4         QLD        GSK     57655.43
# 5         QLD   GUARDIAN     50945.95
# 6         QLD      MED +     49955.37
# 7         QLD    RANBAXY     44910.74
# 8         QLD   RELEGARE     55585.38
# 9         VIC     APPOLO     26079.11
# 10        VIC      CIPLA     22912.18
# 11        VIC  DR.REDDYS     21665.00
# 12        VIC       GENO     17093.22
# 13        VIC        GSK     22302.17
# 14        VIC   GUARDIAN     28446.88
# 15        VIC      MED +     24853.67
# 16        VIC    RANBAXY     19234.35
# 17        VIC   RELEGARE     17000.39

# %%
med_summ_v2.columns
# Out:
# Index(['STATE_CODE', 'Company', 'TOTAL_SPENT'], dtype='object')

# %%
med_summ_v2['TOTAL_SPENT']=med_summ_v2['TOTAL_SPENT'].map("${:,.0f}".format)

# %%
med_summ_v2 # Final Output
# Out:
#    STATE_CODE    Company TOTAL_SPENT
# 0         QLD     APPOLO     $51,824
# 1         QLD      CIPLA     $53,112
# 2         QLD  DR.REDDYS     $57,667
# 3         QLD       GENO     $37,227
# 4         QLD        GSK     $57,655
# 5         QLD   GUARDIAN     $50,946
# 6         QLD      MED +     $49,955
# 7         QLD    RANBAXY     $44,911
# 8         QLD   RELEGARE     $55,585
# 9         VIC     APPOLO     $26,079
# 10        VIC      CIPLA     $22,912
# 11        VIC  DR.REDDYS     $21,665
# 12        VIC       GENO     $17,093
# 13        VIC        GSK     $22,302
# 14        VIC   GUARDIAN     $28,447
# 15        VIC      MED +     $24,854
# 16        VIC    RANBAXY     $19,234
# 17        VIC   RELEGARE     $17,000

# %% [markdown]
# #### <font color="brown">Q6	FROM TABLE MED_SELECT_V6 GET THE SUMMARY OUTPUT BY
# 		BY COMPANY
# 		BY GENDER
# 		BY CUSTOMER_SEGMENT
# 		BY AGE_BUCKET
#         COUNT OF CUSTOMER_ID	    FORMAT IN  NUMBERS
# 		SUM OF TRIPS	            FORMAT IN  NUMBERS
# 		SUM OF SPENT	            FORMAT IN  CURRENCY

# %%
med_suum_v1=med_select_v6.groupby(['Company','GENDER','Customer_Segment','Age_Bucket'],as_index=False).agg(SUBS=('CUSTOMER_ID','count'),VISITS=('NO_OF_TRIPS','sum'),TOTAL_SPENT=('Spent_amount','sum'))

# %%
med_suum_v1
# Out:
#       Company  GENDER Customer_Segment     Age_Bucket  SUBS  VISITS  \
# 0      APPOLO  Female      Non_Premier    Mid_Old_Age    79     263
# 1      APPOLO  Female      Non_Premier  Mid_Young_Age   102     309
# 2      APPOLO  Female      Non_Premier        Old_Age    41     258
# 3      APPOLO  Female      Non_Premier      Young_Age    52     273
# 4      APPOLO  Female          Premier    Mid_Old_Age    50     478
# ..        ...     ...              ...            ...   ...     ...
# 144  RELEGARE    Male          Premier    Mid_Old_Age    29     222
# 145  RELEGARE    Male          Premier  Mid_Young_Age    28     249
# 146  RELEGARE    Male          Premier      Young_Age     1      18
# 147  RELEGARE  Unisex      Non_Premier    Mid_Old_Age     3      15
# 148  RELEGARE  Unisex      Non_Premier  Mid_Young_Age     3      14
#
#      TOTAL_SPENT
# 0       11031.29
# 1       12939.08
# 2       14074.00
# 3       15172.10
# 4       33796.75
# ..           ...
# 144     18023.02
# ...

# %%
med_suum_v1.columns
# Out:
# Index(['Company', 'GENDER', 'Customer_Segment', 'Age_Bucket', 'SUBS', 'VISITS',
#        'TOTAL_SPENT'],
#       dtype='object')

# %%
med_suum_v1['TOTAL_SPENT']=med_suum_v1['TOTAL_SPENT'].map("${:,.0f}".format) # Total_Spent format in Currency

# %%
med_suum_v1['VISITS']=med_suum_v1['VISITS'].map("{:,.0f}".format)  # Visits Format in Number

# %%
med_suum_v1['SUBS']=med_suum_v1['SUBS'].map("{:,.0f}".format) # Subs format in Number

# %%
med_suum_v1 # Final Output
# Out:
#       Company  GENDER Customer_Segment     Age_Bucket SUBS VISITS TOTAL_SPENT
# 0      APPOLO  Female      Non_Premier    Mid_Old_Age   79    263     $11,031
# 1      APPOLO  Female      Non_Premier  Mid_Young_Age  102    309     $12,939
# 2      APPOLO  Female      Non_Premier        Old_Age   41    258     $14,074
# 3      APPOLO  Female      Non_Premier      Young_Age   52    273     $15,172
# 4      APPOLO  Female          Premier    Mid_Old_Age   50    478     $33,797
# ..        ...     ...              ...            ...  ...    ...         ...
# 144  RELEGARE    Male          Premier    Mid_Old_Age   29    222     $18,023
# 145  RELEGARE    Male          Premier  Mid_Young_Age   28    249     $17,621
# 146  RELEGARE    Male          Premier      Young_Age    1     18      $1,288
# 147  RELEGARE  Unisex      Non_Premier    Mid_Old_Age    3     15      $1,039
# 148  RELEGARE  Unisex      Non_Premier  Mid_Young_Age    3     14        $576
#
# [149 rows x 7 columns]

# %% [markdown]
# #### <font color="brwon">Q8	GET THE COUNT OF BLANK VALUES IN COLUMN CONTACT_PREF

# %%
med_select_v6["CONTACT_PREF"].isnull().sum()
# Out:
# 893

# %% [markdown]
# ## <font color="red">TASK-5:--

# %%
df=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-2\ASSIGNMENTS ANS\Data.xlsx",sheet_name="Data1")

# %%
df
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  524  120
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  100  222
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  115  690
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  396  801
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  606  170
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  760  852
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  625  318
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  124  598
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  591  426
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  883  281
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  481  648
# ...

# %% [markdown]
# #### <font color="brown"> Q1	FROM CUSTOMER_MONTHLY_SALES TABLE GET
# 	Q1+Q2+Q3+Q4 AS TOTAL SALES

# %%
df["Q1"]=df['JAN']+df['FEB']+df['MAR']

# %%
df["Q2"]=df['APR']+df['MAY']+df['JUN']

# %%
df["Q3"]=df['JUL']+df['AUG']+df['SEP']

# %%
df["Q4"]=df['OCT']+df['NOV']+df['DEC']

# %%
df["Total_Sales"]=df["Q1"]+df["Q2"]+df["Q3"]+df["Q4"]

# %%
df
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  524  120
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  100  222
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  115  690
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  396  801
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  606  170
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  760  852
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  625  318
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  124  598
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  591  426
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  883  281
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  481  648
# ...

# %% [markdown]
# #### <font color="brown">Q2	GET SALES IN %
# 	Q1 SALES % OVER YEARLY SALES
# 	Q2 SALES % OVER YEARLY SALES
# 	Q3 SALES % OVER YEARLY SALES
# 	Q4 SALES % OVER YEARLY SALES

# %%
df["Q1_sales_perc"] = (df["Q1"]/df["Total_Sales"]).map('{:,.0%}'.format) # Q1 SALES % OVER YEARLY SALES

# %%
df["Q2_sales_perc"] = (df["Q2"]/df["Total_Sales"]).map('{:,.0%}'.format) # Q2 SALES % OVER YEARLY SALES

# %%
df["Q3_sales_perc"] = (df["Q3"]/df["Total_Sales"]).map('{:,.0%}'.format) # Q3 SALES % OVER YEARLY SALES

# %%
df["Q4_sales_perc"] = (df["Q4"]/df["Total_Sales"]).map('{:,.0%}'.format) # Q4 SALES % OVER YEARLY SALES

# %%
df    # Final Output
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  ...  DEC  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  ...  290
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  ...  540
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  ...  232
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  ...  885
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  ...  601
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  ...  660
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  ...  690
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  ...  178
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  ...  661
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  ...  365
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  ...  180
# ...

# %% [markdown]
# ## <font color="red">TASK-6:---

# %% [markdown]
# #### <font color="brown">Q1	CREATE A NEW DATASET CALLED STU_MASTER

# %%
df2=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-2\ASSIGNMENTS ANS\Data.xlsx",sheet_name='Data2')

# %%
df2
# Out:
#             FULL NAME         CITY STATE       PHONE DATE OF JOINING  \
# 0          James Butt  New Orleans    LA  5046218927      2019-02-11
# 1          James Butt  New Orleans    LA  5046218927      2019-02-11
# 2          James Butt  New Orleans    LA  5046218927      2019-02-11
# 3          James Butt  New Orleans    LA  5046218927      2019-02-11
# 4          James Butt  New Orleans    LA  5046218927      2019-02-11
# ...               ...          ...   ...         ...             ...
# 3965  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3966  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3967  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3968  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3969  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
#
#            COURSE ENVIRONMENT      TOOL    FEE
# 0     MINI MODULE      NORMAL     EXCEL  10000
# ...

# %% [markdown]
# #### <font color="brown">Q2	CREATE A NEW FIELD DISCOUNT BASED ON CONDITIONS AS BELOW IMAGE

# %% [markdown]
# ![Screenshot%206.png](attachment:Screenshot%206.png)

# %%
df2["Discount"]=0.05
df2["Discount"][(df2['COURSE']=='MPIDS') & (df2['TOOL']=='SAS') & (df2['FEE']==25000)]=0.2
df2["Discount"][(df2['COURSE']=='MPIDS') & (df2['TOOL']=='POWER BI') & (df2['FEE']==19000)]=0.3
df2["Discount"][(df2['COURSE']=='MPIDS') & (df2['TOOL']=='ADVANCED ANALYTICS') & (df2['FEE']==45000)]=0.1
df2["Discount"][(df2['COURSE']=='MPIDS') & (df2['TOOL']=='MACHINE LEARNING') & (df2['FEE']==70000)]=0.2
df2["Discount"][(df2['COURSE']=='ADA') & (df2['TOOL']=='SQL') & (df2['FEE']==15000)]=0.1
df2["Discount"][(df2['COURSE']=='ADA') & (df2['TOOL']=='PYTHON') & (df2['FEE']==15000)]=0.1
df2["Discount"][(df2['COURSE']=='ADA') & (df2['TOOL']=='SAS') & (df2['FEE']==25000)]=0.2
df2["Discount"][(df2['COURSE']=='ADA') & (df2['TOOL']=='R') & (df2['FEE']==15000)]=0.1
df2["Discount"][(df2['COURSE']=='ADA') & (df2['TOOL']=='ADVANCED ANALYTICS') & (df2['FEE']==45000)]=0.1
df2["Discount"][(df2['COURSE']=='DAS') & (df2['TOOL']=='SAS') & (df2['FEE']==25000)]=0.2
df2["Discount"][(df2['COURSE']=='MINI MODULE') & (df2['TOOL']=='TABLEAU') & (df2['FEE']==17000)]=0.1
df2["Discount"][(df2['COURSE']=='MINI MODULE') & (df2['TOOL']=='POWER BI') & (df2['FEE']==19000)]=0.1

# %%
df2["Discount_percentage"]=df2["Discount"].map('{:,.0%}'.format)

# %%
df2
# Out:
#             FULL NAME         CITY STATE       PHONE DATE OF JOINING  \
# 0          James Butt  New Orleans    LA  5046218927      2019-02-11
# 1          James Butt  New Orleans    LA  5046218927      2019-02-11
# 2          James Butt  New Orleans    LA  5046218927      2019-02-11
# 3          James Butt  New Orleans    LA  5046218927      2019-02-11
# 4          James Butt  New Orleans    LA  5046218927      2019-02-11
# ...               ...          ...   ...         ...             ...
# 3965  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3966  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3967  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3968  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3969  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
#
#            COURSE ENVIRONMENT      TOOL    FEE  Discount Discount_percentage
# ...

# %% [markdown]
# #### <font color="brown">Q2	CREATE A NEW FIELD FINAL_FEE=FEE-DISCOUNT

# %%
df2["Final_Fee"]=df2["FEE"]-df2["FEE"]-df2["Discount_percentage"].str.rstrip("%").astype("float")

# %%
df2
# Out:
#             FULL NAME         CITY STATE       PHONE DATE OF JOINING  \
# 0          James Butt  New Orleans    LA  5046218927      2019-02-11
# 1          James Butt  New Orleans    LA  5046218927      2019-02-11
# 2          James Butt  New Orleans    LA  5046218927      2019-02-11
# 3          James Butt  New Orleans    LA  5046218927      2019-02-11
# 4          James Butt  New Orleans    LA  5046218927      2019-02-11
# ...               ...          ...   ...         ...             ...
# 3965  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3966  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3967  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3968  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
# 3969  Chauncey Motley      Orlando    FL  4074134842      2020-09-02
#
#            COURSE ENVIRONMENT      TOOL    FEE  Discount Discount_percentage  \
# ...

# %% [markdown]
# ## <font color="red">TASK-7:--

# %% [markdown]
# #### <font color="brown"> Q1	CONVERT COLUMNS INTO ROWS

# %%
tdf=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-2\ASSIGNMENTS ANS\Data.xlsx",sheet_name="TData1")

# %%
tdf
# Out:
#     CUSTOMER_ID    Company  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  \
# 0    1000032547      MED +  317  877  794  219  635  617  777  803  524  120
# 1    1000032548  DR.REDDYS  178  133  193  879  638  752  476  316  100  222
# 2    1000032549   RELEGARE  294  649  105  124  357  518  831  164  115  690
# 3    1000032550        GSK  368  293  322  597  722  475  559  438  396  801
# 4    1000032551        GSK  490  843  850  559  656  850  137  500  606  170
# 5    1000032552     APPOLO  184  381  260  107  654  490  243  763  760  852
# 6    1000032553      CIPLA  176  164  281  221  338  349  162  657  625  318
# 7    1000032554     APPOLO  666  477  647  262  325  532  550  445  124  598
# 8    1000032555     APPOLO  367  590  248  715  563  181  696  228  591  426
# 9    1000032556      MED +  797  883  783  733  484  144  613  575  883  281
# 10   1000032557        GSK  655  275  128  234  234  838  515  291  481  648
# ...

# %%
Col_Row=tdf.melt(id_vars=["CUSTOMER_ID","Company"],var_name="Month",value_name="Sales")

# %%
Col_Row
# Out:
#      CUSTOMER_ID    Company Month  Sales
# 0     1000032547      MED +   JAN    317
# 1     1000032548  DR.REDDYS   JAN    178
# 2     1000032549   RELEGARE   JAN    294
# 3     1000032550        GSK   JAN    368
# 4     1000032551        GSK   JAN    490
# ..           ...        ...   ...    ...
# 355   1000032572        GSK   DEC    437
# 356   1000032573       GENO   DEC    333
# 357   1000032574        GSK   DEC    597
# 358   1000032575      MED +   DEC    248
# 359   1000032576      CIPLA   DEC    591
#
# [360 rows x 4 columns]

# %% [markdown]
# ## <font color="red">TASK-8:----

# %% [markdown]
# #### <font color="brown">Q1	CONVERT ROWS INTO COLS

# %%
tdf1=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-2\ASSIGNMENTS ANS\Data.xlsx",sheet_name="TData2")

# %%
tdf1
# Out:
#      CUSTOMER_ID Company  MONTH  SALES
# 0     1000032547    MED+   2010    317
# 1     1000032547    MED+   2011    877
# 2     1000032547    MED+   2012    794
# 3     1000032547    MED+   2013    219
# 4     1000032547    MED+   2014    635
# ..           ...     ...    ...    ...
# 139   1000032558    MED+   2017    184
# 140   1000032558    MED+   2018    614
# 141   1000032558    MED+   2019    187
# 142   1000032558    MED+   2020    506
# 143   1000032558    MED+   2021    803
#
# [144 rows x 4 columns]

# %%
Row_Col=tdf1.pivot(index=["CUSTOMER_ID","Company"],columns="MONTH",values="SALES").fillna("").reset_index()

# %%
Row_Col
# Out:
# MONTH  CUSTOMER_ID    Company  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0       1000032547       MED+   317   877   794   219   635   617   777   803
# 1       1000032548  DR.REDDYS   178   133   193   879   638   752   476   316
# 2       1000032549   RELEGARE   294   649   105   124   357   518   831   164
# 3       1000032550        GSK   368   293   322   597   722   475   559   438
# 4       1000032551        GSK   490   843   850   559   656   850   137   500
# 5       1000032552     APPOLO   184   381   260   107   654   490   243   763
# 6       1000032553      CIPLA   176   164   281   221   338   349   162   657
# 7       1000032554     APPOLO   666   477   647   262   325   532   550   445
# 8       1000032555     APPOLO   367   590   248   715   563   181   696   228
# 9       1000032556       MED+   797   883   783   733   484   144   613   575
# 10      1000032557        GSK   655   275   128   234   234   838   515   291
# ...
