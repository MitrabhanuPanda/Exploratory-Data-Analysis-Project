# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## <FONT COLOR="RED">TASK--2

# %% [markdown]
# ### <font color='brown'>Q1	CREATE A DATAFRAME CALLED CUSTOMER_MASTER

# %%
customer_master=pd.DataFrame(
    {
        "customer_id":["1000032547","1000032548","1000032549","1000032550","1000032551","1000032552","1000032553","1000032554","1000032555","1000032556","1000032557","1000032558","1000032559","1000032560","1000032561","1000032562","1000032563","1000032564","1000032565","1000032566","1000032567"
                    ],
        "customer_name":["Rick Hansen","Justin Ritter","Craig Reiter","Katherine Murray","Rick Hansen","Jim Mitchum","Toby Swindell","Mick Brown","Jane Waco","Joseph Holt","Greg Maxwell","Anthony Jacobs","Magdelene Morse","Vicky Freymann","Peter Fuller","Ben Peterman","Thomas Boland","Patrick Jones","Jim Sink","Ritsa Hightower","Ann Blume"
                    ],
        "customer_ssn":["RH-19495","JR-16210","CR-12730","KM-16375",np.nan,"RH-9495","TS-21340","MB-18085","JW-15220","JH-15985","GM-14695","AJ-10780","MM-7260","VF-21715","PF-19120","BP-11185","TB-21175","PJ-18835",np.nan,"RH-9555","AB-600"
                    ],
        "city":["New York City","Wollongong","Brisbane","Berlin","Dakar","Sydney","Porirua","Hamilton","Sacramento","Concord","Alexandria",np.nan,"Jizan","Toledo","Mudanjiang","Paris","Henderson","Prato","Townsville","Uvinza","Bytom"
                    ],
        "market":["US","APAC","APAC","EU","Africa","APAC","APAC","APAC","US","US","US","APAC","EMEA","LATAM","APAC","EU","US","EU","APAC","Africa","EMEA"
                    ],
        "dob":["15-09-1984","15-07-1974","01-04-1959","16-05-1978","16-12-1978","21-07-1987","07-11-1986","29-04-1987","04-03-1958","15-08-1952","26-12-1984","17-02-1956","11-04-1979","12-03-1985",np.nan,"10-01-1952","10-07-1965","20-07-1948","30-09-1949","21-10-1948","31-05-1972"
                    ],
        "town":["Kyabram","Hawthorn East","Revesby","Willow Grove","mona vale","Rowville","MINNAMURRA","Lake Illawarra","Vermont South","Blackburn Nth","Rowville","Box Hill North","FOREST HILL","BERWICK","Buderim",np.nan,"scarness","Kuluin","Menai",np.nan,"BARRACK HEIGHTS"
                ]
    })

# %%
customer_master
# Out:
#    customer_id     customer_name customer_ssn           city  market  \
# 0   1000032547       Rick Hansen     RH-19495  New York City      US
# 1   1000032548     Justin Ritter     JR-16210     Wollongong    APAC
# 2   1000032549      Craig Reiter     CR-12730       Brisbane    APAC
# 3   1000032550  Katherine Murray     KM-16375         Berlin      EU
# 4   1000032551       Rick Hansen          NaN          Dakar  Africa
# 5   1000032552       Jim Mitchum      RH-9495         Sydney    APAC
# 6   1000032553     Toby Swindell     TS-21340        Porirua    APAC
# 7   1000032554        Mick Brown     MB-18085       Hamilton    APAC
# 8   1000032555         Jane Waco     JW-15220     Sacramento      US
# 9   1000032556       Joseph Holt     JH-15985        Concord      US
# 10  1000032557      Greg Maxwell     GM-14695     Alexandria      US
# 11  1000032558    Anthony Jacobs     AJ-10780            NaN    APAC
# 12  1000032559   Magdelene Morse      MM-7260          Jizan    EMEA
# ...

# %% [markdown]
# ### <font color='brown'>Q2	DESCRIBE THE DATASET CUSTOMER_MASTER
# 			GET NUMBER OF COLUMNS AND RECORDS IN THE DATASET
# 			GET THE LIST OF COLUMNS HEADERS NAME
# 			GET FIRST 3 RECORDS FROM THE DATASET
# 			GET LAST 3 RECORDS FROM THE DATASET
# 			GET VARIABLES DATA TYPES
# 			GET THE TOTAL MISSING RECORDS IN THE DATASET
# 			GET THE TOTAL MISSING RECORDS IN THE VARIABLE CUSTOMER_SSN

# %% [markdown]
# #### <font color='blue'>GET NUMBER OF COLUMNS AND RECORDS IN THE DATASET

# %%
customer_master.shape
# Out:
# (21, 7)

# %% [markdown]
# #### <font color="blue">GET THE LIST OF COLUMNS HEADERS NAME

# %%
customer_master.columns
# Out:
# Index(['customer_id', 'customer_name', 'customer_ssn', 'city', 'market', 'dob',
#        'town'],
#       dtype='object')

# %% [markdown]
# #### <font color='blue'>GET FIRST 3 RECORDS FROM THE DATASET

# %%
customer_master.head(3)
# Out:
#   customer_id  customer_name customer_ssn           city market         dob  \
# 0  1000032547    Rick Hansen     RH-19495  New York City     US  15-09-1984
# 1  1000032548  Justin Ritter     JR-16210     Wollongong   APAC  15-07-1974
# 2  1000032549   Craig Reiter     CR-12730       Brisbane   APAC  01-04-1959
#
#             town
# 0        Kyabram
# 1  Hawthorn East
# 2        Revesby

# %% [markdown]
# #### <font color="blue">GET LAST 3 RECORDS FROM THE DATASET

# %%
customer_master.tail(3)
# Out:
#    customer_id    customer_name customer_ssn        city  market         dob  \
# 18  1000032565         Jim Sink          NaN  Townsville    APAC  30-09-1949
# 19  1000032566  Ritsa Hightower      RH-9555      Uvinza  Africa  21-10-1948
# 20  1000032567        Ann Blume       AB-600       Bytom    EMEA  31-05-1972
#
#                town
# 18            Menai
# 19              NaN
# 20  BARRACK HEIGHTS

# %% [markdown]
# #### <font color="blue">GET VARIABLES DATA TYPES

# %%
customer_master.dtypes
# Out:
# customer_id      object
# customer_name    object
# customer_ssn     object
# city             object
# market           object
# dob              object
# town             object
# dtype: object

# %% [markdown]
# #### <font color="blue">GET THE TOTAL MISSING RECORDS IN THE DATASET

# %%
customer_master.isnull().sum().sum()
# Out:
# 6

# %% [markdown]
# #### <font color="blue">GET THE TOTAL MISSING RECORDS IN THE VARIABLE CUSTOMER_SSN

# %%
customer_master['customer_ssn'].isnull().sum()
# Out:
# 2

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red">TASK--3

# %% [markdown]
# ### <FONT COLOR="BROWN">Q1	IMPORT DATA FROM 	DATA FOLDER IN THE ASSIGNMENT
# 			ACCOUNT_PERF_DATA.xlsx
# 			ACCOUNT_PERF_DATA.csv
# 			ACCOUNT_PERF_DATA.txt
#
# 		GIVE DATASET NAME
#             ACCOUNT_PERF_DATA.xlsx	ACCOUNT_PERF_EXCEL
# 			ACCOUNT_PERF_DATA.csv	ACCOUNT_PERF_CSV
# 			ACCOUNT_PERF_DATA.txt	ACCOUNT_PERF_TXT

# %% [markdown]
# #### <FONT COLOR="BLUE">IMPORT DATA FROM EXCEL FILE & NAME THE FILE -- ACCOUNT_PERF_EXCEL

# %%
account_perf_excel=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-1\ASSIGNMENTS ANS\DATA\ACCOUNT_PERF_DATA.xlsx")

# %%
account_perf_excel
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# #### <FONT COLOR="BLUE">IMPORT DATA FROM EXCEL FILE & NAME THE FILE -- ACCOUNT_PERF_CSV

# %%
account_perf_csv=pd.read_csv(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-1\ASSIGNMENTS ANS\DATA\ACCOUNT_PERF_DATA.csv")

# %%
account_perf_csv
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %% [markdown]
# #### <FONT COLOR="BLUE">IMPORT DATA FROM EXCEL FILE & NAME THE FILE -- ACCOUNT_PERF_txt

# %%
account_perf_txt=pd.read_csv(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-1\ASSIGNMENTS ANS\DATA\ACCOUNT_PERF_DATA.txt",sep="\t")

# %%
account_perf_txt
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
account_perf_excel.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'Phone No. ', 'Place Name',
#        'County', 'City', 'State', 'Zip', 'Region', 'Account Open Date',
#        'Loan_amount', 'Loan_status', 'Last_payment_date',
#        'Origination_fico_score', 'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %% [markdown]
# ### <font color="brown"> Q2	WRITE PROGRAM TO CREATE A NEW DATASET AS ACCOUNT_PERF_V1 FROM ACCOUNT_PERF_EXCEL
# 		KEEP VARIABLES
#             Account_number
# 			PORTFOLIO
# 			SSN
# 			Phone No.
# 			City
# 			State
# 			Account Open Date
# 			Loan_amount
# 			Origination_fico_score
# 			Current_fico_score
# 			Current_outstanding

# %%
# some columns have spaces so first remove them.
account_perf_excel.columns=account_perf_excel.columns.str.replace(" ","")
account_perf_excel.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'PhoneNo.', 'PlaceName', 'County',
#        'City', 'State', 'Zip', 'Region', 'AccountOpenDate', 'Loan_amount',
#        'Loan_status', 'Last_payment_date', 'Origination_fico_score',
#        'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %%
account_perf_v1=account_perf_excel[['Account_number','PORTFOLIO','SSN', 'PhoneNo.','City','State','AccountOpenDate','Loan_amount','Origination_fico_score','Current_fico_score','Current_outstanding']]

# %%
account_perf_v1
# Out:
#        Account_number      PORTFOLIO          SSN      PhoneNo.  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#                  City State AccountOpenDate  Loan_amount  \
# 0             Bromide    OK      2018-03-13        40169
# 1      Reading Center    NY      2019-06-23       187055
# ...

# %% [markdown]
# #### <font color="blue">Q3	PRINT FIRST 1000 OBSERVATIONS FROM NEW DATASET ACCOUNT_PERF_V1

# %%
account_perf_v1.head(1000)
# Out:
#      Account_number      PORTFOLIO          SSN      PhoneNo.            City  \
# 0          38673575    CREDIT CARD  640-29-9264  405-775-9884         Bromide
# 1          38673576  PERSONAL LOAN  375-37-8517  212-786-7533  Reading Center
# 2          38673577  PERSONAL LOAN  073-02-5563  385-775-0225          Ibapah
# 3          38673578       MORTGAGE  106-98-7919  216-984-8974       Wickliffe
# 4          38673579    CREDIT CARD  753-07-4655  217-307-8597         Forrest
# ..              ...            ...          ...           ...             ...
# 995        38674570    CREDIT CARD  059-02-7412  225-732-1222     New Orleans
# 996        38674571    CREDIT CARD  274-17-5324  218-652-2488         Maynard
# 997        38674572       MORTGAGE  061-02-3181  229-491-7441      Bainbridge
# 998        38674573       MORTGAGE  063-02-8673  603-857-2424  Center Ossipee
# 999        38674574    CREDIT CARD  008-94-6199  205-655-3751     Robertsdale
#
# ...

# %% [markdown]
# #### <font color="blue">Q4	GET THE LIST OF VARIABLES DATA TYPES

# %%
# To get lists of variables
account_perf_v1.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'PhoneNo.', 'City', 'State',
#        'AccountOpenDate', 'Loan_amount', 'Origination_fico_score',
#        'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %%
# To get all the variables with their data types
account_perf_v1.dtypes
# Out:
# Account_number                     int64
# PORTFOLIO                         object
# SSN                               object
# PhoneNo.                          object
# City                              object
# State                             object
# AccountOpenDate           datetime64[ns]
# Loan_amount                        int64
# Origination_fico_score             int64
# Current_fico_score                 int64
# Current_outstanding              float64
# dtype: object

# %% [markdown]
# #### <font color="blue">Q5	IDENTIFY THE LIST OF VARIABLES WITH DATA TYPE AS INT AND FLOAT

# %%
account_perf_v1.select_dtypes(include=["int","float"]).columns
# Out:
# Index(['Account_number', 'Loan_amount', 'Origination_fico_score',
#        'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %% [markdown]
# #### <font color="blue"> Q6	GET THE TOTAL MISSING VALUES IN THE DATASET

# %%
account_perf_v1.isnull().sum().sum()
# Out:
# 150

# %% [markdown]
# #### <font color="blue">Q7	GET THE TOTAL MISSING VALUES IN THE VARIABLE SSN

# %%
account_perf_v1["SSN"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### <font color="blue">Q8	WRITE PROGRAM TO CREATE A NEW DATASET AS ACCOUNT_PERF_V2 FROM ACCOUNT_PERF_EXCEL
# 		DROP VARIABLES
# 			Place Name
# 			County
# 			City
# 			Region
# 			Loan_status
# 			Origination_fico_score
# 			Current_fico_score

# %%
account_perf_excel.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'PhoneNo.', 'PlaceName', 'County',
#        'City', 'State', 'Zip', 'Region', 'AccountOpenDate', 'Loan_amount',
#        'Loan_status', 'Last_payment_date', 'Origination_fico_score',
#        'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %%
account_perf_v2=account_perf_excel.drop(['PlaceName','County','City','Region','Loan_status','Origination_fico_score','Current_fico_score'],axis=1)

# %%
account_perf_v2
# Out:
#        Account_number      PORTFOLIO          SSN      PhoneNo. State    Zip  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884    OK  74530
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533    NY  14876
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225    UT  84034
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974    OH  44092
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597    IL  61741
# ...               ...            ...          ...           ...   ...    ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904    NJ   8090
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762    CA  95255
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318    NY  13225
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734    NY  11797
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770    GA  30813
#
# ...

# %% [markdown]
# #### <font color="blue">Q9	EXPORT DATASET TO ACCOUNT_PERF_V1
#
#         TO ACCOUNT_PERF_V1.xlsx
# 		TO ACCOUNT_PERF_V1.txt with comma delimiter
# 		TO ACCOUNT_PERF_V1.csv

# %%
account_perf_v1.to_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-1\ASSIGNMENTS ANS\OUTPUT DATA\account_perf_v1.xlsx",sheet_name="account_perf_v1_export")

# %%
account_perf_v1.to_csv(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-1\ASSIGNMENTS ANS\OUTPUT DATA\account_perf_v1_csv.csv")

# %%
account_perf_v1.to_csv(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\PYTHON\SESSION-1\ASSIGNMENTS ANS\OUTPUT DATA\account_perf_v1_txt.txt",sep=",")
