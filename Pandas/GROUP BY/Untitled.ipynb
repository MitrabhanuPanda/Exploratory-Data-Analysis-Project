# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS SUMMARIZATION\GROUP BY\MED_STORE_2022.xlsx")

# %%
df.head()
# Out:
#    CUSTOMER_ID    Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  firstSTOR  \
# 0   1000032547      MED +    2006-09-12           Y    2007-05-12       2587
# 1   1000032548  DR.REDDYS    2006-09-12           Y    2007-03-12       4341
# 2   1000032549   RELEGARE    2006-09-12           Y    2007-02-12       1090
# 3   1000032550        GSK    2006-09-12           Y    2007-03-12       3179
# 4   1000032551        GSK    2006-09-12           Y    2007-05-12       3135
#
#   TITLE  GENDER  max_spent        DOB  ... CUST_STAT  Avgsize_spent  \
# 0  Mrs.  Female      56.31 1984-09-15  ...    Active          17.34
# 1   Ms.  Female     598.95 1974-07-15  ...    Active          29.32
# 2  Mrs.  Female       1.56 1959-04-01  ...    Active           1.56
# 3   Mr.    Male     115.76 1978-05-16  ...    Active          80.49
# 4   Mr.    Male     305.90 1978-12-16  ...    Active          24.09
#
#     CARD_STAT  RGSTN_TYPE_IND NO_OF_TRIPS           TOWN EMAIL_IND  \
# ...

# %%
df.columns
# Out:
# Index(['CUSTOMER_ID', 'Company', 'CARD_REG_DATE', 'CARD_ACTIVE',
#        'FIRST_USE_DTE', 'firstSTOR', 'TITLE', 'GENDER', 'max_spent', 'DOB',
#        'FTD', 'Age', 'STATE_CODE', 'POST_CODE', 'CUST_STAT', 'Avgsize_spent',
#        'CARD_STAT', 'RGSTN_TYPE_IND', 'NO_OF_TRIPS', 'TOWN', 'EMAIL_IND',
#        'CONTACT_PREF', 'Average_Qty_PER_ACC', 'Spent_amount'],
#       dtype='object')

# %%
df.groupby(["Company"],as_index=False).agg(subs=("NO_OF_TRIPS","sum"))
# Out:
#      Company  subs
# 0     APPOLO  3154
# 1      CIPLA  2943
# 2  DR.REDDYS  3326
# 3       GENO  2737
# 4        GSK  3395
# 5   GUARDIAN  2979
# 6      MED +  3060
# 7    RANBAXY  2839
# 8   RELEGARE  2706

# %%
df.groupby(["Company"],as_index=False).agg(subs=("Age","mean"))
# Out:
#      Company       subs
# 0     APPOLO  49.493103
# 1      CIPLA  50.383538
# 2  DR.REDDYS  50.901042
# 3       GENO  50.185639
# 4        GSK  50.111296
# 5   GUARDIAN  49.440585
# 6      MED +  51.015411
# 7    RANBAXY  50.206049
# 8   RELEGARE  50.150362

# %%
dfw=df.groupby(["Company","STATE_CODE"],as_index=False).agg(sub=("CUSTOMER_ID","count"))
dfw
# Out:
#      Company STATE_CODE  sub
# 0     APPOLO        ACT   18
# 1     APPOLO        NSW  128
# 2     APPOLO         NT    5
# 3     APPOLO        QLD  147
# 4     APPOLO         SA   30
# ..       ...        ...  ...
# 58  RELEGARE         NT    3
# 59  RELEGARE        QLD  161
# 60  RELEGARE         SA   34
# 61  RELEGARE        VIC   73
# 62  RELEGARE         WA  146
#
# [63 rows x 3 columns]

# %%
dfw["ranks"]=dfw["sub"].rank().astype(int)
dfw[dfw["ranks"].i
# Out:
#      Company STATE_CODE  sub  cumsum  ranks
# 23      GENO         NT    2    1880      1
# 37  GUARDIAN         NT    2    3036      1

# %%
dfw["cumsum"]=dfw[["sub"]].apply(lambda x: x.cumsum())

# %%
dfw
# Out:
#      Company STATE_CODE  sub  cumsum
# 0     APPOLO        ACT   18      18
# 1     APPOLO        NSW  128     146
# 2     APPOLO         NT    5     151
# 3     APPOLO        QLD  147     298
# 4     APPOLO         SA   30     328
# ..       ...        ...  ...     ...
# 58  RELEGARE         NT    3    4698
# 59  RELEGARE        QLD  161    4859
# 60  RELEGARE         SA   34    4893
# 61  RELEGARE        VIC   73    4966
# 62  RELEGARE         WA  146    5112
#
# [63 rows x 4 columns]

# %%
dfw.groupby(["STATE_CODE"]).first().reset_index()
# Out:
#   STATE_CODE Company  sub  cumsum
# 0        ACT  APPOLO   18      18
# 1        NSW  APPOLO  128     146
# 2         NT  APPOLO    5     151
# 3        QLD  APPOLO  147     298
# 4         SA  APPOLO   30     328
# 5        VIC  APPOLO   87     415
# 6         WA  APPOLO  165     580

# %%
df[["Company","STATE_CODE"]]
# Out:
#         Company STATE_CODE
# 0         MED +        QLD
# 1     DR.REDDYS         WA
# 2      RELEGARE        NSW
# 3           GSK        VIC
# 4           GSK        VIC
# ...         ...        ...
# 5107   RELEGARE         WA
# 5108     APPOLO         WA
# 5109        GSK         WA
# 5110      MED +         WA
# 5111    RANBAXY         WA
#
# [5112 rows x 2 columns]

# %%
df.loc[0:20,["CUSTOMER_ID","Company"]]
# Out:
#     CUSTOMER_ID    Company
# 0    1000032547      MED +
# 1    1000032548  DR.REDDYS
# 2    1000032549   RELEGARE
# 3    1000032550        GSK
# 4    1000032551        GSK
# 5    1000032552     APPOLO
# 6    1000032553      CIPLA
# 7    1000032554     APPOLO
# 8    1000032555     APPOLO
# 9    1000032556      MED +
# 10   1000032557        GSK
# 11   1000032558      MED +
# 12   1000032559       GENO
# 13   1000032560  DR.REDDYS
# 14   1000032561   RELEGARE
# 15   1000032562   GUARDIAN
# 16   1000032563   RELEGARE
# 17   1000032564   GUARDIAN
# 18   1000032565       GENO
# 19   1000032566    RANBAXY
# 20   1000032567      MED +

# %%
df.iloc[0:20,[0,1]]
# Out:
#     CUSTOMER_ID    Company
# 0    1000032547      MED +
# 1    1000032548  DR.REDDYS
# 2    1000032549   RELEGARE
# 3    1000032550        GSK
# 4    1000032551        GSK
# 5    1000032552     APPOLO
# 6    1000032553      CIPLA
# 7    1000032554     APPOLO
# 8    1000032555     APPOLO
# 9    1000032556      MED +
# 10   1000032557        GSK
# 11   1000032558      MED +
# 12   1000032559       GENO
# 13   1000032560  DR.REDDYS
# 14   1000032561   RELEGARE
# 15   1000032562   GUARDIAN
# 16   1000032563   RELEGARE
# 17   1000032564   GUARDIAN
# 18   1000032565       GENO
# 19   1000032566    RANBAXY

# %%
df.loc[0:20]
# Out:
#     CUSTOMER_ID    Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  firstSTOR  \
# 0    1000032547      MED +    2006-09-12           Y    2007-05-12       2587
# 1    1000032548  DR.REDDYS    2006-09-12           Y    2007-03-12       4341
# 2    1000032549   RELEGARE    2006-09-12           Y    2007-02-12       1090
# 3    1000032550        GSK    2006-09-12           Y    2007-03-12       3179
# 4    1000032551        GSK    2006-09-12           Y    2007-05-12       3135
# 5    1000032552     APPOLO    2007-07-09           Y    2007-02-12       5688
# 6    1000032553      CIPLA    2006-09-12           Y    2008-12-01       5687
# 7    1000032554     APPOLO    2006-09-12           Y    2007-10-12       5689
# 8    1000032555     APPOLO    2006-09-12           Y    2007-01-12       3196
# 9    1000032556      MED +    2006-09-12           Y    2007-03-12       3227
# 10   1000032557        GSK    2006-09-12           Y    2007-03-12       5739
# ...

# %%
df.iloc[0:20,0:2]
# Out:
#     CUSTOMER_ID    Company
# 0    1000032547      MED +
# 1    1000032548  DR.REDDYS
# 2    1000032549   RELEGARE
# 3    1000032550        GSK
# 4    1000032551        GSK
# 5    1000032552     APPOLO
# 6    1000032553      CIPLA
# 7    1000032554     APPOLO
# 8    1000032555     APPOLO
# 9    1000032556      MED +
# 10   1000032557        GSK
# 11   1000032558      MED +
# 12   1000032559       GENO
# 13   1000032560  DR.REDDYS
# 14   1000032561   RELEGARE
# 15   1000032562   GUARDIAN
# 16   1000032563   RELEGARE
# 17   1000032564   GUARDIAN
# 18   1000032565       GENO
# 19   1000032566    RANBAXY

# %%
df[0:5].index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.drop(index=df[0:5].index)
# Out:
#       CUSTOMER_ID   Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  \
# 5      1000032552    APPOLO    2007-07-09           Y    2007-02-12
# 6      1000032553     CIPLA    2006-09-12           Y    2008-12-01
# 7      1000032554    APPOLO    2006-09-12           Y    2007-10-12
# 8      1000032555    APPOLO    2006-09-12           Y    2007-01-12
# 9      1000032556     MED +    2006-09-12           Y    2007-03-12
# ...           ...       ...           ...         ...           ...
# 5107   1000037830  RELEGARE    2008-05-06           Y    2009-05-02
# 5108   1000037831    APPOLO    2008-05-06           Y    2008-10-06
# 5109   1000037832       GSK    2008-05-06           Y    2009-05-04
# 5110   1000037833     MED +    2008-05-06           Y    2009-06-10
# 5111   1000037834   RANBAXY    2008-05-06           Y    2009-05-04
#
#       firstSTOR TITLE  GENDER  max_spent        DOB  ... CUST_STAT  \
# 5          5688   Ms.  Female     724.05 1987-07-21  ...    Active
# ...

# %%
df.drop(columns=df.columns[0:4])
# Out:
#      FIRST_USE_DTE  firstSTOR TITLE  GENDER  max_spent        DOB  \
# 0       2007-05-12       2587  Mrs.  Female      56.31 1984-09-15
# 1       2007-03-12       4341   Ms.  Female     598.95 1974-07-15
# 2       2007-02-12       1090  Mrs.  Female       1.56 1959-04-01
# 3       2007-03-12       3179   Mr.    Male     115.76 1978-05-16
# 4       2007-05-12       3135   Mr.    Male     305.90 1978-12-16
# ...            ...        ...   ...     ...        ...        ...
# 5107    2009-05-02       3381   Mr.    Male     198.36 1935-11-23
# 5108    2008-10-06       3244  Mrs.  Female      28.09 1956-08-27
# 5109    2009-05-04       3381  Mrs.  Female     653.10 1982-05-13
# 5110    2009-06-10       3130   Ms.  Female     228.55 1960-01-14
# 5111    2009-05-04       3363  Mrs.  Female      26.35 1971-12-22
#
#                     FTD  Age STATE_CODE  POST_CODE CUST_STAT  Avgsize_spent  \
# 0     9/25/2013 0:00:00   29        QLD       4701    Active          17.34
# ...

# %%
df.columns[0:4]
# Out:
# Index(['CUSTOMER_ID', 'Company', 'CARD_REG_DATE', 'CARD_ACTIVE'], dtype='object')

# %%
df.head()
# Out:
#    CUSTOMER_ID    Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  firstSTOR  \
# 0   1000032547      MED +    2006-09-12           Y    2007-05-12       2587
# 1   1000032548  DR.REDDYS    2006-09-12           Y    2007-03-12       4341
# 2   1000032549   RELEGARE    2006-09-12           Y    2007-02-12       1090
# 3   1000032550        GSK    2006-09-12           Y    2007-03-12       3179
# 4   1000032551        GSK    2006-09-12           Y    2007-05-12       3135
#
#   TITLE  GENDER  max_spent        DOB  ... CUST_STAT  Avgsize_spent  \
# 0  Mrs.  Female      56.31 1984-09-15  ...    Active          17.34
# 1   Ms.  Female     598.95 1974-07-15  ...    Active          29.32
# 2  Mrs.  Female       1.56 1959-04-01  ...    Active           1.56
# 3   Mr.    Male     115.76 1978-05-16  ...    Active          80.49
# 4   Mr.    Male     305.90 1978-12-16  ...    Active          24.09
#
#     CARD_STAT  RGSTN_TYPE_IND NO_OF_TRIPS           TOWN EMAIL_IND  \
# ...

# %%
df[df["Company"]=="GSK"]
# Out:
#       CUSTOMER_ID Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  firstSTOR  \
# 3      1000032550     GSK    2006-09-12           Y    2007-03-12       3179
# 4      1000032551     GSK    2006-09-12           Y    2007-05-12       3135
# 10     1000032557     GSK    2006-09-12           Y    2007-03-12       5739
# 25     1000032572     GSK    2006-09-12           Y    2007-03-12       2650
# 27     1000032574     GSK    2006-09-12           Y    2008-12-07       1087
# ...           ...     ...           ...         ...           ...        ...
# 5086   1000037809     GSK    2008-05-06           Y    2008-10-06       3340
# 5098   1000037821     GSK    2008-05-06           Y    2010-05-02       1132
# 5101   1000037824     GSK    2008-05-06           Y    2008-09-06       1092
# 5105   1000037828     GSK    2008-05-06           Y    2008-12-21       3330
# 5109   1000037832     GSK    2008-05-06           Y    2009-05-04       3381
#
# ...

# %%
a=["Company","CUSTOMER_ID","CARD_ACTIVE"]

# %%
df[a][df["Company"]=="GSK"]
# Out:
#      Company  CUSTOMER_ID CARD_ACTIVE
# 3        GSK   1000032550           Y
# 4        GSK   1000032551           Y
# 10       GSK   1000032557           Y
# 25       GSK   1000032572           Y
# 27       GSK   1000032574           Y
# ...      ...          ...         ...
# 5086     GSK   1000037809           Y
# 5098     GSK   1000037821           Y
# 5101     GSK   1000037824           Y
# 5105     GSK   1000037828           Y
# 5109     GSK   1000037832           Y
#
# [602 rows x 3 columns]

# %%
df[a][(df["Company"]=="GSK") & (df["TOWN"].isin(["Rowville","warilla","Buderim"])) |(df["NO_OF_TRIPS"].between(5,10))]
# Out:
#         Company  CUSTOMER_ID CARD_ACTIVE
# 5        APPOLO   1000032552           Y
# 6         CIPLA   1000032553           Y
# 7        APPOLO   1000032554           Y
# 10          GSK   1000032557           Y
# 20        MED +   1000032567           Y
# ...         ...          ...         ...
# 5099  DR.REDDYS   1000037822           Y
# 5100      CIPLA   1000037823           Y
# 5102   GUARDIAN   1000037825           Y
# 5109        GSK   1000037832           Y
# 5110      MED +   1000037833           Y
#
# [1502 rows x 3 columns]

# %%
df.head()
# Out:
#    CUSTOMER_ID    Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  firstSTOR  \
# 0   1000032547      MED +    2006-09-12           Y    2007-05-12       2587
# 1   1000032548  DR.REDDYS    2006-09-12           Y    2007-03-12       4341
# 2   1000032549   RELEGARE    2006-09-12           Y    2007-02-12       1090
# 3   1000032550        GSK    2006-09-12           Y    2007-03-12       3179
# 4   1000032551        GSK    2006-09-12           Y    2007-05-12       3135
#
#   TITLE  GENDER  max_spent        DOB  ... CUST_STAT  Avgsize_spent  \
# 0  Mrs.  Female      56.31 1984-09-15  ...    Active          17.34
# 1   Ms.  Female     598.95 1974-07-15  ...    Active          29.32
# 2  Mrs.  Female       1.56 1959-04-01  ...    Active           1.56
# 3   Mr.    Male     115.76 1978-05-16  ...    Active          80.49
# 4   Mr.    Male     305.90 1978-12-16  ...    Active          24.09
#
#     CARD_STAT  RGSTN_TYPE_IND NO_OF_TRIPS           TOWN EMAIL_IND  \
# ...

# %%
df[-5:]
# Out:
#       CUSTOMER_ID   Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  \
# 5107   1000037830  RELEGARE    2008-05-06           Y    2009-05-02
# 5108   1000037831    APPOLO    2008-05-06           Y    2008-10-06
# 5109   1000037832       GSK    2008-05-06           Y    2009-05-04
# 5110   1000037833     MED +    2008-05-06           Y    2009-06-10
# 5111   1000037834   RANBAXY    2008-05-06           Y    2009-05-04
#
#       firstSTOR TITLE  GENDER  max_spent        DOB  ... CUST_STAT  \
# 5107       3381   Mr.    Male     198.36 1935-11-23  ...    Active
# 5108       3244  Mrs.  Female      28.09 1956-08-27  ...    Active
# 5109       3381  Mrs.  Female     653.10 1982-05-13  ...    Active
# 5110       3130   Ms.  Female     228.55 1960-01-14  ...    Active
# 5111       3363  Mrs.  Female      26.35 1971-12-22  ...    Active
#
#       Avgsize_spent   CARD_STAT  RGSTN_TYPE_IND NO_OF_TRIPS       TOWN  \
# 5107          66.12  Registered          Online           3   Kyvalley
# ...

# %%
df.count()
# Out:
# CUSTOMER_ID            5112
# Company                5112
# CARD_REG_DATE          5112
# CARD_ACTIVE            5112
# FIRST_USE_DTE          5112
# firstSTOR              5112
# TITLE                  5112
# GENDER                 5112
# max_spent              5097
# DOB                    5112
# FTD                    5112
# Age                    5112
# STATE_CODE             5112
# POST_CODE              5112
# CUST_STAT              5112
# Avgsize_spent          5112
# CARD_STAT              5112
# RGSTN_TYPE_IND         5112
# NO_OF_TRIPS            5112
# TOWN                   5112
# EMAIL_IND              5112
# CONTACT_PREF           4219
# Average_Qty_PER_ACC    5112
# Spent_amount           5112
# dtype: int64

# %%
df.head()
# Out:
#    CUSTOMER_ID    Company CARD_REG_DATE CARD_ACTIVE FIRST_USE_DTE  firstSTOR  \
# 0   1000032547      MED +    2006-09-12           Y    2007-05-12       2587
# 1   1000032548  DR.REDDYS    2006-09-12           Y    2007-03-12       4341
# 2   1000032549   RELEGARE    2006-09-12           Y    2007-02-12       1090
# 3   1000032550        GSK    2006-09-12           Y    2007-03-12       3179
# 4   1000032551        GSK    2006-09-12           Y    2007-05-12       3135
#
#   TITLE  GENDER  max_spent        DOB  ... CUST_STAT  Avgsize_spent  \
# 0  Mrs.  Female      56.31 1984-09-15  ...    Active          17.34
# 1   Ms.  Female     598.95 1974-07-15  ...    Active          29.32
# 2  Mrs.  Female       1.56 1959-04-01  ...    Active           1.56
# 3   Mr.    Male     115.76 1978-05-16  ...    Active          80.49
# 4   Mr.    Male     305.90 1978-12-16  ...    Active          24.09
#
#     CARD_STAT  RGSTN_TYPE_IND NO_OF_TRIPS           TOWN EMAIL_IND  \
# ...

# %%
dfg=df.groupby(["Company","GENDER"],as_index=False).agg(sub=("CUSTOMER_ID","count"))

# %%
df_red=df[df["Company"]=="DR.REDDYS"]

# %%
df_rel=df[df["Company"]=="RELEGARE"]

# %%
df_in=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\3. PYTHON\SESSION-3\ASSIGNMENTS ANS\DATA.xlsx",sheet_name="india")

# %%
df_jp=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\3. PYTHON\SESSION-3\ASSIGNMENTS ANS\DATA.xlsx",sheet_name="japan")

# %%
df_in.head()
# Out:
#   PRODUCT CATEGORY COUNTRY  YEAR  UNITS
# 0    Acer  Laptops   INDIA  2020  85000
# 1     AGB  Laptops   INDIA  2020  60500
# 2   Apple  MacBook   INDIA  2020  68200
# 3    Asus  Laptops   INDIA  2020  69300
# 4   Avita  Laptops   INDIA  2020  82600

# %%
df_jp.head()
# Out:
#    PRODUCT CATEGORY COUNTRY  YEAR  UNITS
# 0    Reach  Laptops   JAPAN  2020  35100
# 1  Samsung  Laptops   JAPAN  2020  16100
# 2     Sony  Laptops   JAPAN  2020  21500
# 3  Toshiba  Laptops   JAPAN  2020  20100
# 4   Xiaomi  Laptops   JAPAN  2020  74600

# %%
pd.merge(left=df_in,right=df_jp,on="PRODUCT",how="inner",suffixes=("_ind","_jap"))
# Out:
#      PRODUCT CATEGORY_ind COUNTRY_ind  YEAR_ind  UNITS_ind CATEGORY_jap  \
# 0       Acer      Laptops       INDIA      2020      85000      Laptops
# 1        AGB      Laptops       INDIA      2020      60500      Laptops
# 2      Apple      MacBook       INDIA      2020      68200      Laptops
# 3       Asus      Laptops       INDIA      2020      69300      Laptops
# 4      Avita      Laptops       INDIA      2020      82600      Laptops
# 5       Dell      Laptops       INDIA      2020      39100      Laptops
# 6    Fujitsu      Laptops       INDIA      2020      41800      Laptops
# 7         HP      Laptops       INDIA      2020      33900      Laptops
# 8   Micromax      Laptops       INDIA      2020      13500      Laptops
# 9        MSI      Laptops       INDIA      2020      57200      Laptops
# 10     Razer      Laptops       INDIA      2020      20200      Laptops
#
#    COUNTRY_jap  YEAR_jap  UNITS_jap
# 0        JAPAN      2020      18700
# ...

# %%
pd.merge(left=df_in,right=df_jp,on="PRODUCT",how="outer")
# Out:
#      PRODUCT CATEGORY_x COUNTRY_x  YEAR_x  UNITS_x CATEGORY_y COUNTRY_y  \
# 0       Acer    Laptops     INDIA  2020.0  85000.0    Laptops     JAPAN
# 1        AGB    Laptops     INDIA  2020.0  60500.0    Laptops     JAPAN
# 2      Apple    MacBook     INDIA  2020.0  68200.0    Laptops     JAPAN
# 3       Asus    Laptops     INDIA  2020.0  69300.0    Laptops     JAPAN
# 4      Avita    Laptops     INDIA  2020.0  82600.0    Laptops     JAPAN
# 5       Dell    Laptops     INDIA  2020.0  39100.0    Laptops     JAPAN
# 6    Fujitsu    Laptops     INDIA  2020.0  41800.0    Laptops     JAPAN
# 7         HP    Laptops     INDIA  2020.0  33900.0    Laptops     JAPAN
# 8     Huawei    Laptops     INDIA  2020.0  72700.0        NaN       NaN
# 9      iBall    Laptops     INDIA  2020.0  73900.0        NaN       NaN
# 10    I-Life    Laptops     INDIA  2020.0  47500.0        NaN       NaN
# 11      Lava    Laptops     INDIA  2020.0  84300.0        NaN       NaN
# ...

# %%
dff=pd.merge(left=df_in,right=df_jp,on="PRODUCT",how="outer",suffixes=("_ind","_jap"))

# %%
dff.head()
# Out:
#   PRODUCT CATEGORY_ind COUNTRY_ind  YEAR_ind  UNITS_ind CATEGORY_jap  \
# 0    Acer      Laptops       INDIA    2020.0    85000.0      Laptops
# 1     AGB      Laptops       INDIA    2020.0    60500.0      Laptops
# 2   Apple      MacBook       INDIA    2020.0    68200.0      Laptops
# 3    Asus      Laptops       INDIA    2020.0    69300.0      Laptops
# 4   Avita      Laptops       INDIA    2020.0    82600.0      Laptops
#
#   COUNTRY_jap  YEAR_jap  UNITS_jap
# 0       JAPAN    2020.0    18700.0
# 1       JAPAN    2020.0    53400.0
# 2       JAPAN    2020.0    64900.0
# 3       JAPAN    2020.0    81900.0
# 4       JAPAN    2020.0    83300.0

# %%
dff[dff["CATEGORY_jap"].isnull()]
# Out:
#    PRODUCT CATEGORY_ind COUNTRY_ind  YEAR_ind  UNITS_ind CATEGORY_jap  \
# 8   Huawei      Laptops       INDIA    2020.0    72700.0          NaN
# 9    iBall      Laptops       INDIA    2020.0    73900.0          NaN
# 10  I-Life      Laptops       INDIA    2020.0    47500.0          NaN
# 11    Lava      Laptops       INDIA    2020.0    84300.0          NaN
# 12  Lenovo      Laptops       INDIA    2020.0    43200.0          NaN
# 13      LG      Laptops       INDIA    2020.0    17500.0          NaN
# 17     RDP      Laptops       INDIA    2020.0    36600.0          NaN
#
#    COUNTRY_jap  YEAR_jap  UNITS_jap
# 8          NaN       NaN        NaN
# 9          NaN       NaN        NaN
# 10         NaN       NaN        NaN
# 11         NaN       NaN        NaN
# 12         NaN       NaN        NaN
# 13         NaN       NaN        NaN
# 17         NaN       NaN        NaN

# %%
dff[dff["UNITS_jap"]>dff["UNITS_ind"]]
# Out:
#      PRODUCT CATEGORY_ind COUNTRY_ind  YEAR_ind  UNITS_ind CATEGORY_jap  \
# 3       Asus      Laptops       INDIA    2020.0    69300.0      Laptops
# 4      Avita      Laptops       INDIA    2020.0    82600.0      Laptops
# 5       Dell      Laptops       INDIA    2020.0    39100.0      Laptops
# 6    Fujitsu      Laptops       INDIA    2020.0    41800.0      Laptops
# 14  Micromax      Laptops       INDIA    2020.0    13500.0      Laptops
# 15       MSI      Laptops       INDIA    2020.0    57200.0      Laptops
# 16     Razer      Laptops       INDIA    2020.0    20200.0      Laptops
#
#    COUNTRY_jap  YEAR_jap  UNITS_jap
# 3        JAPAN    2020.0    81900.0
# 4        JAPAN    2020.0    83300.0
# 5        JAPAN    2020.0    57100.0
# 6        JAPAN    2020.0    46200.0
# 14       JAPAN    2020.0    55300.0
# 15       JAPAN    2020.0    70500.0
# 16       JAPAN    2020.0    59500.0

# %%
df_20=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\3. PYTHON\SESSION-3\ASSIGNMENTS ANS\DATA.xlsx",sheet_name="y_2021")

# %%
df_21=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\3. PYTHON\SESSION-3\ASSIGNMENTS ANS\DATA.xlsx",sheet_name="y_2021")

# %%
df_20.head()
# Out:
#   PRODUCT  YEAR  PRICE
# 0    Acer  2021  81920
# 1     AGB  2021  84816
# 2   Apple  2021  81000
# 3    Asus  2021  87600
# 4   Avita  2021  68324

# %%
dff=pd.merge(left=df_20,right=df_21,on=["PRODUCT","YEAR"],how="outer",suffixes=("_20","_21"))

# %%
dff.head()
# Out:
#   PRODUCT  YEAR  PRICE_20  PRICE_21
# 0    Acer  2021     81920     81920
# 1     AGB  2021     84816     84816
# 2   Apple  2021     81000     81000
# 3    Asus  2021     87600     87600
# 4   Avita  2021     68324     68324

# %%
df_tr=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\3. PYTHON\SESSION-3\ASSIGNMENTS ANS\DATA.xlsx",sheet_name="ms")

# %%
df_tr.head()
# Out:
#   TRANSACTION_DATE  TRANSACTION_YEAR   PRODUCT      COUNTRY  UNITS
# 0       2018-11-05              2018        LG     MALAYSIA  33600
# 1       2019-10-19              2019    I-Life     MALAYSIA  89900
# 2       2020-01-03              2020   Toshiba  NEW ZEALAND  13700
# 3       2018-09-18              2018     Reach        INDIA  32000
# 4       2018-06-03              2018  Micromax    SINGAPORE  88400

# %%
df_gp=df_tr.groupby(["COUNTRY","TRANSACTION_YEAR"],as_index=False).agg(sales=("UNITS","sum"))
df_gp.head()
# Out:
#      COUNTRY  TRANSACTION_YEAR    sales
# 0  AUSTRALIA              2015  2987900
# 1  AUSTRALIA              2016  3196000
# 2  AUSTRALIA              2017  3027800
# 3  AUSTRALIA              2018  2402100
# 4  AUSTRALIA              2019  3037500

# %%
df_uin=pd.merge(left=df_tr,right=df_gp,on=["COUNTRY","TRANSACTION_YEAR"],how="outer")
df_uin["share"]=(df_uin["UNITS"]/df_uin["sales"])*100
df_uin.head()
# Out:
#   TRANSACTION_DATE  TRANSACTION_YEAR  PRODUCT   COUNTRY  UNITS    sales  \
# 0       2018-11-05              2018       LG  MALAYSIA  33600  2482800
# 1       2018-01-04              2018     Sony  MALAYSIA  70600  2482800
# 2       2018-11-28              2018      MSI  MALAYSIA  75200  2482800
# 3       2018-10-17              2018     Sony  MALAYSIA  80600  2482800
# 4       2018-06-01              2018  Samsung  MALAYSIA  25900  2482800
#
#       share
# 0  1.353311
# 1  2.843564
# 2  3.028838
# 3  3.246335
# 4  1.043177

# %%
df_uin["share"]=df_uin["share"].map(lambda x: "{:,.2f}%".format(x))
df_uin.head()
# Out:
#   TRANSACTION_DATE  TRANSACTION_YEAR  PRODUCT   COUNTRY  UNITS    sales  share
# 0       2018-11-05              2018       LG  MALAYSIA  33600  2482800  1.35%
# 1       2018-01-04              2018     Sony  MALAYSIA  70600  2482800  2.84%
# 2       2018-11-28              2018      MSI  MALAYSIA  75200  2482800  3.03%
# 3       2018-10-17              2018     Sony  MALAYSIA  80600  2482800  3.25%
# 4       2018-06-01              2018  Samsung  MALAYSIA  25900  2482800  1.04%

# %%
df_tr=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\3. PYTHON\SESSION-3\ASSIGNMENTS ANS\DATA.xlsx",sheet_name="task-9.1")

# %%
df_tr2=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\3. PYTHON\SESSION-3\ASSIGNMENTS ANS\DATA.xlsx",sheet_name="task-9.2")

# %%
df_tr3=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\3. PYTHON\SESSION-3\ASSIGNMENTS ANS\DATA.xlsx",sheet_name="task-9.3")

# %%
df_tr.head()
# Out:
#    Emp ID First Name  Last Name Gender DEPARTMENT
# 0  850297     Shawna       Buck      F        MKT
# 1  304721  Nathaniel      Burke      M        OPS
# 2  412317  Elisabeth     Foster      F        OPS
# 3  621375     Briana  Lancaster      F        OPS
# 4  787549    Estella     Potter      F        MKT

# %%
df_tr2.head()
# Out:
#    Emp ID          SSN    Phone No.  State
# 0  850297  222-11-7603  702-771-7149    NV
# 1  304721  550-99-9897  231-765-6923    MI
# 2  412317  215-91-0004  270-749-4774    KY
# 3  621375  534-71-1053  219-623-8216    IN
# 4  787549  644-29-6396  907-677-8486    AK

# %%
df_tr3.head()
# Out:
#    Emp ID LEAVE_DATE
# 0  913253 2019-02-20
# 1  520092 2019-08-03
# 2  913253 2019-02-09
# 3  612850 2019-09-01
# 4  621375 2019-09-17

# %% [markdown]
# ### Q1	GET STATE_CODE, DEPARTMENT AND GENDER WISE TOTAL NUMBER PF LEAVES TAKEN

# %%
df_mer=pd.merge(left=df_tr,right=df_tr2,on="Emp ID",how="left")
df_merr=pd.merge(left=df_mer,right=df_tr3,on="Emp ID",how="left")
df_merr.head()
# Out:
#    Emp ID First Name Last Name Gender DEPARTMENT          SSN    Phone No.   \
# 0  850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# 1  850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# 2  850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# 3  850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# 4  850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
#
#   State LEAVE_DATE
# 0    NV 2019-12-04
# 1    NV 2019-05-05
# 2    NV 2019-05-17
# 3    NV 2019-12-18
# 4    NV 2019-12-14

# %%
df_leav=df_merr.groupby(["State","DEPARTMENT","Gender"],as_index=False).agg(leaves=("LEAVE_DATE","count"))
df_leav.head()
# Out:
#   State DEPARTMENT Gender  leaves
# 0    AK        MKT      F      15
# 1    CA         IT      M      10
# 2    CA      SALES      F       9
# 3    CA      SALES      M      19
# 4    IA      SALES      M      13

# %%
df_mx=df_leav.groupby(["DEPARTMENT"],as_index=False).agg(leaves=("leaves","max"))
df_mx
# Out:
#   DEPARTMENT  leaves
# 0    FINANCE       8
# 1         IT      17
# 2        MKT      16
# 3        OPS      14
# 4      SALES      19

# %%
df_mx["Emp ID"].index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %% [markdown]
# ### Q2	GET DEPARTMENT WISE WHO HAS TAKEN THE HIGHEST NUMBER OF LEAVES AND THEIR PHONE AND SSN NUMBER

# %%
df_fin=pd.merge(left=df_merr,right=df_leav,on=["State","DEPARTMENT","Gender"],how="left")
df_fin
# Out:
#      Emp ID First Name Last Name Gender DEPARTMENT          SSN    Phone No.   \
# 0    850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# 1    850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# 2    850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# 3    850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# 4    850297     Shawna      Buck      F        MKT  222-11-7603  702-771-7149
# ..      ...        ...       ...    ...        ...          ...           ...
# 237  913253      Carey   Ferrell      M    FINANCE  522-99-2018  212-495-4523
# 238  913253      Carey   Ferrell      M    FINANCE  522-99-2018  212-495-4523
# 239  913253      Carey   Ferrell      M    FINANCE  522-99-2018  212-495-4523
# 240  913253      Carey   Ferrell      M    FINANCE  522-99-2018  212-495-4523
# 241  913253      Carey   Ferrell      M    FINANCE  522-99-2018  212-495-4523
#
#     State LEAVE_DATE  leaves
# ...

# %%
dff=pd.merge(left=df_merr,right=df_mx,on=["DEPARTMENT"],how="inner")

# %%
dff["Emp ID"].drop_duplicates()
# Out:
# 0      850297
# 9      787549
# 24     520092
# 40     795934
# 53     304721
# 64     412317
# 78     621375
# 90     159108
# 107    330816
# 124    532002
# 131    612850
# 143    483751
# 153    252938
# 170    966375
# 189    707520
# 202    673049
# 213    265124
# 222    300693
# 228    369712
# 236    913253
# Name: Emp ID, dtype: int64

# %%
dff[["State","SSN","First Name"]].drop_duplicates()
# Out:
#     State          SSN First Name
# 0      NV  222-11-7603     Shawna
# 9      AK  644-29-6396    Estella
# 24     VA  037-74-2595     Lamont
# 40     TX  541-83-6362    Melinda
# 53     MI  550-99-9897  Nathaniel
# 64     KY  215-91-0004  Elisabeth
# 78     IN  534-71-1053     Briana
# 90     VA  673-48-7003     Shanna
# 107    TN  600-99-8437    Jasmine
# 124    IL  177-86-7347      Madge
# 131    PA  700-18-6519    Bethany
# 143    CA  343-11-4951       Reid
# 153    OR  078-02-8772    Antoine
# 170    CA  161-86-9547     Mathew
# 189    IA  143-23-9034   Bernardo
# 202    OK  762-12-1934       Cole
# 213    CA  093-02-0725      Tonia
# 222    MD  770-02-9125        Tod
# 228    MD  494-29-3248    Yesenia
# 236    NY  522-99-2018      Carey

# %%
df=pd.read_excel(r"C:\Users\mitra\Desktop\DV ANALYTIC\TOPICS\1. DBMS & PROGRAMMING SKILLS\2. SQL SERVER\SESSION-5\ASSIGNMENTS ANS\D_2.xlsx",sheet_name="TASK-6")

# %%
df.head()
# Out:
#   COUNTRY CATEGORY                                       PRODUCT_NAME  SALES
# 0   INDIA  Organic  Kirkland Signature Organic Extra Virgin Olive ...  73300
# 1   INDIA  Organic  Newman's Own Organics Coffee Special Blend K-C...  51500
# 2   INDIA  Organic  Kirkland Signature Organic Chicken Stock, 32 f...  66100
# 3   INDIA  Organic  Seeds of Change Organic Quinoa and Brown Rice,...  67200
# 4   INDIA  Organic  Kirkland Signature Organic Lemonade, 96 fl oz,...  73800

# %%
dff=df.groupby(["COUNTRY","CATEGORY","PRODUCT_NAME"],as_index=False).agg(sales=("SALES","sum"))
dff
# Out:
#    COUNTRY       CATEGORY                                       PRODUCT_NAME  \
# 0    INDIA  Gourmet Foods      D'Artagnan Berkshire Pork Tenderloins 12-pack
# 1    INDIA  Gourmet Foods  Morning Star Farms Frozen Chipotle Black Bean ...
# 2    INDIA  Gourmet Foods  Pederson Natural Farms No Sugar Italian Ground...
# 3    INDIA  Gourmet Foods  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 4    INDIA  Gourmet Foods  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
# 5    INDIA  Gourmet Foods  Rastelli Market Fresh Angus Beef Prime Petite ...
# 6    INDIA           Meat  D'Artagnan Extreme American Wagyu Burger Lover...
# 7    INDIA           Meat  D’Artagnan Gourmet Steak & Burger Grill Pack, ...
# 8    INDIA           Meat                Kirkland Signature Meatballs, 6 lbs
# 9    INDIA           Meat  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 10   INDIA           Meat  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
# ...

# %%
dff1=dff.sort_values(by=["COUNTRY","CATEGORY","sales"],ascending=[True,True,False])
dff1.head()
# Out:
#   COUNTRY       CATEGORY                                       PRODUCT_NAME  \
# 3   INDIA  Gourmet Foods  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 2   INDIA  Gourmet Foods  Pederson Natural Farms No Sugar Italian Ground...
# 5   INDIA  Gourmet Foods  Rastelli Market Fresh Angus Beef Prime Petite ...
# 0   INDIA  Gourmet Foods      D'Artagnan Berkshire Pork Tenderloins 12-pack
# 4   INDIA  Gourmet Foods  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
#
#    sales
# 3  75000
# 2  60000
# 5  38700
# 0  31100
# 4  23600

# %%
dff1["ranks"]=dff1.groupby(["COUNTRY","CATEGORY"])["sales"].rank(method="dense",ascending=False).astype(int)
dff1
# Out:
#    COUNTRY       CATEGORY                                       PRODUCT_NAME  \
# 3    INDIA  Gourmet Foods  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 2    INDIA  Gourmet Foods  Pederson Natural Farms No Sugar Italian Ground...
# 5    INDIA  Gourmet Foods  Rastelli Market Fresh Angus Beef Prime Petite ...
# 0    INDIA  Gourmet Foods      D'Artagnan Berkshire Pork Tenderloins 12-pack
# 4    INDIA  Gourmet Foods  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
# 1    INDIA  Gourmet Foods  Morning Star Farms Frozen Chipotle Black Bean ...
# 6    INDIA           Meat  D'Artagnan Extreme American Wagyu Burger Lover...
# 9    INDIA           Meat  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 7    INDIA           Meat  D’Artagnan Gourmet Steak & Burger Grill Pack, ...
# 10   INDIA           Meat  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
# 8    INDIA           Meat                Kirkland Signature Meatballs, 6 lbs
# ...

# %%
dff1.head()
# Out:
#   COUNTRY       CATEGORY                                       PRODUCT_NAME  \
# 3   INDIA  Gourmet Foods  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 2   INDIA  Gourmet Foods  Pederson Natural Farms No Sugar Italian Ground...
# 5   INDIA  Gourmet Foods  Rastelli Market Fresh Angus Beef Prime Petite ...
# 0   INDIA  Gourmet Foods      D'Artagnan Berkshire Pork Tenderloins 12-pack
# 4   INDIA  Gourmet Foods  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
#
#    sales  ranks
# 3  75000      1
# 2  60000      2
# 5  38700      3
# 0  31100      4
# 4  23600      5

# %%
dff1["cumsum"]=dff1.groupby(["COUNTRY","CATEGORY"])["sales"].apply(lambda x: x.cumsum())

# %%
dff1["%cat"]=dff1.groupby(["COUNTRY","CATEGORY"])["sales"].apply(lambda x: (x/x.sum()*100)).apply(lambda x : "{:,.2f}%".format(x))

# %%
dff1.head()
# Out:
#   COUNTRY       CATEGORY                                       PRODUCT_NAME  \
# 3   INDIA  Gourmet Foods  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 2   INDIA  Gourmet Foods  Pederson Natural Farms No Sugar Italian Ground...
# 5   INDIA  Gourmet Foods  Rastelli Market Fresh Angus Beef Prime Petite ...
# 0   INDIA  Gourmet Foods      D'Artagnan Berkshire Pork Tenderloins 12-pack
# 4   INDIA  Gourmet Foods  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
#
#    sales  ranks  cumsum    %cat
# 3  75000      1   75000  31.45%
# 2  60000      2  135000  25.16%
# 5  38700      3  173700  16.23%
# 0  31100      4  204800  13.04%
# 4  23600      5  228400   9.90%

# %%
dff1["%cou"]=dff1.groupby(["COUNTRY"])["sales"].apply(lambda x: (x/x.sum()*100)).apply(lambda x : "{:,.2f}%".format(x))
dff1.head()
# Out:
#   COUNTRY       CATEGORY                                       PRODUCT_NAME  \
# 3   INDIA  Gourmet Foods  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 2   INDIA  Gourmet Foods  Pederson Natural Farms No Sugar Italian Ground...
# 5   INDIA  Gourmet Foods  Rastelli Market Fresh Angus Beef Prime Petite ...
# 0   INDIA  Gourmet Foods      D'Artagnan Berkshire Pork Tenderloins 12-pack
# 4   INDIA  Gourmet Foods  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
#
#    sales  ranks  cumsum    %cat   %cou
# 3  75000      1   75000  31.45%  6.72%
# 2  60000      2  135000  25.16%  5.38%
# 5  38700      3  173700  16.23%  3.47%
# 0  31100      4  204800  13.04%  2.79%
# 4  23600      5  228400   9.90%  2.12%

# %%
dff1["ranks"]=dff1["sales"].rank(method="dense",ascending=False)

# %%
dff1
# Out:
#    COUNTRY       CATEGORY                                       PRODUCT_NAME  \
# 3    INDIA  Gourmet Foods  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 2    INDIA  Gourmet Foods  Pederson Natural Farms No Sugar Italian Ground...
# 5    INDIA  Gourmet Foods  Rastelli Market Fresh Angus Beef Prime Petite ...
# 0    INDIA  Gourmet Foods      D'Artagnan Berkshire Pork Tenderloins 12-pack
# 4    INDIA  Gourmet Foods  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
# 1    INDIA  Gourmet Foods  Morning Star Farms Frozen Chipotle Black Bean ...
# 6    INDIA           Meat  D'Artagnan Extreme American Wagyu Burger Lover...
# 9    INDIA           Meat  Rastelli Antibiotic-free Pork Bacon, 12 oz, 12...
# 7    INDIA           Meat  D’Artagnan Gourmet Steak & Burger Grill Pack, ...
# 10   INDIA           Meat  Rastelli Bone-In Premium Pork Rib Steak 8 oz, ...
# 8    INDIA           Meat                Kirkland Signature Meatballs, 6 lbs
# ...

# %%
dff1=pd.read_excel(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS SUMMARIZATION\GROUP BY\MED_STORE_2022.xlsx",sheet_name="dup")
dff1.head()
# Out:
#   STU_NAME SUBJECT  SCORE
# 0     SIMI     SAS    453
# 1     SIMI       R    743
# 2     SIMI  PYTHON    282
# 3     SIMI   EXCEL    250
# 4    SUDIP       R    598

# %%
dff1[dff1.duplicated()]
# Out:
#    STU_NAME SUBJECT  SCORE
# 11     SIMI     SAS    453
# 12     SIMI       R    743
# 13     SIMI  PYTHON    282

# %%
dff2=dff1.copy()
dff2.head()
# Out:
#   STU_NAME SUBJECT  SCORE
# 0     SIMI     SAS    453
# 1     SIMI       R    743
# 2     SIMI  PYTHON    282
# 3     SIMI   EXCEL    250
# 4    SUDIP       R    598

# %%
dff1.drop_duplicates()

# %%
dff4=pd.read_excel(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\PANDAS\PANDAS SUMMARIZATION\GROUP BY\MED_STORE_2022.xlsx",sheet_name="dew")
dff4
# Out:
#    EMP_NAME  EMP_ID MANAGER_NAME  MANAGER_ID
# 0     BLAKE    7698         KING        7839
# 1     CLARK    7782         KING        7839
# 2     JONES    7566         KING        7839
# 3    MARTIN    7654        BLAKE        7698
# 4     ALLEN    7499        BLAKE        7698
# 5    TURNER    7844        BLAKE        7698
# 6     JAMES    7900        BLAKE        7698
# 7      WARD    7521        BLAKE        7698
# 8      FORD    7902        JONES        7566
# 9     SMITH    7369         FORD        7902
# 10    SCOTT    7788        JONES        7566
# 11    ADAMS    7876        SCOTT        7788
# 12   MILLER    7934        CLARK        7782

# %%
pd.merge(left=dff4,right=dff4,right_on=dff4["EMP_ID"],left_on=dff4["MANAGER_ID"],suffixes=("_mgr","_mid"),how="left")
# Out:
#     key_0 EMP_NAME_mgr  EMP_ID_mgr MANAGER_NAME_mgr  MANAGER_ID_mgr  \
# 0    7839        BLAKE        7698             KING            7839
# 1    7839        CLARK        7782             KING            7839
# 2    7839        JONES        7566             KING            7839
# 3    7698       MARTIN        7654            BLAKE            7698
# 4    7698        ALLEN        7499            BLAKE            7698
# 5    7698       TURNER        7844            BLAKE            7698
# 6    7698        JAMES        7900            BLAKE            7698
# 7    7698         WARD        7521            BLAKE            7698
# 8    7566         FORD        7902            JONES            7566
# 9    7902        SMITH        7369             FORD            7902
# 10   7566        SCOTT        7788            JONES            7566
# 11   7788        ADAMS        7876            SCOTT            7788
# 12   7782       MILLER        7934            CLARK            7782
#
# ...
