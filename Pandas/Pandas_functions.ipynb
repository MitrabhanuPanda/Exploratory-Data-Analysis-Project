# %%
import pandas as pd

# %%
dfwh = pd.read_csv(r"C:\Users\hp\Desktop\Outlier Detection Dataset\weight-height.csv")

# %%
dfwh
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
dfwh["Height"]
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 9995    66.172652
# 9996    67.067155
# 9997    63.867992
# 9998    69.034243
# 9999    61.944246
# Name: Height, Length: 10000, dtype: float64

# %%
dfwh[["Height"]]
# Out:
#          Height
# 0     73.847017
# 1     68.781904
# 2     74.110105
# 3     71.730978
# 4     69.881796
# ...         ...
# 9995  66.172652
# 9996  67.067155
# 9997  63.867992
# 9998  69.034243
# 9999  61.944246
#
# [10000 rows x 1 columns]

# %%
dfwh["Height"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10000 entries, 0 to 9999
# Series name: Height
# Non-Null Count  Dtype
# --------------  -----
# 10000 non-null  float64
# dtypes: float64(1)
# memory usage: 78.2 KB

# %%
dfwh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
dfwh["Height"].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
dfwh["Gender"]
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 9995    Female
# 9996    Female
# 9997    Female
# 9998    Female
# 9999    Female
# Name: Gender, Length: 10000, dtype: object

# %%
dfwh["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dfwh["Gender"].nunique()
# Out:
# 2

# %%
dfwh["Gender"].value_counts()
# Out:
# Male      5000
# Female    5000
# Name: Gender, dtype: int64

# %%
dfwh
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
dfcars = pd.read_csv(r"C:\Users\hp\Desktop\Outlier Detection Dataset\Onehotencoding dataset\cars.csv")

# %%
dfcars
# Out:
#         brand  km_driven    fuel                 owner  selling_price
# 0      Maruti     145500  Diesel           First Owner         450000
# 1       Skoda     120000  Diesel          Second Owner         370000
# 2       Honda     140000  Petrol           Third Owner         158000
# 3     Hyundai     127000  Diesel           First Owner         225000
# 4      Maruti     120000  Petrol           First Owner         130000
# ...       ...        ...     ...                   ...            ...
# 8123  Hyundai     110000  Petrol           First Owner         320000
# 8124  Hyundai     119000  Diesel  Fourth & Above Owner         135000
# 8125   Maruti     120000  Diesel           First Owner         382000
# 8126     Tata      25000  Diesel           First Owner         290000
# 8127     Tata      25000  Diesel           First Owner         290000
#
# [8128 rows x 5 columns]

# %%
dfcars["fuel"].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
dfcars["fuel"].value_counts()
# Out:
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: fuel, dtype: int64

# %%
dfcars.columns
# Out:
# Index(['brand', 'km_driven', 'fuel', 'owner', 'selling_price'], dtype='object')

# %%
dfcars["brand"]
# Out:
# 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 8123    Hyundai
# 8124    Hyundai
# 8125     Maruti
# 8126       Tata
# 8127       Tata
# Name: brand, Length: 8128, dtype: object

# %%
dfcars["brand"].unique()
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Fiat', 'Datsun', 'Jeep',
#        'Mercedes-Benz', 'Mitsubishi', 'Audi', 'Volkswagen', 'BMW',
#        'Nissan', 'Lexus', 'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo',
#        'Kia', 'Force', 'Ambassador', 'Ashok', 'Isuzu', 'Opel', 'Peugeot'],
#       dtype=object)

# %%
dfcars["brand"].nunique()
# Out:
# 32

# %%
dfcars.columns
# Out:
# Index(['brand', 'km_driven', 'fuel', 'owner', 'selling_price'], dtype='object')

# %%
dfcars.columns = ['Brand', 'KMS_Driven', 'Fuel', 'Owner', 'Selling_Price']

# %%
dfcars.columns = ['Brand', 'KMS_Driven', 'FUEL|', 'Owner', 'Selling_Price']

# %%
dfcars.columns
# Out:
# Index(['Brand', 'KMS_Driven', 'FUEL|', 'Owner', 'Selling_Price'], dtype='object')

# %%
dfcars.rename(columns= {'FUEL|' : "Gas"}, inplace=True)

# %%
dfcars
# Out:
#         Brand  KMS_Driven     Gas                 Owner  Selling_Price
# 0      Maruti      145500  Diesel           First Owner         450000
# 1       Skoda      120000  Diesel          Second Owner         370000
# 2       Honda      140000  Petrol           Third Owner         158000
# 3     Hyundai      127000  Diesel           First Owner         225000
# 4      Maruti      120000  Petrol           First Owner         130000
# ...       ...         ...     ...                   ...            ...
# 8123  Hyundai      110000  Petrol           First Owner         320000
# 8124  Hyundai      119000  Diesel  Fourth & Above Owner         135000
# 8125   Maruti      120000  Diesel           First Owner         382000
# 8126     Tata       25000  Diesel           First Owner         290000
# 8127     Tata       25000  Diesel           First Owner         290000
#
# [8128 rows x 5 columns]

# %%
dfiris = pd.read_csv(r"C:\Users\hp\Desktop\DATASETS\Classification Dataset\Iris.csv")

# %%
dfiris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dfiris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
dfiris.reindex(columns = ['Species','Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])
# Out:
#             Species   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0       Iris-setosa    1            5.1           3.5            1.4
# 1       Iris-setosa    2            4.9           3.0            1.4
# 2       Iris-setosa    3            4.7           3.2            1.3
# 3       Iris-setosa    4            4.6           3.1            1.5
# 4       Iris-setosa    5            5.0           3.6            1.4
# ..              ...  ...            ...           ...            ...
# 145  Iris-virginica  146            6.7           3.0            5.2
# 146  Iris-virginica  147            6.3           2.5            5.0
# 147  Iris-virginica  148            6.5           3.0            5.2
# 148  Iris-virginica  149            6.2           3.4            5.4
# 149  Iris-virginica  150            5.9           3.0            5.1
#
#      PetalWidthCm
# 0             0.2
# 1             0.2
# 2             0.2
# 3             0.2
# 4             0.2
# ..            ...
# ...

# %%
dfstore = pd.read_csv(r"C:\Users\hp\Desktop\DATASETS\cloths_store_sale.csv")

# %%
dfstore
# Out:
#     Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 0          1          Regular      1      39.50          Discover    Male
# 1          2      Promotional      1     102.40  Proprietary Card  Female
# 2          3          Regular      1      22.50  Proprietary Card  Female
# 3          4      Promotional      5     100.40  Proprietary Card  Female
# 4          5          Regular      2      54.00        MasterCard  Female
# ..       ...              ...    ...        ...               ...     ...
# 95        96          Regular      1      39.50        MasterCard  Female
# 96        97      Promotional      9     253.00  Proprietary Card  Female
# 97        98      Promotional     10     287.59  Proprietary Card  Female
# 98        99      Promotional      2      47.60  Proprietary Card  Female
# 99       100      Promotional      1      28.44  Proprietary Card  Female
#
#    Marital Status  Age
# 0         Married   32
# 1         Married   36
# ...

# %%
dfstore.columns
# Out:
# Index(['Customer', 'Type of Customer', 'Items', 'Net Sales',
#        'Method of Payment', 'Gender', 'Marital Status', 'Age'],
#       dtype='object')

# %%
dfstore.rename(columns={'Type of Customer' : "CustType", 
                       'Net Sales' : 'Sales', 'Method of Payment' : 'PaymentMethod', 'Marital Status' : 'Status'}, inplace=True)

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
#     Age
# 0    32
# 1    36
# 2    32
# 3    28
# ...

# %% [markdown]
# ###  QUERY

# %%
dfstore["Gender"] == "Female"
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: Gender, Length: 100, dtype: bool

# %%
dfstore[  dfstore["Gender"] == "Female" ]
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# 5          6      Regular      1   44.50        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
#     Age
# 1    36
# 2    32
# 3    28
# 4    34
# ...

# %%
dfstore.query(" Gender == 'Male'  ")
# Out:
#     Customer     CustType  Items  Sales     PaymentMethod Gender   Status  Age
# 0          1      Regular      1   39.5          Discover   Male  Married   32
# 14        15      Regular      1   49.5              Visa   Male   Single   24
# 15        16  Promotional      2   71.4  Proprietary Card   Male   Single   36
# 24        25  Promotional      2   39.5              Visa   Male  Married   48
# 35        36      Regular      1   29.5        MasterCard   Male   Single   36
# 51        52  Promotional      5  118.8  Proprietary Card   Male  Married   68
# 68        69  Promotional      2   47.2  Proprietary Card   Male  Married   46

# %%
dfstore.query("Age == 30")
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 6          7  Promotional      2   78.00  Proprietary Card  Female  Married
# 47        48  Promotional      3   63.64  Proprietary Card  Female  Married
# 61        62  Promotional      3   59.91  Proprietary Card  Female   Single
# 70        71  Promotional      5  155.32  Proprietary Card  Female  Married
# 81        82  Promotional      6   53.20  Proprietary Card  Female   Single
# 93        94  Promotional     17  229.50  Proprietary Card  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
#
#     Age
# 6    30
# 47   30
# 61   30
# 70   30
# 81   30
# 93   30
# 96   30
# 98   30

# %%
dfstore.query("Age == 46")
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 8          9  Promotional      2   56.52  Proprietary Card  Female  Married
# 13        14  Promotional      2   64.50              Visa  Female  Married
# 41        42  Promotional      4   19.50              Visa  Female  Married
# 46        47      Regular      1   25.00        MasterCard  Female  Married
# 49        50  Promotional      9  145.20        MasterCard  Female  Married
# 58        59  Promotional      4   65.20        MasterCard  Female  Married
# 60        61  Promotional      1  108.80  Proprietary Card  Female  Married
# 68        69  Promotional      2   47.20  Proprietary Card    Male  Married
# 94        95      Regular      3   66.00  American Express  Female  Married
#
#     Age
# 8    46
# 13   46
# 41   46
# 46   46
# 49   46
# 58   46
# 60   46
# 68   46
# 94   46

# %%
dfstore.query("Age == 46 and Gender == 'Male'")
# Out:
#     Customer     CustType  Items  Sales     PaymentMethod Gender   Status  Age
# 68        69  Promotional      2   47.2  Proprietary Card   Male  Married   46

# %%
dfstore.query("Age <= 46 and Gender == 'Male'")
# Out:
#     Customer     CustType  Items  Sales     PaymentMethod Gender   Status  Age
# 0          1      Regular      1   39.5          Discover   Male  Married   32
# 14        15      Regular      1   49.5              Visa   Male   Single   24
# 15        16  Promotional      2   71.4  Proprietary Card   Male   Single   36
# 35        36      Regular      1   29.5        MasterCard   Male   Single   36
# 68        69  Promotional      2   47.2  Proprietary Card   Male  Married   46

# %% [markdown]
# ###  Duplicates

# %%
dfstd = pd.read_csv(r"C:\Users\hp\Desktop\Dataset_Pandas\std_data1.csv")

# %%
dfstd
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfdup = dfstd.loc[2 : 5]

# %%
dfdup
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89

# %%
dfstd1 = pd.concat([dfstd, dfdup])

# %%
dfstd1
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89

# %%
dfstd1.reset_index(inplace=True)

# %%
dfstd1
# Out:
#     index SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0       0     A       10       67        66       66
# 1       1     B       12       87        56       65
# 2       2     C       11       66        89       63
# 3       3     D       10       56        88       66
# 4       4     E       10       89        90       56
# 5       5     F        9       88        85       89
# 6       6     G       12       90        83       88
# 7       7     H       11       79        88       90
# 8       2     C       11       66        89       63
# 9       3     D       10       56        88       66
# 10      4     E       10       89        90       56
# 11      5     F        9       88        85       89

# %%
dfstd1.drop("index", axis = 1, inplace=True)

# %%
dfstd1
# Out:
#    SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0      A       10       67        66       66
# 1      B       12       87        56       65
# 2      C       11       66        89       63
# 3      D       10       56        88       66
# 4      E       10       89        90       56
# 5      F        9       88        85       89
# 6      G       12       90        83       88
# 7      H       11       79        88       90
# 8      C       11       66        89       63
# 9      D       10       56        88       66
# 10     E       10       89        90       56
# 11     F        9       88        85       89

# %%
dfstd1.duplicated(keep="first")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10     True
# 11     True
# dtype: bool

# %%
dfstd1[   dfstd1.duplicated(keep="first") ]
# Out:
#    SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 8      C       11       66        89       63
# 9      D       10       56        88       66
# 10     E       10       89        90       56
# 11     F        9       88        85       89

# %%
dfstd1[   dfstd1.duplicated(keep="last") ]
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89

# %%
dfstd1[   dfstd1.duplicated(keep= False) ]
# Out:
#    SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 2      C       11       66        89       63
# 3      D       10       56        88       66
# 4      E       10       89        90       56
# 5      F        9       88        85       89
# 8      C       11       66        89       63
# 9      D       10       56        88       66
# 10     E       10       89        90       56
# 11     F        9       88        85       89

# %%
dfstd1
# Out:
#    SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0      A       10       67        66       66
# 1      B       12       87        56       65
# 2      C       11       66        89       63
# 3      D       10       56        88       66
# 4      E       10       89        90       56
# 5      F        9       88        85       89
# 6      G       12       90        83       88
# 7      H       11       79        88       90
# 8      C       11       66        89       63
# 9      D       10       56        88       66
# 10     E       10       89        90       56
# 11     F        9       88        85       89

# %%
dfstd1.drop_duplicates()
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfstd1
# Out:
#    SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0      A       10       67        66       66
# 1      B       12       87        56       65
# 2      C       11       66        89       63
# 3      D       10       56        88       66
# 4      E       10       89        90       56
# 5      F        9       88        85       89
# 6      G       12       90        83       88
# 7      H       11       79        88       90
# 8      C       11       66        89       63
# 9      D       10       56        88       66
# 10     E       10       89        90       56
# 11     F        9       88        85       89

# %%
dfstd1.drop_duplicates(keep = "first")
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfstd1.drop_duplicates(keep = 'last')
# Out:
#    SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0      A       10       67        66       66
# 1      B       12       87        56       65
# 6      G       12       90        83       88
# 7      H       11       79        88       90
# 8      C       11       66        89       63
# 9      D       10       56        88       66
# 10     E       10       89        90       56
# 11     F        9       88        85       89

# %%
dfstd1.drop_duplicates(keep = False)
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %% [markdown]
# ### Between

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
#     Age
# 0    32
# 1    36
# 2    32
# 3    28
# ...

# %%
dfstore["Age"].between(35,55)
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96    False
# 97     True
# 98    False
# 99     True
# Name: Age, Length: 100, dtype: bool

# %%
dfstore[   dfstore["Age"].between(35,55)  ]
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 5          6      Regular      1   44.50        MasterCard  Female  Married
# 7          8      Regular      1   22.50              Visa  Female  Married
# 8          9  Promotional      2   56.52  Proprietary Card  Female  Married
# 9         10      Regular      1   44.50  Proprietary Card  Female  Married
# 10        11      Regular      1   29.50  Proprietary Card  Female  Married
# 11        12  Promotional      1   31.60  Proprietary Card  Female  Married
# 12        13  Promotional      9  160.40              Visa  Female  Married
# 13        14  Promotional      2   64.50              Visa  Female  Married
# 15        16  Promotional      2   71.40  Proprietary Card    Male   Single
# 17        18      Regular      3   54.50          Discover  Female  Married
# ...

# %%
dfstore[   dfstore["Age"].between(35,55)  ].shape
# Out:
# (57, 8)

# %%
dfstore[   dfstore["Age"].between(35,55)  ].shape[0]
# Out:
# 57

# %%
dfstore["Age"].between(20,40)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 95    False
# 96     True
# 97    False
# 98     True
# 99    False
# Name: Age, Length: 100, dtype: bool

# %%
dfstore[     dfstore["Age"].between(20,40)   ]
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# 6          7  Promotional      2   78.00  Proprietary Card  Female  Married
# 7          8      Regular      1   22.50              Visa  Female  Married
# 9         10      Regular      1   44.50  Proprietary Card  Female  Married
# 11        12  Promotional      1   31.60  Proprietary Card  Female  Married
# 12        13  Promotional      9  160.40              Visa  Female  Married
# 14        15      Regular      1   49.50              Visa    Male   Single
# ...

# %%
dfstore[     dfstore["Age"].between(20,40)   ].shape
# Out:
# (44, 8)

# %%
dfstore[     dfstore["Age"].between(20,40)   ].shape[0]
# Out:
# 44

# %%
dfstore["Age"].isin([30, 38])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96     True
# 97    False
# 98     True
# 99    False
# Name: Age, Length: 100, dtype: bool

# %%
dfstore[  dfstore["Age"].isin([30, 38]) ]
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 6          7  Promotional      2   78.00  Proprietary Card  Female  Married
# 21        22  Promotional      4   70.82  Proprietary Card  Female  Married
# 44        45  Promotional      2   23.80  Proprietary Card  Female  Married
# 47        48  Promotional      3   63.64  Proprietary Card  Female  Married
# 50        51  Promotional      6  176.62  Proprietary Card  Female  Married
# 55        56  Promotional      3  141.60  Proprietary Card  Female  Married
# 61        62  Promotional      3   59.91  Proprietary Card  Female   Single
# 70        71  Promotional      5  155.32  Proprietary Card  Female  Married
# 78        79  Promotional      3   86.80  Proprietary Card  Female  Married
# 81        82  Promotional      6   53.20  Proprietary Card  Female   Single
# 93        94  Promotional     17  229.50  Proprietary Card  Female  Married
# ...

# %%
dfstore[  dfstore["Age"].isin([30, 38]) ].shape
# Out:
# (13, 8)

# %%
dfstore[ dfstore["Age"].between(30,38)   ]
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# 6          7  Promotional      2   78.00  Proprietary Card  Female  Married
# 9         10      Regular      1   44.50  Proprietary Card  Female  Married
# 15        16  Promotional      2   71.40  Proprietary Card    Male   Single
# 18        19  Promotional      2   38.50        MasterCard  Female  Married
# 21        22  Promotional      4   70.82  Proprietary Card  Female  Married
# 28        29  Promotional      3   71.20  Proprietary Card  Female  Married
# 33        34      Regular      1   40.00  Proprietary Card  Female  Married
# ...

# %%
dfstore[ dfstore["Age"].between(30,38)   ].shape
# Out:
# (30, 8)

# %%
dfstore["Age"] >= 30
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: Age, Length: 100, dtype: bool

# %%
dfstore[ dfstore["Age"] >= 30  ]
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# 5          6      Regular      1   44.50        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
#     Age
# 0    32
# 1    36
# 2    32
# 4    34
# ...

# %%
dfstore [ dfstore["Age"] <= 38 ]
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# 6          7  Promotional      2   78.00  Proprietary Card  Female  Married
# 9         10      Regular      1   44.50  Proprietary Card  Female  Married
# 14        15      Regular      1   49.50              Visa    Male   Single
# 15        16  Promotional      2   71.40  Proprietary Card    Male   Single
# 16        17  Promotional      3   94.00  Proprietary Card  Female   Single
# 18        19  Promotional      2   38.50        MasterCard  Female  Married
# ...

# %%
(dfstore["Age"] >= 30)   &     (dfstore["Age"] <= 38)
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
#       ...
# 95    False
# 96     True
# 97    False
# 98     True
# 99    False
# Name: Age, Length: 100, dtype: bool

# %%
dfstore[ (dfstore["Age"] >= 30)   &     (dfstore["Age"] <= 38)]
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# 6          7  Promotional      2   78.00  Proprietary Card  Female  Married
# 9         10      Regular      1   44.50  Proprietary Card  Female  Married
# 15        16  Promotional      2   71.40  Proprietary Card    Male   Single
# 18        19  Promotional      2   38.50        MasterCard  Female  Married
# 21        22  Promotional      4   70.82  Proprietary Card  Female  Married
# 28        29  Promotional      3   71.20  Proprietary Card  Female  Married
# 33        34      Regular      1   40.00  Proprietary Card  Female  Married
# ...

# %%
dfstore[ dfstore["Age"].between(30,38)   ].shape
# Out:
# (30, 8)

# %%
dfstore[ (dfstore["Age"] >= 30)   &     (dfstore["Age"] <= 38)].shape
# Out:
# (30, 8)

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
#     Age
# 0    32
# 1    36
# 2    32
# 3    28
# ...

# %%
dfstore["PaymentMethod"]
# Out:
# 0             Discover
# 1     Proprietary Card
# 2     Proprietary Card
# 3     Proprietary Card
# 4           MasterCard
#             ...
# 95          MasterCard
# 96    Proprietary Card
# 97    Proprietary Card
# 98    Proprietary Card
# 99    Proprietary Card
# Name: PaymentMethod, Length: 100, dtype: object

# %%
dfstore["PaymentMethod"].unique()
# Out:
# array(['Discover', 'Proprietary Card', 'MasterCard', 'Visa',
#        'American Express'], dtype=object)

# %%
['Discover', 'MasterCard', 'Visa']
# Out:
# ['Discover', 'MasterCard', 'Visa']

# %%
dfstore["PaymentMethod"].isin(['Discover', 'MasterCard', 'Visa'])
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 95     True
# 96    False
# 97    False
# 98    False
# 99    False
# Name: PaymentMethod, Length: 100, dtype: bool

# %%
dfstore[  dfstore["PaymentMethod"].isin(['Discover', 'MasterCard', 'Visa']) ]
# Out:
#     Customer     CustType  Items  Sales PaymentMethod  Gender   Status  Age
# 0          1      Regular      1   39.5      Discover    Male  Married   32
# 4          5      Regular      2   54.0    MasterCard  Female  Married   34
# 5          6      Regular      1   44.5    MasterCard  Female  Married   44
# 7          8      Regular      1   22.5          Visa  Female  Married   40
# 12        13  Promotional      9  160.4          Visa  Female  Married   40
# 13        14  Promotional      2   64.5          Visa  Female  Married   46
# 14        15      Regular      1   49.5          Visa    Male   Single   24
# 17        18      Regular      3   54.5      Discover  Female  Married   40
# 18        19  Promotional      2   38.5    MasterCard  Female  Married   32
# 24        25  Promotional      2   39.5          Visa    Male  Married   48
# 30        31  Promotional      2   63.2    MasterCard  Female  Married   28
# ...

# %% [markdown]
# ###  Str.Replace

# %%
dfspeed = pd.read_csv(r"C:\Users\hp\Desktop\DATASETS\Datasets\replace\speed.csv")

# %%
dfspeed
# Out:
#          Date     Bajaj Price_india     Honda    Price Daytype
# 0  05-01-2021  135 kmph   Rs.150000  132 kmph  $1,500      Sun
# 1  05-02-2021  110 kmph   Rs.175000  112 kmph  $2,500    Windy
# 2  05-03-2021   98 kmph   Rs.150000   95 kmph  $3,500    Rainy
# 3  05-04-2021  105 kmph   Rs.200000  106 kmph  $2,500    Windy
# 4  05-05-2021  135 kmph   Rs.150000  133 kmph  $1,800      Sun
# 5  05-06-2021  140 kmph   Rs.100000  138 kmph  $2,500      Sun
# 6  05-07-2021  135 kmph   Rs.175000  138 kmph  $3,500      Sun
# 7  05-08-2021   90 kmph   Rs.100000   92 kmph  $2,500     Cold
# 8  05-09-2021   95 kmph   Rs.150007   93 kmph  $1,800     Cold
# 9  05-10-2021  100 kmph   Rs.175008   98 kmph  $1,500    Rainy

# %%
dfspeed['Bajaj'].replace('[a-z]', "", regex=True)
# Out:
# 0    135
# 1    110
# 2     98
# 3    105
# 4    135
# 5    140
# 6    135
# 7     90
# 8     95
# 9    100
# Name: Bajaj, dtype: object

# %%
dfbj = dfspeed[["Bajaj"]]

# %%
dfbj
# Out:
#       Bajaj
# 0  135 kmph
# 1  110 kmph
# 2   98 kmph
# 3  105 kmph
# 4  135 kmph
# 5  140 kmph
# 6  135 kmph
# 7   90 kmph
# 8   95 kmph
# 9  100 kmph

# %%
dfbj["Bajaj"].str.replace("kmph","")
# Out:
# 0    135
# 1    110
# 2     98
# 3    105
# 4    135
# 5    140
# 6    135
# 7     90
# 8     95
# 9    100
# Name: Bajaj, dtype: object

# %%
dfspeed
# Out:
#          Date     Bajaj Price_india     Honda    Price Daytype
# 0  05-01-2021  135 kmph   Rs.150000  132 kmph  $1,500      Sun
# 1  05-02-2021  110 kmph   Rs.175000  112 kmph  $2,500    Windy
# 2  05-03-2021   98 kmph   Rs.150000   95 kmph  $3,500    Rainy
# 3  05-04-2021  105 kmph   Rs.200000  106 kmph  $2,500    Windy
# 4  05-05-2021  135 kmph   Rs.150000  133 kmph  $1,800      Sun
# 5  05-06-2021  140 kmph   Rs.100000  138 kmph  $2,500      Sun
# 6  05-07-2021  135 kmph   Rs.175000  138 kmph  $3,500      Sun
# 7  05-08-2021   90 kmph   Rs.100000   92 kmph  $2,500     Cold
# 8  05-09-2021   95 kmph   Rs.150007   93 kmph  $1,800     Cold
# 9  05-10-2021  100 kmph   Rs.175008   98 kmph  $1,500    Rainy

# %%
dfspeed["Price_india"].str.replace("Rs.","")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8384\4030639417.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfspeed["Price_india"].str.replace("Rs.","")
# 0    150000
# 1    175000
# 2    150000
# 3    200000
# 4    150000
# 5    100000
# 6    175000
# 7    100000
# 8    150007
# 9    175008
# Name: Price_india, dtype: object

# %%
dfspeed
# Out:
#          Date     Bajaj Price_india     Honda    Price Daytype
# 0  05-01-2021  135 kmph   Rs.150000  132 kmph  $1,500      Sun
# 1  05-02-2021  110 kmph   Rs.175000  112 kmph  $2,500    Windy
# 2  05-03-2021   98 kmph   Rs.150000   95 kmph  $3,500    Rainy
# 3  05-04-2021  105 kmph   Rs.200000  106 kmph  $2,500    Windy
# 4  05-05-2021  135 kmph   Rs.150000  133 kmph  $1,800      Sun
# 5  05-06-2021  140 kmph   Rs.100000  138 kmph  $2,500      Sun
# 6  05-07-2021  135 kmph   Rs.175000  138 kmph  $3,500      Sun
# 7  05-08-2021   90 kmph   Rs.100000   92 kmph  $2,500     Cold
# 8  05-09-2021   95 kmph   Rs.150007   93 kmph  $1,800     Cold
# 9  05-10-2021  100 kmph   Rs.175008   98 kmph  $1,500    Rainy

# %%
dfspeed["Daytype"].str.upper()
# Out:
# 0      SUN
# 1    WINDY
# 2    RAINY
# 3    WINDY
# 4      SUN
# 5      SUN
# 6      SUN
# 7     COLD
# 8     COLD
# 9    RAINY
# Name: Daytype, dtype: object

# %%
dfspeed["Daytype"].map(lambda x : x.upper() )
# Out:
# 0      SUN
# 1    WINDY
# 2    RAINY
# 3    WINDY
# 4      SUN
# 5      SUN
# 6      SUN
# 7     COLD
# 8     COLD
# 9    RAINY
# Name: Daytype, dtype: object

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
#     Age
# 0    32
# 1    36
# 2    32
# 3    28
# ...

# %%
dfstd
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
lname = ["FAAA LAAA", "FBBB LBBB", "FCCC LCCC", "FDDD LDDD", "FEEE LEEE", "FFFF LFFF", "FGGG LGGG", "FHHH LHHH"]

# %%
lname
# Out:
# ['FAAA LAAA',
#  'FBBB LBBB',
#  'FCCC LCCC',
#  'FDDD LDDD',
#  'FEEE LEEE',
#  'FFFF LFFF',
#  'FGGG LGGG',
#  'FHHH LHHH']

# %%
dfstd
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
dfstd["SNAME"] = lname

# %%
dfstd
# Out:
#        SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0  FAAA LAAA       10       67        66       66
# 1  FBBB LBBB       12       87        56       65
# 2  FCCC LCCC       11       66        89       63
# 3  FDDD LDDD       10       56        88       66
# 4  FEEE LEEE       10       89        90       56
# 5  FFFF LFFF        9       88        85       89
# 6  FGGG LGGG       12       90        83       88
# 7  FHHH LHHH       11       79        88       90

# %%
dfstd["SNAME"].str.split(" ", expand=True)
# Out:
#       0     1
# 0  FAAA  LAAA
# 1  FBBB  LBBB
# 2  FCCC  LCCC
# 3  FDDD  LDDD
# 4  FEEE  LEEE
# 5  FFFF  LFFF
# 6  FGGG  LGGG
# 7  FHHH  LHHH

# %%
dfstd[["FNAME", "LNAME"]] = dfstd["SNAME"].str.split(" ", expand=True)

# %%
dfstd
# Out:
#        SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE FNAME LNAME
# 0  FAAA LAAA       10       67        66       66  FAAA  LAAA
# 1  FBBB LBBB       12       87        56       65  FBBB  LBBB
# 2  FCCC LCCC       11       66        89       63  FCCC  LCCC
# 3  FDDD LDDD       10       56        88       66  FDDD  LDDD
# 4  FEEE LEEE       10       89        90       56  FEEE  LEEE
# 5  FFFF LFFF        9       88        85       89  FFFF  LFFF
# 6  FGGG LGGG       12       90        83       88  FGGG  LGGG
# 7  FHHH LHHH       11       79        88       90  FHHH  LHHH

# %%
dfstd.drop("SNAME", axis = 1, inplace=True)

# %%
dfstd
# Out:
#    SCLASS   ENGLISH  COMPUTER  SCIENCE FNAME LNAME
# 0       10       67        66       66  FAAA  LAAA
# 1       12       87        56       65  FBBB  LBBB
# 2       11       66        89       63  FCCC  LCCC
# 3       10       56        88       66  FDDD  LDDD
# 4       10       89        90       56  FEEE  LEEE
# 5        9       88        85       89  FFFF  LFFF
# 6       12       90        83       88  FGGG  LGGG
# 7       11       79        88       90  FHHH  LHHH

# %%
dfstd.columns
# Out:
# Index(['SCLASS ', 'ENGLISH', 'COMPUTER', 'SCIENCE', 'FNAME', 'LNAME'], dtype='object')

# %%
dfstd = dfstd.reindex(columns=['FNAME', 'LNAME', 'SCLASS ', 'ENGLISH', 'COMPUTER', 'SCIENCE'])

# %%
dfstd
# Out:
#   FNAME LNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0  FAAA  LAAA       10       67        66       66
# 1  FBBB  LBBB       12       87        56       65
# 2  FCCC  LCCC       11       66        89       63
# 3  FDDD  LDDD       10       56        88       66
# 4  FEEE  LEEE       10       89        90       56
# 5  FFFF  LFFF        9       88        85       89
# 6  FGGG  LGGG       12       90        83       88
# 7  FHHH  LHHH       11       79        88       90

# %%
s1 = pd.Series(['XYZ123', 'xyz222', 'ABC890', 'SKY565', "GMP243", 'mnp543', 'kig675'])

# %%
s1
# Out:
# 0    XYZ123
# 1    xyz222
# 2    ABC890
# 3    SKY565
# 4    GMP243
# 5    mnp543
# 6    kig675
# dtype: object

# %%
s1.str.extract(r'([A-Z]+[0-9]+)')
# Out:
#         0
# 0  XYZ123
# 1     NaN
# 2  ABC890
# 3  SKY565
# 4  GMP243
# 5     NaN
# 6     NaN

# %%
# "([A-Z])"

# %%
s1 = ["F1","F2","F3","F4","F5"]

# %%
s2 = ["vizaghyderabadmumbaidelhi", "chennaimumbaidelhi", "kolkatahyderabadchennai", 
      "chennaivizagpunekolkata", "delhimumbaihyderabad"]

# %%
df1 = pd.DataFrame(s1, columns=["FName"])

# %%
df1
# Out:
#   FName
# 0    F1
# 1    F2
# 2    F3
# 3    F4
# 4    F5

# %%
df1["Route"] = s2

# %%
df1
# Out:
#   FName                      Route
# 0    F1  vizaghyderabadmumbaidelhi
# 1    F2         chennaimumbaidelhi
# 2    F3    kolkatahyderabadchennai
# 3    F4    chennaivizagpunekolkata
# 4    F5       delhimumbaihyderabad

# %%
df1["Route"].str.contains("hyderabad")
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Route, dtype: bool

# %%
df1[ df1["Route"].str.contains("hyderabad")]
# Out:
#   FName                      Route
# 0    F1  vizaghyderabadmumbaidelhi
# 2    F3    kolkatahyderabadchennai
# 4    F5       delhimumbaihyderabad

# %%
dfcolor = pd.DataFrame(["Green","Red","Blue","Orange","Red","Yellow","Green", "Blue"], columns=["Colours"])

# %%
dfcolor
# Out:
#   Colours
# 0   Green
# 1     Red
# 2    Blue
# 3  Orange
# 4     Red
# 5  Yellow
# 6   Green
# 7    Blue

# %%
pd.get_dummies(dfcolor)
# Out:
#    Colours_Blue  Colours_Green  Colours_Orange  Colours_Red  Colours_Yellow
# 0             0              1               0            0               0
# 1             0              0               0            1               0
# 2             1              0               0            0               0
# 3             0              0               1            0               0
# 4             0              0               0            1               0
# 5             0              0               0            0               1
# 6             0              1               0            0               0
# 7             1              0               0            0               0

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
#     Age
# 0    32
# 1    36
# 2    32
# 3    28
# ...

# %%
dfstore["PaymentMethod"]
# Out:
# 0             Discover
# 1     Proprietary Card
# 2     Proprietary Card
# 3     Proprietary Card
# 4           MasterCard
#             ...
# 95          MasterCard
# 96    Proprietary Card
# 97    Proprietary Card
# 98    Proprietary Card
# 99    Proprietary Card
# Name: PaymentMethod, Length: 100, dtype: object

# %%
dfstore["PaymentMethod"].unique()
# Out:
# array(['Discover', 'Proprietary Card', 'MasterCard', 'Visa',
#        'American Express'], dtype=object)

# %%
dfpay = pd.get_dummies(dfstore["PaymentMethod"])

# %%
dfpay
# Out:
#     American Express  Discover  MasterCard  Proprietary Card  Visa
# 0                  0         1           0                 0     0
# 1                  0         0           0                 1     0
# 2                  0         0           0                 1     0
# 3                  0         0           0                 1     0
# 4                  0         0           1                 0     0
# ..               ...       ...         ...               ...   ...
# 95                 0         0           1                 0     0
# 96                 0         0           0                 1     0
# 97                 0         0           0                 1     0
# 98                 0         0           0                 1     0
# 99                 0         0           0                 1     0
#
# [100 rows x 5 columns]

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
#     Age
# 0    32
# 1    36
# 2    32
# 3    28
# ...

# %%
dfstore = pd.concat([dfstore, dfpay], axis=1)

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales     PaymentMethod  Gender   Status  \
# 0          1      Regular      1   39.50          Discover    Male  Married
# 1          2  Promotional      1  102.40  Proprietary Card  Female  Married
# 2          3      Regular      1   22.50  Proprietary Card  Female  Married
# 3          4  Promotional      5  100.40  Proprietary Card  Female  Married
# 4          5      Regular      2   54.00        MasterCard  Female  Married
# ..       ...          ...    ...     ...               ...     ...      ...
# 95        96      Regular      1   39.50        MasterCard  Female  Married
# 96        97  Promotional      9  253.00  Proprietary Card  Female  Married
# 97        98  Promotional     10  287.59  Proprietary Card  Female  Married
# 98        99  Promotional      2   47.60  Proprietary Card  Female  Married
# 99       100  Promotional      1   28.44  Proprietary Card  Female  Married
#
# ...

# %%
dfstore.drop("PaymentMethod", axis = 1, inplace=True)

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales  Gender   Status  Age  \
# 0          1      Regular      1   39.50    Male  Married   32
# 1          2  Promotional      1  102.40  Female  Married   36
# 2          3      Regular      1   22.50  Female  Married   32
# 3          4  Promotional      5  100.40  Female  Married   28
# 4          5      Regular      2   54.00  Female  Married   34
# ..       ...          ...    ...     ...     ...      ...  ...
# 95        96      Regular      1   39.50  Female  Married   44
# 96        97  Promotional      9  253.00  Female  Married   30
# 97        98  Promotional     10  287.59  Female  Married   52
# 98        99  Promotional      2   47.60  Female  Married   30
# 99       100  Promotional      1   28.44  Female  Married   44
#
#     American Express  Discover  MasterCard  Proprietary Card  Visa
# 0                  0         1           0                 0     0
# 1                  0         0           0                 1     0
# ...

# %%
dfstore["Status"].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dfstatus = pd.get_dummies(dfstore["Status"])

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales  Gender   Status  Age  \
# 0          1      Regular      1   39.50    Male  Married   32
# 1          2  Promotional      1  102.40  Female  Married   36
# 2          3      Regular      1   22.50  Female  Married   32
# 3          4  Promotional      5  100.40  Female  Married   28
# 4          5      Regular      2   54.00  Female  Married   34
# ..       ...          ...    ...     ...     ...      ...  ...
# 95        96      Regular      1   39.50  Female  Married   44
# 96        97  Promotional      9  253.00  Female  Married   30
# 97        98  Promotional     10  287.59  Female  Married   52
# 98        99  Promotional      2   47.60  Female  Married   30
# 99       100  Promotional      1   28.44  Female  Married   44
#
#     American Express  Discover  MasterCard  Proprietary Card  Visa
# 0                  0         1           0                 0     0
# 1                  0         0           0                 1     0
# ...

# %%
dfstore = pd.concat([dfstore, dfstatus], axis = 1).drop("Status", axis = 1)

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales  Gender  Age  American Express  \
# 0          1      Regular      1   39.50    Male   32                 0
# 1          2  Promotional      1  102.40  Female   36                 0
# 2          3      Regular      1   22.50  Female   32                 0
# 3          4  Promotional      5  100.40  Female   28                 0
# 4          5      Regular      2   54.00  Female   34                 0
# ..       ...          ...    ...     ...     ...  ...               ...
# 95        96      Regular      1   39.50  Female   44                 0
# 96        97  Promotional      9  253.00  Female   30                 0
# 97        98  Promotional     10  287.59  Female   52                 0
# 98        99  Promotional      2   47.60  Female   30                 0
# 99       100  Promotional      1   28.44  Female   44                 0
#
#     Discover  MasterCard  Proprietary Card  Visa  Married  Single
# ...

# %%
dfstore["CustType"].unique()
# Out:
# array(['Regular', 'Promotional'], dtype=object)

# %%
dfcust = pd.get_dummies(dfstore["CustType"])

# %%
pd.concat([dfstore, dfcust], axis = 1).drop("CustType", axis = 1)
# Out:
#     Customer  Items   Sales  Gender  Age  American Express  Discover  \
# 0          1      1   39.50    Male   32                 0         1
# 1          2      1  102.40  Female   36                 0         0
# 2          3      1   22.50  Female   32                 0         0
# 3          4      5  100.40  Female   28                 0         0
# 4          5      2   54.00  Female   34                 0         0
# ..       ...    ...     ...     ...  ...               ...       ...
# 95        96      1   39.50  Female   44                 0         0
# 96        97      9  253.00  Female   30                 0         0
# 97        98     10  287.59  Female   52                 0         0
# 98        99      2   47.60  Female   30                 0         0
# 99       100      1   28.44  Female   44                 0         0
#
#     MasterCard  Proprietary Card  Visa  Married  Single  Promotional  Regular
# ...

# %%
dfstore
# Out:
#     Customer     CustType  Items   Sales  Gender  Age  American Express  \
# 0          1      Regular      1   39.50    Male   32                 0
# 1          2  Promotional      1  102.40  Female   36                 0
# 2          3      Regular      1   22.50  Female   32                 0
# 3          4  Promotional      5  100.40  Female   28                 0
# 4          5      Regular      2   54.00  Female   34                 0
# ..       ...          ...    ...     ...     ...  ...               ...
# 95        96      Regular      1   39.50  Female   44                 0
# 96        97  Promotional      9  253.00  Female   30                 0
# 97        98  Promotional     10  287.59  Female   52                 0
# 98        99  Promotional      2   47.60  Female   30                 0
# 99       100  Promotional      1   28.44  Female   44                 0
#
#     Discover  MasterCard  Proprietary Card  Visa  Married  Single
# ...

# %%
dfstore[["CustType", "Gender"]]
# Out:
#        CustType  Gender
# 0       Regular    Male
# 1   Promotional  Female
# 2       Regular  Female
# 3   Promotional  Female
# 4       Regular  Female
# ..          ...     ...
# 95      Regular  Female
# 96  Promotional  Female
# 97  Promotional  Female
# 98  Promotional  Female
# 99  Promotional  Female
#
# [100 rows x 2 columns]

# %%
dfsp = pd.get_dummies(dfstore[["CustType", "Gender"]])

# %%
dfsp
# Out:
#     CustType_Promotional  CustType_Regular  Gender_Female  Gender_Male
# 0                      0                 1              0            1
# 1                      1                 0              1            0
# 2                      0                 1              1            0
# 3                      1                 0              1            0
# 4                      0                 1              1            0
# ..                   ...               ...            ...          ...
# 95                     0                 1              1            0
# 96                     1                 0              1            0
# 97                     1                 0              1            0
# 98                     1                 0              1            0
# 99                     1                 0              1            0
#
# [100 rows x 4 columns]

# %%
pd.concat([dfstore, dfsp], axis = 1).drop(["CustType", "Gender"], axis = 1)
# Out:
#     Customer  Items   Sales  Age  American Express  Discover  MasterCard  \
# 0          1      1   39.50   32                 0         1           0
# 1          2      1  102.40   36                 0         0           0
# 2          3      1   22.50   32                 0         0           0
# 3          4      5  100.40   28                 0         0           0
# 4          5      2   54.00   34                 0         0           1
# ..       ...    ...     ...  ...               ...       ...         ...
# 95        96      1   39.50   44                 0         0           1
# 96        97      9  253.00   30                 0         0           0
# 97        98     10  287.59   52                 0         0           0
# 98        99      2   47.60   30                 0         0           0
# 99       100      1   28.44   44                 0         0           0
#
#     Proprietary Card  Visa  Married  Single  CustType_Promotional  \
# ...
