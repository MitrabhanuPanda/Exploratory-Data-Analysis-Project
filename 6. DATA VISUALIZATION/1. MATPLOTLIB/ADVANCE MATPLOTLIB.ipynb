# %% [markdown]
# # <font color="red">ADVANCE MATPLOTLIB</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
batter=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\DATA VISUALIZATION\MATPLOTLIB\DATASETS\ADVANCE\batsman_season_record.csv")

# %%
batter
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
iris=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\DATA VISUALIZATION\MATPLOTLIB\DATASETS\ADVANCE\iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
iris.sample(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 91  92            6.1           3.0            4.6           1.4        1
# 5    6            5.4           3.9            1.7           0.4        0
# 3    4            4.6           3.1            1.5           0.2        0
# 30  31            4.8           3.1            1.6           0.2        0
# 98  99            5.1           2.5            3.0           1.1        1

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="jet")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="jet")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.colorbar()

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="jet",alpha=0.5)
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.colorbar()

# %% [markdown]
# ## <font color="brown">PLOT SIZE</font>

# %% [markdown]
# #### `plt.figure(figsize=(width,height))`

# %%
plt.figure(figsize=(15,7))

plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="jet",alpha=0.5)
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.colorbar()

# %% [markdown]
# ## <font color="brown">ANNOTATION</font>

# %% [markdown]
# #### `plt.text(x1,y1,name)`

# %%
x = [1,2,3,4]
y = [5,6,7,8]

plt.scatter(x,y)
plt.text(1,5,'Point 1')
plt.text(2,6,'Point 2')
plt.text(3,7,'Point 3')
plt.text(4,8,'Point 4',fontdict={'size':12,'color':'brown'})
# Out:
# Text(4, 8, 'Point 4')

# %% [markdown]
# ####  `plt.ahline(y_cordinate_value,color="red"/"greeen")`

# %%
x = [1,2,3,4]
y = [5,6,7,8]

plt.scatter(x,y)

plt.axhline(6.5,color='red')
plt.axhline(7.0,color='green')
plt.axvline(2.5,color='red')

plt.text(1,5,'Point 1')
plt.text(2,6,'Point 2')
plt.text(3,7,'Point 3')
plt.text(4,8,'Point 4',fontdict={'size':12,'color':'brown'})
# Out:
# Text(4, 8, 'Point 4')

# %%
sample_df=pd.read_csv(r"C:\Users\mitra\Desktop\DUDUL DS\CAMPUSX\PYTHON\DATA VISUALIZATION\MATPLOTLIB\DATASETS\ADVANCE\batter.csv")

# %%
sample_df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %% [markdown]
# ## <font color="brown">SUB-PLOTS</font>
# * It is nothing but another way to plot graph.
# * You can also plot many graph using SubPlot.

# %%
plt.scatter(sample_df["avg"],sample_df["strike_rate"])

# %%
plt.subplots()

 # It give two objects. (Figure & Axes)
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %%
fig,ax = plt.subplots()  

ax.scatter(sample_df["avg"],sample_df["strike_rate"])   # Plot graph using axes object
ax.set_title("Batter")    # Add Title
ax.set_xlabel("Avg")    # Add x-axis lable
ax.set_ylabel("Strike_rate")   # Add y-axis lable

fig.show()
# Out:
# C:\Users\mitra\AppData\Local\Temp\ipykernel_26420\593720046.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig,ax = plt.subplots(figsize=(15,6))  # Add width & height / Increase the size of the Graph

ax.scatter(sample_df["avg"],sample_df["strike_rate"])   # Plot graph using axes object
ax.set_title("Batter")    # Add Title
ax.set_xlabel("Avg")    # Add x-axis lable
ax.set_ylabel("Strike_rate")   # Add y-axis lable
# Out:
# Text(0, 0.5, 'Strike_rate')

# %% [markdown]
# ### <font color="dark blue">HOW TO PLOT MULTIPLE GRAPHS</font>

# %%
plt.subplots(nrows=2,ncols=1)   # Add 2 Blank Figures
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
plt.subplots(nrows=2,ncols=2)  # Add 4 Blank Figures
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %% [markdown]
# ### <font color="green">PLOTTING 2 GRAPHS</font>

# %%
fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(10,6))

ax[0].scatter(sample_df["avg"],sample_df["strike_rate"])
ax[1].scatter(sample_df["runs"],sample_df["strike_rate"])


ax[0].set_title('Avg Vs Strike Rate')
ax[0].set_ylabel('Strike Rate')


ax[1].set_title('Avg Vs Runs')
ax[1].set_ylabel('Runs')
ax[1].set_xlabel('Avg')
# Out:
# Text(0.5, 0, 'Avg')

# %%
fig,ax = plt.subplots(nrows=2,ncols=1,sharex=True)

ax[0].scatter(sample_df["avg"],sample_df["strike_rate"])
ax[1].scatter(sample_df["runs"],sample_df["strike_rate"])

# %% [markdown]
# ### <font color="green">PLOTTING 4 GRAPHS</font>

# %%
fig,ax=plt.subplots(nrows=2, ncols=2)

ax[0,0].scatter(sample_df["avg"],sample_df["strike_rate"])
ax[0,1].scatter(sample_df["runs"],sample_df["strike_rate"])

ax[1,0].hist(sample_df["avg"])
ax[1,1].hist(sample_df["runs"])
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### <font color="dark blue">ANOTHER WAY TO PLOT MULTIPLE GRAPHS</font>

# %% [markdown]
# #### `fig.add_subplot(number of rows,number of columns,Figure number)`

# %%
fig=plt.figure()

ax1=fig.add_subplot(2,1,1)
ax1.scatter(sample_df["avg"],sample_df["strike_rate"])

ax2=fig.add_subplot(2,1,2)
ax2.scatter(sample_df["runs"],sample_df["strike_rate"])

# %%
fig=plt.figure()

ax1=fig.add_subplot(2,2,1)
ax1.scatter(sample_df["avg"],sample_df["strike_rate"])

ax2=fig.add_subplot(2,2,2)
ax2.scatter(sample_df["runs"],sample_df["strike_rate"])

ax3=fig.add_subplot(2,2,3)
ax3.hist(sample_df["runs"])


ax4=fig.add_subplot(2,2,4)
ax4.hist(sample_df["avg"])
# Out:
# (array([102., 125., 103.,  82.,  78.,  43.,  22.,  14.,   2.,   1.]),
#  array([ 0.        ,  5.56666667, 11.13333333, 16.7       , 22.26666667,
#         27.83333333, 33.4       , 38.96666667, 44.53333333, 50.1       ,
#         55.66666667]),
#  <BarContainer object of 10 artists>)
